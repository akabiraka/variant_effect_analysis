# %%
import os
import sys
home_dir = "../../"
module_path = os.path.abspath(os.path.join(home_dir))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import pandas as pd

# %%
conservation_df = pd.read_csv(home_dir+"data/cdd_conservationTable_18kHumanProts.csv.gzip", compression='gzip', comment='#')
print(conservation_df.shape)
print(conservation_df.columns)
conservation_df
# Out:
# (4104012, 36)
# Index(['qNo', 'NPid', 'accession', 'que', 'sub', 'ali', 'qPos', 'sPos', 'aPos',
#        'qPos_', 'sPos_', 'bitscore', 'A', 'D', 'C', 'E', 'F', 'G', 'H', 'I',
#        'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y', 'cons',
#        'entropy', 'qcov', 'CScore'],
#       dtype='object')
#          qNo            NPid  accession que sub ali  qPos  sPos  aPos  qPos_  \
# 0          1     NP_064505.1  pfam18400   S   A   |    57     1     1     57
# 1          1     NP_064505.1  pfam18400   T   T   |    58     2     2     58
# 2          1     NP_064505.1  pfam18400   P   P   |    59     3     3     59
# 3          1     NP_064505.1  pfam18400   L   L   |    60     4     4     60
# 4          1     NP_064505.1  pfam18400   L   L   |    61     5     5     61
# ...      ...             ...        ...  ..  ..  ..   ...   ...   ...    ...
# 4104007  961  NP_001091888.1  pfam05831   T   M   |   107   103   108    107
# 4104008  961  NP_001091888.1  pfam05831   P   P   |   108   104   109    108
# 4104009  961  NP_001091888.1  pfam05831   E   E       109   105   110    109
# 4104010  961  NP_001091888.1  pfam05831   E   A   |   110   106   111    110
# 4104011  961  NP_001091888.1  pfam05831   G   G  \n   111   107   112    111
#
#          ...         R         S         T         V    W         Y  cons  \
# 0        ...  0.000000  0.303030  0.000000  0.000000  0.0  0.000000     X
# 1        ...  0.000000  0.030303  0.555556  0.000000  0.0  0.000000     X
# 2        ...  0.000000  0.101010  0.000000  0.000000  0.0  0.000000     P
# 3        ...  0.000000  0.000000  0.000000  0.050505  0.0  0.161616     X
# 4        ...  0.000000  0.010101  0.010101  0.050505  0.0  0.020202     L
# ...      ...       ...       ...       ...       ...  ...       ...   ...
# 4104007  ...  0.041667  0.000000  0.041667  0.125000  0.0  0.000000     X
# 4104008  ...  0.000000  0.041667  0.000000  0.000000  0.0  0.000000     P
# 4104009  ...  0.041667  0.000000  0.000000  0.000000  0.0  0.000000     E
# 4104010  ...  0.000000  0.000000  0.041667  0.000000  0.0  0.000000     X
# 4104011  ...  0.000000  0.000000  0.000000  0.000000  0.0  0.000000     G
#
#           entropy      qcov    CScore
# 0        0.492204  0.715113  0.507796
# 1        0.288488  0.715113  0.711512
# 2        0.125695  0.715113  0.874305
# 3        0.479242  0.715113  0.520758
# 4        0.352476  0.715113  0.647524
# ...           ...       ...       ...
# 4104007  0.554522  0.905983  0.445478
# 4104008  0.308799  0.905983  0.691201
# 4104009  0.278218  0.905983  0.721782
# 4104010  0.315743  0.905983  0.684257
# 4104011  0.056891  0.905983  0.943109
#
# [4104012 rows x 36 columns]

# %%
from models.aa_common.data_loader import get_population_freq_SNVs
popu_freq_variants_df = get_population_freq_SNVs(home_dir=home_dir)
popu_freq_variants_df
# Out:
# Log: Loading data ...
# (95223, 13)
# Index(['snp_id', 'chrom_acc_version', 'chrom_pos', 'ref_allele', 'alt_allele',
#        'prot_acc_version', 'prot_pos', 'wt', 'mut', 'wt_population',
#        'mut_poulation', 'wt_freq', 'mt_freq'],
#       dtype='object')
# After combining common (18279), rare (29383) and sampled-singletons (48434), data: (95223, 13)
# NP_001277137.1    95
# NP_001291317.1    78
# NP_002115.2       74
# NP_112241.2       68
# NP_001075106.2    65
#                   ..
# NP_037408.2        1
# NP_066951.1        1
# NP_001013716.2     1
# NP_001316544.1     1
# NP_065171.2        1
# Name: prot_acc_version, Length: 14997, dtype: int64
#              snp_id chrom_acc_version  chrom_pos ref_allele alt_allele  \
# 0        rs41288789      NC_000002.12   26944749          G          A
# 1        rs34603401      NC_000001.11    9245386          A          C
# 2       rs115026899      NC_000001.11  210683774          C          A
# 3        rs17260829      NC_000006.12  122451974          T          C
# 4      rs1438318937      NC_000019.10   54575019          A          G
# ...             ...               ...        ...        ...        ...
# 95218  rs1404095987      NC_000007.14  143755938          T          C
# 95219  rs1331626452      NC_000019.10   57328412          G          C
# 95220   rs751861106      NC_000020.11   44921715          G          A
# 95221   rs771902243      NC_000008.11   28503161          C          T
# 95222  rs1433551223      NC_000019.10   11486860          G          A
#
#       prot_acc_version  prot_pos wt mut  wt_population  mut_poulation  \
# 0          NP_064519.2       512  A   T         218102          10302
# 1          NP_004276.2       151  D   A         225918          32086
# 2          NP_758872.1       826  G   V         211392           6706
# 3          NP_065806.1       225  S   G         301772          13333
# 4       NP_001124389.2       214  E   G          11862           5489
# ...                ...       ... ..  ..            ...            ...
# 95218      NP_848656.2       574  N   S          11862              1
# 95219      NP_998763.2       317  G   A           4470              1
# 95220   NP_001359108.1       287  R   Q          35412              1
# 95221      NP_059108.1        50  L   M          35424              1
# 95222      NP_620138.2       455  S   L          11862              1
#
#         wt_freq   mt_freq
# 0      0.954896  0.045104
# 1      0.875638  0.124362
# 2      0.969252  0.030748
# 3      0.957687  0.042313
# 4      0.683649  0.316351
# ...         ...       ...
# 95218  0.999916  0.000084
# 95219  0.999776  0.000224
# 95220  0.999972  0.000028
# 95221  0.999972  0.000028
# 95222  0.999916  0.000084
#
# [95223 rows x 13 columns]

# %%
for tuple in popu_freq_variants_df.itertuples():
    print(tuple)
    mask = (conservation_df["NPid"]==tuple.prot_acc_version) & (conservation_df["qPos"]==512)
    score = conservation_df[mask]
    print(score)
    break
# Out:
# Pandas(Index=0, snp_id='rs41288789', chrom_acc_version='NC_000002.12', chrom_pos=26944749, ref_allele='G', alt_allele='A', prot_acc_version='NP_064519.2', prot_pos=512, wt='A', mut='T', wt_population=218102, mut_poulation=10302, wt_freq=0.9548957111083868, mt_freq=0.0451042888916131)
# Empty DataFrame
# Columns: [qNo, NPid, accession, que, sub, ali, qPos, sPos, aPos, qPos_, sPos_, bitscore, A, D, C, E, F, G, H, I, K, L, M, N, P, Q, R, S, T, V, W, Y, cons, entropy, qcov, CScore]
# Index: []
#
# [0 rows x 36 columns]
