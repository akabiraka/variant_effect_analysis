# %%
import os
import sys
home_dir = "../../"
module_path = os.path.abspath(os.path.join(home_dir))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import pandas as pd 
from models.aa_common.data_loader import get_population_freq_SNVs

# %%
variants_df = get_population_freq_SNVs(home_dir)
variants_df = variants_df[variants_df["class"]!="Zero-population"]
# Out:
# Log: Loading data ...
# (2865836, 14)
# Index(['snp_id', 'chrom_acc_version', 'chrom_pos', 'ref_allele', 'alt_allele',
#        'prot_acc_version', 'prot_pos', 'wt', 'mut', 'wt_population',
#        'mut_poulation', 'wt_freq', 'mt_freq', 'class'],
#       dtype='object')
# Zero-population    2042590
# Singleton           462444
# Ultra-rare          314013
# Rare                 28622
# Common               18167
# Name: class, dtype: int64

# %%
# merging dbNSFP extracted scores with popu-freq dataset.
pred_df = pd.read_csv(home_dir+"models/dbnsfp/outputs/dbnsfp_outputs/popu_freq_preds.txt", sep="\t")
pred_df.drop(columns=['Polyphen2_HDIV_score'], inplace=True)
pred_df = pred_df.loc[pred_df[["#chr", "pos(1-based)", "ref", "alt"]].drop_duplicates(keep="first").index] # for a single chromosomal position, a model can have multiple outputs from dbnsfp, so removing them

pred_df.rename(columns={"#chr":"chrom", "pos(1-based)":"chrom_pos", "ref":"ref_allele", "alt":"alt_allele"}, inplace=True)
print(f"#-of SNVs found from dbNSFP: {pred_df.shape[0]}")

variants_df["chrom"] = variants_df["chrom_acc_version"].apply(lambda x: int(x[x.index("_")+1:x.index(".")])) # taking only chromosom number for dbNSFP inputs

print("Log: merging dbNSFP prediction scores with ground truth population freq data ...")
result_df = variants_df.merge(pred_df, how="inner", on=["chrom", "chrom_pos", "ref_allele", "alt_allele"])#, right_on=["#chr", "pos(1-based)", "ref", "alt"])
result_df = result_df.drop_duplicates(keep="first")
print(result_df.columns)
print(result_df.shape)
result_df["class"].value_counts()
# Out:
# /tmp/ipykernel_897068/2035382353.py:2: DtypeWarning: Columns (13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   pred_df = pd.read_csv(home_dir+"models/dbnsfp/outputs/dbnsfp_outputs/popu_freq_preds.txt", sep="\t")
# #-of SNVs found from dbNSFP: 2367960
# Log: merging dbNSFP prediction scores with ground truth population freq data ...
# Index(['snp_id', 'chrom_acc_version', 'chrom_pos', 'ref_allele', 'alt_allele',
#        'prot_acc_version', 'prot_pos', 'wt', 'mut', 'wt_population',
#        'mut_poulation', 'wt_freq', 'mt_freq', 'class', 'chrom', 'aaref',
#        'aaalt', 'MetaRNN_score', 'MVP_score', 'SIFT_score',
#        'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score',
#        'integrated_fitCons_score', 'phyloP17way_primate',
#        'phastCons17way_primate', 'bStatistic'],
#       dtype='object')
# (786385, 27)
# Singleton     445925
# Ultra-rare    298006
# Rare           26419
# Common         16035
# Name: class, dtype: int64

# %%
# computing average scores for each method for each row
def compute_avg(x):
    x = str(x).split(";")
    return np.mean([float(i) for i in x if i!="."]) 

model_names = ['MetaRNN_score', 'MVP_score', 'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score', 'integrated_fitCons_score', 'phyloP17way_primate', 'phastCons17way_primate', 'bStatistic']
print("Log: missing values in percentages ...")
for model_name in model_names:
    model_scores = result_df[model_name].apply(compute_avg) # can have multiple scores, ie '0.4573521;0.4573521;0.4573521;0.4573521'. taking the avg
    result_df[model_name] = model_scores
    
    missing, total = result_df[pd.isna(result_df[model_name])].shape[0], result_df.shape[0]
    print(f"\t{model_name}: ({missing}/{total})*100 = {(missing / total) * 100:.4f}")
    # break
# Out:
# Log: missing values in percentages ...
# /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# 	MetaRNN_score: (2016/786385)*100 = 0.2564
# 	MVP_score: (23260/786385)*100 = 2.9578
# 	SIFT_score: (36950/786385)*100 = 4.6987
# 	Polyphen2_HVAR_score: (54050/786385)*100 = 6.8732
# 	CADD_raw: (0/786385)*100 = 0.0000
# 	REVEL_score: (33515/786385)*100 = 4.2619
# 	integrated_fitCons_score: (2790/786385)*100 = 0.3548
# 	phyloP17way_primate: (43/786385)*100 = 0.0055
# 	phastCons17way_primate: (43/786385)*100 = 0.0055
# 	bStatistic: (13107/786385)*100 = 1.6667

# %%
supervised_method_cols = ['MetaRNN_score', 'MVP_score', 'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score']
def get_num_of_methods_have_prediction_on_this_row(row):
    n = 0
    for col in supervised_method_cols:
        # print(pd.isna(row[col]))
        if not pd.isna(row[col]):
            n += 1
    # print(n)
    return n

for i in range(result_df.shape[0]):
    if i%10000==0: print(i)
    result_df.loc[i, "n_methods_having_preds"] = get_num_of_methods_have_prediction_on_this_row(result_df.loc[i])

print(result_df.shape)
print(result_df.columns)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# (786385, 28)
# Index(['snp_id', 'chrom_acc_version', 'chrom_pos', 'ref_allele', 'alt_allele',
#        'prot_acc_version', 'prot_pos', 'wt', 'mut', 'wt_population',
#        'mut_poulation', 'wt_freq', 'mt_freq', 'class', 'chrom', 'aaref',
#        'aaalt', 'MetaRNN_score', 'MVP_score', 'SIFT_score',
#        'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score',
#        'integrated_fitCons_score', 'phyloP17way_primate',
#        'phastCons17way_primate', 'bStatistic', 'n_methods_having_preds'],
#       dtype='object')

# %%
# keeping only those that for which at leat 3 out of 6 supervised models have predictions.
result_df = result_df[result_df["n_methods_having_preds"]>=3]
print(result_df.shape)
result_df["class"].value_counts()
# Out:
# (780183, 28)
# Singleton     442824
# Ultra-rare    295960
# Rare           26002
# Common         15397
# Name: class, dtype: int64

# %%
# recomputing the missing values to see how much reduced
model_names = ['MetaRNN_score', 'MVP_score', 'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score', 'integrated_fitCons_score', 'phyloP17way_primate', 'phastCons17way_primate', 'bStatistic']
for model_name in model_names:
    missing, total = result_df[pd.isna(result_df[model_name])].shape[0], result_df.shape[0]
    print(f"\t{model_name}: ({missing}/{total})*100 = {(missing / total) * 100:.4f}")
# Out:
# 	MetaRNN_score: (0/780183)*100 = 0.0000
# 	MVP_score: (17058/780183)*100 = 2.1864
# 	SIFT_score: (30748/780183)*100 = 3.9411
# 	Polyphen2_HVAR_score: (47848/780183)*100 = 6.1329
# 	CADD_raw: (0/780183)*100 = 0.0000
# 	REVEL_score: (27313/780183)*100 = 3.5008
# 	integrated_fitCons_score: (1427/780183)*100 = 0.1829
# 	phyloP17way_primate: (31/780183)*100 = 0.0040
# 	phastCons17way_primate: (31/780183)*100 = 0.0040
# 	bStatistic: (12606/780183)*100 = 1.6158

# %%
apply seq len filter here

# %%
prots = [] # having at least 1 variants for each class
data = []
n_unique_prots = result_df['prot_acc_version'].unique().shape[0]
for i, prot_acc_version in enumerate(result_df['prot_acc_version'].unique()):
    x = result_df[result_df['prot_acc_version']==prot_acc_version]
    class_dict = x["class"].value_counts().to_dict()
    if len(class_dict)==4:
        print(f"{i}|{n_unique_prots}", prot_acc_version, class_dict)
        prots.append(prot_acc_version)
        data.append(x[x["class"]=="Common"].sample(1, random_state=29))
        data.append(x[x["class"]=="Rare"].sample(1, random_state=29))
        data.append(x[x["class"]=="Ultra-rare"].sample(1, random_state=29))
        data.append(x[x["class"]=="Singleton"].sample(1, random_state=29))
    # if i==10: break
    
print(len(prots))
data = pd.concat(data)
print(data.shape)
print(data.columns)
data.to_csv(home_dir+f"models/aa_common/datasets_population_freq/SNVs_with_popu_freq_sampled.tsv", sep="\t")
# Out:
# 1|15129 NP_064519.2 {'Singleton': 27, 'Ultra-rare': 18, 'Rare': 1, 'Common': 1}
# 3|15129 NP_004276.2 {'Ultra-rare': 108, 'Singleton': 83, 'Rare': 3, 'Common': 1}
# 4|15129 NP_758872.1 {'Singleton': 38, 'Ultra-rare': 31, 'Rare': 2, 'Common': 1}
# 6|15129 NP_065806.1 {'Singleton': 21, 'Ultra-rare': 18, 'Rare': 1, 'Common': 1}
# 9|15129 NP_001124389.2 {'Ultra-rare': 43, 'Singleton': 36, 'Rare': 21, 'Common': 11}
# 10|15129 NP_003357.2 {'Singleton': 30, 'Ultra-rare': 12, 'Rare': 2, 'Common': 1}
# 11|15129 NP_064560.2 {'Singleton': 59, 'Ultra-rare': 39, 'Rare': 2, 'Common': 2}
# 14|15129 NP_112228.1 {'Singleton': 14, 'Ultra-rare': 10, 'Rare': 5, 'Common': 3}
# 17|15129 NP_067022.1 {'Singleton': 44, 'Ultra-rare': 21, 'Rare': 2, 'Common': 1}
# 18|15129 NP_000693.1 {'Singleton': 39, 'Ultra-rare': 21, 'Common': 1, 'Rare': 1}
# 23|15129 NP_001171754.1 {'Singleton': 48, 'Ultra-rare': 38, 'Rare': 6, 'Common': 5}
# 26|15129 NP_079203.4 {'Singleton': 63, 'Ultra-rare': 30, 'Rare': 3, 'Common': 2}
# 28|15129 NP_001164225.1 {'Singleton': 55, 'Ultra-rare': 49, 'Common': 6, 'Rare': 5}
# 30|15129 NP_079539.2 {'Ultra-rare': 14, 'Singleton': 6, 'Rare': 1, 'Common': 1}
# 35|15129 NP_115827.1 {'Singleton': 72, 'Ultra-rare': 62, 'Rare': 6, 'Common': 1}
# 36|15129 NP_001157912.1 {'Singleton': 26, 'Ultra-rare': 13, 'Rare': 4, 'Common': 2}
# 38|15129 NP_002617.3 {'Singleton': 54, 'Ultra-rare': 41, 'Rare': 5, 'Common': 1}
# 39|15129 NP_001372577.1 {'Singleton': 39, 'Ultra-rare': 35, 'Rare': 2, 'Common': 1}
# 40|15129 NP_112599.2 {'Singleton': 14, 'Ultra-rare': 9, 'Rare': 1, 'Common': 1}
# 41|15129 NP_001071174.1 {'Singleton': 57, 'Ultra-rare': 43, 'Rare': 10, 'Common': 1}
# 42|15129 NP_001035940.1 {'Singleton': 39, 'Ultra-rare': 39, 'Common': 3, 'Rare': 2}
# 51|15129 NP_073753.3 {'Singleton': 65, 'Ultra-rare': 38, 'Rare': 3, 'Common': 3}
# 53|15129 NP_000180.2 {'Singleton': 65, 'Ultra-rare': 44, 'Rare': 3, 'Common': 2}
# 55|15129 NP_055106.1 {'Ultra-rare': 33, 'Singleton': 33, 'Rare': 2, 'Common': 2}
# 56|15129 NP_788276.1 {'Singleton': 41, 'Ultra-rare': 35, 'Rare': 5, 'Common': 1}
# 59|15129 NP_061732.1 {'Singleton': 61, 'Ultra-rare': 30, 'Rare': 2, 'Common': 1}
# 60|15129 NP_001005356.1 {'Singleton': 21, 'Ultra-rare': 20, 'Rare': 12, 'Common': 6}
# 61|15129 NP_060988.3 {'Singleton': 74, 'Ultra-rare': 48, 'Common': 5, 'Rare': 1}
# 64|15129 NP_057118.1 {'Singleton': 29, 'Ultra-rare': 24, 'Common': 2, 'Rare': 1}
# 65|15129 NP_001167594.1 {'Singleton': 28, 'Ultra-rare': 18, 'Rare': 3, 'Common': 1}
# 66|15129 NP_001276880.1 {'Singleton': 54, 'Ultra-rare': 52, 'Rare': 6, 'Common': 1}
# 67|15129 NP_004052.2 {'Singleton': 55, 'Ultra-rare': 29, 'Rare': 3, 'Common': 2}
# 69|15129 NP_077740.1 {'Singleton': 85, 'Ultra-rare': 48, 'Rare': 5, 'Common': 2}
# 70|15129 NP_001161840.1 {'Singleton': 36, 'Ultra-rare': 26, 'Rare': 4, 'Common': 1}
# 75|15129 NP_060898.2 {'Singleton': 51, 'Ultra-rare': 24, 'Rare': 3, 'Common': 1}
# 79|15129 NP_000810.1 {'Singleton': 57, 'Ultra-rare': 41, 'Rare': 7, 'Common': 2}
# 87|15129 NP_000076.2 {'Singleton': 69, 'Ultra-rare': 47, 'Common': 7, 'Rare': 3}
# 88|15129 NP_689550.2 {'Singleton': 27, 'Ultra-rare': 21, 'Rare': 3, 'Common': 2}
# 89|15129 NP_001153780.1 {'Singleton': 45, 'Ultra-rare': 20, 'Rare': 2, 'Common': 2}
# 92|15129 NP_001013663.1 {'Ultra-rare': 34, 'Singleton': 24, 'Rare': 4, 'Common': 2}
# 93|15129 NP_061854.1 {'Singleton': 62, 'Ultra-rare': 26, 'Common': 3, 'Rare': 2}
# 94|15129 NP_689988.1 {'Singleton': 52, 'Ultra-rare': 34, 'Common': 5, 'Rare': 4}
# 96|15129 NP_001288711.1 {'Singleton': 43, 'Ultra-rare': 26, 'Rare': 7, 'Common': 2}
# 97|15129 NP_003408.1 {'Singleton': 47, 'Ultra-rare': 42, 'Common': 2, 'Rare': 1}
# 98|15129 NP_071361.2 {'Singleton': 28, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 99|15129 NP_002437.2 {'Singleton': 65, 'Ultra-rare': 25, 'Rare': 6, 'Common': 2}
# 102|15129 NP_963925.2 {'Singleton': 55, 'Ultra-rare': 42, 'Rare': 6, 'Common': 2}
# 103|15129 NP_689624.2 {'Singleton': 69, 'Ultra-rare': 35, 'Rare': 2, 'Common': 1}
# 104|15129 NP_001337850.1 {'Singleton': 73, 'Ultra-rare': 42, 'Rare': 6, 'Common': 3}
# 108|15129 NP_001010889.1 {'Rare': 26, 'Singleton': 24, 'Common': 21, 'Ultra-rare': 17}
# 111|15129 NP_060592.2 {'Singleton': 36, 'Ultra-rare': 20, 'Rare': 3, 'Common': 1}
# 112|15129 NP_001716.3 {'Singleton': 32, 'Ultra-rare': 28, 'Common': 4, 'Rare': 3}
# 113|15129 NP_001243793.1 {'Singleton': 63, 'Ultra-rare': 39, 'Rare': 4, 'Common': 1}
# 115|15129 NP_001384175.1 {'Singleton': 34, 'Ultra-rare': 28, 'Common': 2, 'Rare': 1}
# 117|15129 NP_060197.4 {'Singleton': 45, 'Ultra-rare': 37, 'Rare': 1, 'Common': 1}
# 118|15129 NP_006291.2 {'Singleton': 34, 'Ultra-rare': 22, 'Rare': 5, 'Common': 3}
# 119|15129 NP_066292.2 {'Ultra-rare': 53, 'Singleton': 42, 'Common': 20, 'Rare': 3}
# 120|15129 NP_005281.1 {'Singleton': 22, 'Ultra-rare': 21, 'Rare': 2, 'Common': 1}
# 122|15129 NP_001342405.1 {'Ultra-rare': 33, 'Singleton': 26, 'Rare': 16, 'Common': 3}
# 124|15129 NP_056344.2 {'Singleton': 41, 'Ultra-rare': 37, 'Common': 1, 'Rare': 1}
# 128|15129 NP_002046.1 {'Singleton': 40, 'Ultra-rare': 23, 'Common': 2, 'Rare': 1}
# 172|15129 NP_001277008.1 {'Singleton': 25, 'Ultra-rare': 11, 'Rare': 6, 'Common': 1}
# 173|15129 NP_473448.1 {'Singleton': 19, 'Ultra-rare': 15, 'Rare': 2, 'Common': 2}
# 175|15129 NP_000136.2 {'Singleton': 42, 'Ultra-rare': 27, 'Common': 2, 'Rare': 1}
# 179|15129 NP_001257437.1 {'Singleton': 49, 'Ultra-rare': 41, 'Rare': 2, 'Common': 1}
# 180|15129 NP_078988.3 {'Singleton': 73, 'Ultra-rare': 40, 'Rare': 4, 'Common': 2}
# 181|15129 NP_001138476.2 {'Ultra-rare': 47, 'Singleton': 30, 'Rare': 29, 'Common': 17}
# 183|15129 NP_060401.3 {'Ultra-rare': 35, 'Singleton': 34, 'Common': 4, 'Rare': 3}
# 189|15129 NP_778223.2 {'Singleton': 51, 'Ultra-rare': 50, 'Common': 8, 'Rare': 7}
# 190|15129 NP_777598.3 {'Singleton': 26, 'Ultra-rare': 18, 'Rare': 3, 'Common': 1}
# 191|15129 NP_006830.2 {'Singleton': 60, 'Ultra-rare': 29, 'Rare': 2, 'Common': 1}
# 194|15129 NP_945352.4 {'Ultra-rare': 14, 'Singleton': 12, 'Rare': 2, 'Common': 1}
# 195|15129 NP_001356718.1 {'Singleton': 76, 'Ultra-rare': 34, 'Rare': 2, 'Common': 1}
# 196|15129 NP_001002836.2 {'Singleton': 19, 'Ultra-rare': 10, 'Rare': 2, 'Common': 1}
# 197|15129 NP_001380918.1 {'Ultra-rare': 7, 'Singleton': 6, 'Rare': 2, 'Common': 2}
# 199|15129 NP_786923.1 {'Singleton': 30, 'Ultra-rare': 9, 'Rare': 1, 'Common': 1}
# 201|15129 NP_071373.2 {'Singleton': 40, 'Ultra-rare': 38, 'Rare': 1, 'Common': 1}
# 202|15129 NP_001342126.2 {'Singleton': 35, 'Ultra-rare': 22, 'Rare': 9, 'Common': 1}
# 203|15129 NP_001152994.1 {'Ultra-rare': 34, 'Singleton': 32, 'Rare': 6, 'Common': 2}
# 205|15129 NP_477513.2 {'Singleton': 32, 'Ultra-rare': 19, 'Common': 2, 'Rare': 1}
# 206|15129 NP_001005181.1 {'Singleton': 19, 'Ultra-rare': 18, 'Rare': 1, 'Common': 1}
# 208|15129 NP_000741.1 {'Singleton': 47, 'Ultra-rare': 25, 'Rare': 4, 'Common': 1}
# 209|15129 NP_068800.2 {'Singleton': 33, 'Ultra-rare': 28, 'Rare': 2, 'Common': 1}
# 210|15129 NP_001363852.1 {'Singleton': 21, 'Ultra-rare': 13, 'Rare': 4, 'Common': 1}
# 211|15129 NP_001001415.2 {'Singleton': 52, 'Ultra-rare': 41, 'Rare': 7, 'Common': 1}
# 215|15129 NP_036288.2 {'Singleton': 53, 'Ultra-rare': 38, 'Rare': 2, 'Common': 1}
# 217|15129 NP_116078.4 {'Ultra-rare': 34, 'Singleton': 32, 'Common': 4, 'Rare': 2}
# 219|15129 NP_001538.4 {'Singleton': 33, 'Ultra-rare': 18, 'Rare': 2, 'Common': 2}
# 220|15129 NP_000678.1 {'Singleton': 37, 'Ultra-rare': 21, 'Rare': 3, 'Common': 1}
# 223|15129 NP_006776.1 {'Singleton': 43, 'Ultra-rare': 25, 'Rare': 1, 'Common': 1}
# 226|15129 NP_061987.3 {'Singleton': 65, 'Ultra-rare': 46, 'Rare': 2, 'Common': 1}
# 230|15129 NP_036232.2 {'Singleton': 49, 'Ultra-rare': 22, 'Common': 2, 'Rare': 1}
# 235|15129 NP_066023.2 {'Singleton': 80, 'Ultra-rare': 75, 'Rare': 5, 'Common': 2}
# 237|15129 NP_115904.1 {'Ultra-rare': 17, 'Singleton': 8, 'Rare': 1, 'Common': 1}
# 243|15129 NP_001375419.1 {'Singleton': 60, 'Ultra-rare': 49, 'Rare': 6, 'Common': 1}
# 246|15129 NP_001073947.1 {'Singleton': 45, 'Ultra-rare': 40, 'Rare': 6, 'Common': 1}
# 247|15129 NP_001123544.1 {'Singleton': 44, 'Ultra-rare': 30, 'Rare': 3, 'Common': 2}
# 248|15129 NP_002678.3 {'Singleton': 56, 'Ultra-rare': 36, 'Rare': 1, 'Common': 1}
# 251|15129 NP_001072988.1 {'Singleton': 55, 'Ultra-rare': 36, 'Rare': 2, 'Common': 2}
# 252|15129 NP_001177739.1 {'Singleton': 41, 'Ultra-rare': 21, 'Rare': 11, 'Common': 4}
# 255|15129 NP_997289.2 {'Singleton': 34, 'Ultra-rare': 19, 'Rare': 3, 'Common': 1}
# 256|15129 NP_001005275.2 {'Singleton': 45, 'Ultra-rare': 23, 'Rare': 2, 'Common': 1}
# 257|15129 NP_061734.1 {'Singleton': 57, 'Ultra-rare': 34, 'Rare': 8, 'Common': 7}
# 259|15129 NP_003670.2 {'Singleton': 23, 'Ultra-rare': 22, 'Rare': 3, 'Common': 1}
# 262|15129 NP_937824.3 {'Singleton': 26, 'Ultra-rare': 18, 'Common': 8, 'Rare': 4}
# 263|15129 NP_001291317.1 {'Singleton': 62, 'Ultra-rare': 58, 'Rare': 35, 'Common': 31}
# 266|15129 NP_001382865.1 {'Ultra-rare': 21, 'Singleton': 17, 'Rare': 1, 'Common': 1}
# 267|15129 NP_001073868.2 {'Singleton': 44, 'Ultra-rare': 32, 'Rare': 5, 'Common': 1}
# 268|15129 NP_001242904.1 {'Ultra-rare': 67, 'Singleton': 61, 'Rare': 3, 'Common': 3}
# 269|15129 NP_001005190.1 {'Singleton': 21, 'Ultra-rare': 21, 'Rare': 7, 'Common': 3}
# 271|15129 NP_004583.2 {'Singleton': 67, 'Ultra-rare': 45, 'Rare': 3, 'Common': 2}
# 275|15129 NP_861454.2 {'Singleton': 39, 'Ultra-rare': 33, 'Rare': 7, 'Common': 1}
# 277|15129 NP_997215.1 {'Singleton': 45, 'Ultra-rare': 39, 'Rare': 7, 'Common': 2}
# 278|15129 NP_766627.1 {'Singleton': 23, 'Ultra-rare': 10, 'Rare': 1, 'Common': 1}
# 279|15129 NP_001004485.1 {'Singleton': 27, 'Ultra-rare': 16, 'Common': 4, 'Rare': 3}
# 281|15129 NP_694944.1 {'Singleton': 28, 'Ultra-rare': 26, 'Common': 2, 'Rare': 1}
# 285|15129 NP_006565.2 {'Singleton': 28, 'Ultra-rare': 18, 'Common': 2, 'Rare': 1}
# 288|15129 NP_001131022.1 {'Singleton': 45, 'Ultra-rare': 41, 'Rare': 1, 'Common': 1}
# 289|15129 NP_001116241.1 {'Singleton': 55, 'Ultra-rare': 35, 'Rare': 1, 'Common': 1}
# 290|15129 NP_115516.1 {'Singleton': 26, 'Ultra-rare': 19, 'Rare': 2, 'Common': 2}
# 291|15129 NP_849193.1 {'Singleton': 38, 'Ultra-rare': 15, 'Rare': 1, 'Common': 1}
# 292|15129 NP_079493.1 {'Singleton': 17, 'Ultra-rare': 14, 'Rare': 5, 'Common': 2}
# 295|15129 NP_006855.3 {'Singleton': 50, 'Common': 24, 'Ultra-rare': 22, 'Rare': 15}
# 298|15129 NP_001185.3 {'Singleton': 41, 'Ultra-rare': 24, 'Common': 4, 'Rare': 4}
# 305|15129 NP_001167541.1 {'Singleton': 51, 'Ultra-rare': 25, 'Rare': 2, 'Common': 1}
# 307|15129 NP_003062.2 {'Singleton': 65, 'Ultra-rare': 32, 'Rare': 9, 'Common': 1}
# 308|15129 NP_001361188.1 {'Singleton': 55, 'Ultra-rare': 47, 'Rare': 4, 'Common': 1}
# 309|15129 NP_001106177.1 {'Singleton': 72, 'Ultra-rare': 41, 'Rare': 7, 'Common': 2}
# 312|15129 NP_060842.3 {'Singleton': 49, 'Ultra-rare': 33, 'Rare': 3, 'Common': 1}
# 316|15129 NP_064504.2 {'Singleton': 61, 'Ultra-rare': 45, 'Rare': 4, 'Common': 3}
# 317|15129 NP_001867.2 {'Singleton': 63, 'Ultra-rare': 37, 'Rare': 3, 'Common': 1}
# 319|15129 NP_079388.3 {'Singleton': 63, 'Ultra-rare': 45, 'Rare': 3, 'Common': 3}
# 320|15129 NP_061739.2 {'Singleton': 72, 'Ultra-rare': 49, 'Rare': 3, 'Common': 3}
# 321|15129 NP_085143.1 {'Singleton': 46, 'Ultra-rare': 27, 'Rare': 1, 'Common': 1}
# 324|15129 NP_001357478.1 {'Singleton': 41, 'Ultra-rare': 20, 'Common': 2, 'Rare': 1}
# 326|15129 NP_036276.1 {'Singleton': 46, 'Ultra-rare': 46, 'Rare': 3, 'Common': 1}
# 327|15129 NP_001369426.1 {'Singleton': 20, 'Ultra-rare': 15, 'Rare': 2, 'Common': 1}
# 330|15129 NP_079093.2 {'Singleton': 94, 'Ultra-rare': 51, 'Rare': 4, 'Common': 1}
# 332|15129 NP_003314.2 {'Singleton': 33, 'Ultra-rare': 26, 'Rare': 4, 'Common': 1}
# 333|15129 NP_004283.2 {'Singleton': 60, 'Ultra-rare': 52, 'Rare': 8, 'Common': 1}
# 334|15129 NP_001273575.1 {'Singleton': 73, 'Ultra-rare': 60, 'Rare': 5, 'Common': 2}
# 335|15129 NP_659428.2 {'Ultra-rare': 55, 'Singleton': 53, 'Rare': 7, 'Common': 1}
# 336|15129 NP_938023.1 {'Singleton': 27, 'Ultra-rare': 23, 'Common': 4, 'Rare': 1}
# 339|15129 NP_631901.2 {'Ultra-rare': 39, 'Singleton': 35, 'Rare': 1, 'Common': 1}
# 341|15129 NP_964011.2 {'Singleton': 25, 'Ultra-rare': 19, 'Common': 2, 'Rare': 1}
# 342|15129 NP_009200.2 {'Singleton': 40, 'Ultra-rare': 15, 'Common': 1, 'Rare': 1}
# 343|15129 NP_149023.2 {'Singleton': 55, 'Ultra-rare': 19, 'Common': 6, 'Rare': 2}
# 344|15129 NP_065139.2 {'Singleton': 40, 'Ultra-rare': 23, 'Rare': 3, 'Common': 1}
# 349|15129 NP_899230.2 {'Singleton': 49, 'Ultra-rare': 24, 'Common': 1, 'Rare': 1}
# 350|15129 NP_036529.1 {'Singleton': 33, 'Ultra-rare': 22, 'Common': 2, 'Rare': 1}
# 351|15129 NP_001352719.1 {'Singleton': 53, 'Ultra-rare': 41, 'Rare': 4, 'Common': 3}
# 354|15129 NP_808592.2 {'Singleton': 29, 'Ultra-rare': 20, 'Common': 4, 'Rare': 2}
# 355|15129 NP_115814.1 {'Singleton': 40, 'Ultra-rare': 37, 'Rare': 2, 'Common': 1}
# 356|15129 NP_001155102.1 {'Ultra-rare': 26, 'Singleton': 25, 'Rare': 7, 'Common': 3}
# 357|15129 NP_001339443.1 {'Ultra-rare': 50, 'Singleton': 43, 'Rare': 4, 'Common': 2}
# 358|15129 NP_001139500.1 {'Ultra-rare': 23, 'Singleton': 22, 'Common': 1, 'Rare': 1}
# 359|15129 NP_689576.6 {'Singleton': 51, 'Ultra-rare': 49, 'Rare': 6, 'Common': 6}
# 360|15129 NP_001073998.2 {'Singleton': 33, 'Ultra-rare': 27, 'Rare': 10, 'Common': 2}
# 369|15129 NP_620137.2 {'Singleton': 49, 'Ultra-rare': 22, 'Rare': 2, 'Common': 1}
# 372|15129 NP_872401.3 {'Singleton': 25, 'Ultra-rare': 24, 'Rare': 2, 'Common': 2}
# 373|15129 NP_001494.2 {'Singleton': 69, 'Ultra-rare': 56, 'Rare': 7, 'Common': 7}
# 377|15129 NP_570602.2 {'Singleton': 32, 'Ultra-rare': 29, 'Rare': 3, 'Common': 1}
# 378|15129 NP_955384.3 {'Singleton': 46, 'Ultra-rare': 38, 'Rare': 2, 'Common': 1}
# 379|15129 NP_060604.2 {'Singleton': 34, 'Ultra-rare': 25, 'Rare': 3, 'Common': 2}
# 382|15129 NP_056256.1 {'Singleton': 71, 'Ultra-rare': 43, 'Rare': 6, 'Common': 1}
# 385|15129 NP_001004703.1 {'Singleton': 28, 'Ultra-rare': 24, 'Rare': 4, 'Common': 4}
# 386|15129 NP_037434.2 {'Singleton': 58, 'Ultra-rare': 42, 'Rare': 1, 'Common': 1}
# 388|15129 NP_065764.1 {'Singleton': 81, 'Ultra-rare': 48, 'Common': 3, 'Rare': 1}
# 389|15129 NP_001957.2 {'Ultra-rare': 54, 'Singleton': 48, 'Rare': 7, 'Common': 2}
# 390|15129 NP_031397.1 {'Singleton': 55, 'Ultra-rare': 25, 'Common': 4, 'Rare': 2}
# 392|15129 NP_055509.2 {'Singleton': 44, 'Ultra-rare': 26, 'Rare': 4, 'Common': 2}
# 394|15129 NP_006644.1 {'Singleton': 63, 'Ultra-rare': 33, 'Rare': 4, 'Common': 2}
# 395|15129 NP_003405.4 {'Singleton': 52, 'Ultra-rare': 36, 'Rare': 4, 'Common': 3}
# 396|15129 NP_001358989.1 {'Singleton': 27, 'Ultra-rare': 13, 'Rare': 5, 'Common': 1}
# 399|15129 NP_001128206.1 {'Singleton': 48, 'Ultra-rare': 38, 'Rare': 3, 'Common': 3}
# 403|15129 NP_001005486.2 {'Singleton': 35, 'Ultra-rare': 34, 'Common': 6, 'Rare': 1}
# 406|15129 NP_003958.2 {'Singleton': 30, 'Ultra-rare': 19, 'Rare': 3, 'Common': 1}
# 407|15129 NP_061959.2 {'Singleton': 33, 'Ultra-rare': 28, 'Rare': 6, 'Common': 2}
# 411|15129 NP_689896.1 {'Ultra-rare': 30, 'Singleton': 27, 'Rare': 3, 'Common': 1}
# 412|15129 NP_699192.1 {'Singleton': 38, 'Ultra-rare': 25, 'Rare': 2, 'Common': 1}
# 420|15129 NP_659482.3 {'Singleton': 34, 'Ultra-rare': 19, 'Rare': 4, 'Common': 1}
# 421|15129 NP_061928.4 {'Ultra-rare': 71, 'Singleton': 66, 'Rare': 9, 'Common': 1}
# 423|15129 NP_570970.2 {'Ultra-rare': 19, 'Singleton': 17, 'Rare': 9, 'Common': 1}
# 427|15129 NP_612490.1 {'Singleton': 51, 'Ultra-rare': 32, 'Common': 2, 'Rare': 1}
# 432|15129 NP_000333.1 {'Singleton': 71, 'Ultra-rare': 50, 'Rare': 4, 'Common': 4}
# 435|15129 NP_740754.1 {'Singleton': 36, 'Ultra-rare': 30, 'Rare': 4, 'Common': 2}
# 437|15129 NP_004696.2 {'Singleton': 46, 'Ultra-rare': 19, 'Rare': 4, 'Common': 1}
# 439|15129 NP_000536.6 {'Singleton': 42, 'Ultra-rare': 36, 'Common': 4, 'Rare': 1}
# 440|15129 NP_055107.3 {'Singleton': 27, 'Ultra-rare': 14, 'Rare': 3, 'Common': 1}
# 442|15129 NP_001094077.1 {'Singleton': 33, 'Ultra-rare': 30, 'Rare': 3, 'Common': 3}
# 443|15129 NP_001276091.1 {'Singleton': 69, 'Ultra-rare': 63, 'Rare': 6, 'Common': 3}
# 445|15129 NP_001380960.1 {'Singleton': 60, 'Ultra-rare': 28, 'Rare': 2, 'Common': 2}
# 446|15129 NP_006674.2 {'Singleton': 11, 'Ultra-rare': 9, 'Rare': 1, 'Common': 1}
# 450|15129 NP_065986.3 {'Singleton': 66, 'Ultra-rare': 28, 'Rare': 5, 'Common': 1}
# 453|15129 NP_068603.4 {'Singleton': 73, 'Ultra-rare': 51, 'Rare': 2, 'Common': 1}
# 554|15129 NP_001276330.1 {'Singleton': 55, 'Ultra-rare': 45, 'Rare': 5, 'Common': 1}
# 555|15129 NP_001035121.2 {'Singleton': 26, 'Ultra-rare': 22, 'Rare': 3, 'Common': 1}
# 558|15129 NP_008919.3 {'Singleton': 69, 'Ultra-rare': 49, 'Rare': 4, 'Common': 3}
# 559|15129 NP_002273.3 {'Ultra-rare': 49, 'Singleton': 37, 'Rare': 2, 'Common': 1}
# 563|15129 NP_001120730.1 {'Singleton': 64, 'Ultra-rare': 44, 'Rare': 2, 'Common': 1}
# 564|15129 NP_775808.4 {'Singleton': 41, 'Ultra-rare': 21, 'Rare': 3, 'Common': 3}
# 565|15129 NP_061141.2 {'Singleton': 86, 'Ultra-rare': 61, 'Rare': 1, 'Common': 1}
# 568|15129 NP_000675.1 {'Singleton': 23, 'Ultra-rare': 14, 'Rare': 2, 'Common': 2}
# 572|15129 NP_001138409.1 {'Singleton': 70, 'Ultra-rare': 38, 'Rare': 4, 'Common': 4}
# 575|15129 NP_001005466.2 {'Ultra-rare': 30, 'Singleton': 23, 'Rare': 4, 'Common': 1}
# 577|15129 NP_116204.3 {'Singleton': 37, 'Ultra-rare': 10, 'Rare': 2, 'Common': 1}
# 579|15129 NP_001037770.1 {'Singleton': 42, 'Ultra-rare': 15, 'Rare': 2, 'Common': 2}
# 581|15129 NP_001230.1 {'Singleton': 18, 'Ultra-rare': 17, 'Rare': 2, 'Common': 1}
# 582|15129 NP_008900.3 {'Singleton': 69, 'Ultra-rare': 48, 'Rare': 8, 'Common': 2}
# 583|15129 NP_003120.2 {'Singleton': 43, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 584|15129 NP_003568.2 {'Singleton': 17, 'Ultra-rare': 9, 'Rare': 2, 'Common': 1}
# 586|15129 NP_067638.3 {'Singleton': 56, 'Ultra-rare': 47, 'Rare': 4, 'Common': 1}
# 589|15129 NP_001356425.1 {'Singleton': 40, 'Ultra-rare': 32, 'Common': 1, 'Rare': 1}
# 590|15129 NP_003424.3 {'Singleton': 58, 'Ultra-rare': 37, 'Rare': 2, 'Common': 2}
# 592|15129 NP_005410.1 {'Singleton': 47, 'Ultra-rare': 25, 'Common': 3, 'Rare': 2}
# 593|15129 NP_001077005.1 {'Singleton': 49, 'Ultra-rare': 42, 'Rare': 1, 'Common': 1}
# 595|15129 NP_060685.2 {'Ultra-rare': 32, 'Singleton': 29, 'Rare': 2, 'Common': 2}
# 597|15129 NP_001144.1 {'Singleton': 18, 'Ultra-rare': 14, 'Rare': 2, 'Common': 1}
# 602|15129 NP_689901.2 {'Singleton': 23, 'Ultra-rare': 16, 'Rare': 1, 'Common': 1}
# 603|15129 NP_001353315.1 {'Singleton': 36, 'Ultra-rare': 30, 'Rare': 1, 'Common': 1}
# 605|15129 NP_001001976.1 {'Singleton': 34, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 607|15129 NP_001138604.1 {'Singleton': 12, 'Ultra-rare': 6, 'Rare': 1, 'Common': 1}
# 609|15129 NP_005844.4 {'Singleton': 28, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 612|15129 NP_006064.2 {'Singleton': 48, 'Ultra-rare': 46, 'Rare': 4, 'Common': 4}
# 616|15129 NP_001354543.1 {'Singleton': 61, 'Ultra-rare': 43, 'Rare': 3, 'Common': 2}
# 618|15129 NP_115960.2 {'Singleton': 38, 'Ultra-rare': 32, 'Rare': 4, 'Common': 4}
# 620|15129 NP_067633.2 {'Singleton': 46, 'Ultra-rare': 25, 'Rare': 3, 'Common': 1}
# 623|15129 NP_056089.1 {'Ultra-rare': 100, 'Singleton': 96, 'Rare': 9, 'Common': 4}
# 625|15129 NP_055093.2 {'Singleton': 47, 'Ultra-rare': 35, 'Rare': 2, 'Common': 1}
# 626|15129 NP_062551.1 {'Singleton': 28, 'Ultra-rare': 19, 'Rare': 3, 'Common': 1}
# 629|15129 NP_071443.2 {'Singleton': 38, 'Ultra-rare': 30, 'Rare': 2, 'Common': 1}
# 630|15129 NP_079363.2 {'Singleton': 58, 'Ultra-rare': 32, 'Rare': 7, 'Common': 2}
# 631|15129 NP_000192.2 {'Singleton': 38, 'Ultra-rare': 27, 'Rare': 4, 'Common': 4}
# 633|15129 NP_001036189.1 {'Singleton': 34, 'Ultra-rare': 29, 'Rare': 2, 'Common': 1}
# 637|15129 NP_114063.1 {'Singleton': 65, 'Ultra-rare': 47, 'Rare': 14, 'Common': 5}
# 640|15129 NP_004415.4 {'Singleton': 42, 'Ultra-rare': 24, 'Rare': 5, 'Common': 1}
# 643|15129 NP_055381.1 {'Singleton': 22, 'Ultra-rare': 14, 'Rare': 5, 'Common': 4}
# 647|15129 NP_001004691.1 {'Singleton': 31, 'Ultra-rare': 17, 'Rare': 5, 'Common': 3}
# 649|15129 NP_004061.3 {'Singleton': 44, 'Ultra-rare': 42, 'Common': 6, 'Rare': 2}
# 651|15129 NP_001138696.1 {'Singleton': 28, 'Ultra-rare': 22, 'Rare': 14, 'Common': 4}
# 652|15129 NP_981948.1 {'Singleton': 17, 'Ultra-rare': 9, 'Rare': 1, 'Common': 1}
# 653|15129 NP_055041.1 {'Singleton': 37, 'Ultra-rare': 22, 'Rare': 1, 'Common': 1}
# 654|15129 NP_001335124.1 {'Singleton': 14, 'Common': 6, 'Rare': 5, 'Ultra-rare': 4}
# 656|15129 NP_112603.2 {'Singleton': 39, 'Ultra-rare': 26, 'Common': 3, 'Rare': 3}
# 657|15129 NP_002840.2 {'Singleton': 49, 'Ultra-rare': 36, 'Rare': 6, 'Common': 2}
# 658|15129 NP_005233.4 {'Singleton': 26, 'Ultra-rare': 10, 'Common': 2, 'Rare': 1}
# 660|15129 NP_631916.2 {'Singleton': 24, 'Ultra-rare': 21, 'Rare': 3, 'Common': 1}
# 661|15129 NP_001946.3 {'Ultra-rare': 15, 'Singleton': 5, 'Rare': 1, 'Common': 1}
# 663|15129 NP_001012999.3 {'Singleton': 68, 'Ultra-rare': 68, 'Common': 5, 'Rare': 4}
# 665|15129 NP_065166.2 {'Singleton': 53, 'Ultra-rare': 28, 'Rare': 6, 'Common': 3}
# 670|15129 NP_001001974.1 {'Singleton': 39, 'Ultra-rare': 14, 'Rare': 1, 'Common': 1}
# 672|15129 NP_060556.2 {'Singleton': 49, 'Ultra-rare': 27, 'Common': 2, 'Rare': 1}
# 675|15129 NP_001073899.2 {'Singleton': 32, 'Ultra-rare': 20, 'Rare': 4, 'Common': 1}
# 676|15129 NP_443202.3 {'Singleton': 44, 'Ultra-rare': 22, 'Rare': 1, 'Common': 1}
# 677|15129 NP_113673.3 {'Singleton': 34, 'Ultra-rare': 30, 'Rare': 2, 'Common': 1}
# 679|15129 NP_057732.2 {'Singleton': 32, 'Ultra-rare': 25, 'Common': 3, 'Rare': 1}
# 680|15129 NP_060835.1 {'Ultra-rare': 31, 'Singleton': 26, 'Common': 5, 'Rare': 2}
# 683|15129 NP_000834.2 {'Singleton': 82, 'Ultra-rare': 80, 'Rare': 6, 'Common': 2}
# 685|15129 NP_001229658.1 {'Singleton': 45, 'Ultra-rare': 23, 'Rare': 2, 'Common': 1}
# 686|15129 NP_061731.1 {'Singleton': 48, 'Ultra-rare': 31, 'Rare': 5, 'Common': 2}
# 688|15129 NP_001904.2 {'Singleton': 36, 'Ultra-rare': 26, 'Rare': 2, 'Common': 2}
# 689|15129 NP_542406.2 {'Singleton': 30, 'Ultra-rare': 21, 'Rare': 3, 'Common': 1}
# 695|15129 NP_056366.1 {'Singleton': 49, 'Ultra-rare': 46, 'Rare': 7, 'Common': 2}
# 696|15129 NP_079170.2 {'Singleton': 40, 'Ultra-rare': 25, 'Rare': 5, 'Common': 1}
# 698|15129 NP_057095.4 {'Singleton': 34, 'Ultra-rare': 26, 'Rare': 2, 'Common': 1}
# 702|15129 NP_443739.3 {'Singleton': 53, 'Ultra-rare': 27, 'Common': 2, 'Rare': 1}
# 704|15129 NP_110385.1 {'Singleton': 78, 'Ultra-rare': 51, 'Rare': 3, 'Common': 2}
# 708|15129 NP_001338.2 {'Singleton': 86, 'Ultra-rare': 49, 'Rare': 6, 'Common': 1}
# 709|15129 NP_001004477.1 {'Ultra-rare': 23, 'Singleton': 21, 'Rare': 4, 'Common': 1}
# 710|15129 NP_056209.2 {'Singleton': 39, 'Ultra-rare': 21, 'Rare': 1, 'Common': 1}
# 711|15129 NP_001193555.1 {'Singleton': 31, 'Ultra-rare': 21, 'Rare': 4, 'Common': 1}
# 715|15129 NP_115639.1 {'Singleton': 26, 'Ultra-rare': 24, 'Rare': 3, 'Common': 1}
# 716|15129 NP_073587.1 {'Singleton': 48, 'Ultra-rare': 29, 'Rare': 2, 'Common': 1}
# 719|15129 NP_003293.2 {'Singleton': 52, 'Ultra-rare': 20, 'Rare': 3, 'Common': 1}
# 720|15129 NP_001269401.1 {'Singleton': 41, 'Ultra-rare': 38, 'Rare': 20, 'Common': 6}
# 769|15129 NP_001092288.1 {'Singleton': 57, 'Ultra-rare': 39, 'Rare': 4, 'Common': 1}
# 773|15129 NP_258260.1 {'Singleton': 61, 'Ultra-rare': 48, 'Common': 4, 'Rare': 1}
# 775|15129 NP_061883.1 {'Singleton': 32, 'Ultra-rare': 26, 'Rare': 4, 'Common': 1}
# 780|15129 NP_001362334.1 {'Singleton': 71, 'Ultra-rare': 49, 'Rare': 3, 'Common': 1}
# 791|15129 NP_006691.1 {'Singleton': 39, 'Ultra-rare': 21, 'Rare': 2, 'Common': 1}
# 792|15129 NP_056535.1 {'Singleton': 42, 'Ultra-rare': 26, 'Rare': 5, 'Common': 1}
# 796|15129 NP_001263272.2 {'Singleton': 39, 'Ultra-rare': 27, 'Common': 12, 'Rare': 12}
# 797|15129 NP_005821.2 {'Singleton': 35, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 800|15129 NP_002603.1 {'Singleton': 27, 'Ultra-rare': 10, 'Rare': 2, 'Common': 1}
# 805|15129 NP_001229738.1 {'Singleton': 64, 'Ultra-rare': 48, 'Common': 4, 'Rare': 4}
# 806|15129 NP_001012302.2 {'Singleton': 55, 'Ultra-rare': 38, 'Rare': 4, 'Common': 3}
# 807|15129 NP_001129685.1 {'Singleton': 31, 'Ultra-rare': 25, 'Common': 9, 'Rare': 8}
# 808|15129 NP_008920.5 {'Ultra-rare': 20, 'Singleton': 19, 'Rare': 7, 'Common': 6}
# 809|15129 NP_878315.2 {'Singleton': 52, 'Ultra-rare': 19, 'Rare': 2, 'Common': 2}
# 810|15129 NP_055247.4 {'Singleton': 34, 'Ultra-rare': 24, 'Rare': 3, 'Common': 1}
# 811|15129 NP_001004706.1 {'Singleton': 17, 'Ultra-rare': 13, 'Rare': 1, 'Common': 1}
# 812|15129 NP_001157101.1 {'Singleton': 53, 'Ultra-rare': 40, 'Rare': 7, 'Common': 3}
# 816|15129 NP_001073375.1 {'Singleton': 30, 'Ultra-rare': 13, 'Rare': 1, 'Common': 1}
# 817|15129 NP_998764.1 {'Singleton': 67, 'Ultra-rare': 44, 'Rare': 4, 'Common': 1}
# 819|15129 NP_056949.4 {'Singleton': 30, 'Ultra-rare': 21, 'Common': 3, 'Rare': 2}
# 822|15129 NP_001245335.1 {'Singleton': 40, 'Ultra-rare': 15, 'Rare': 4, 'Common': 1}
# 824|15129 NP_075055.1 {'Ultra-rare': 58, 'Singleton': 57, 'Rare': 8, 'Common': 2}
# 825|15129 NP_112178.2 {'Singleton': 38, 'Ultra-rare': 25, 'Rare': 3, 'Common': 1}
# 829|15129 NP_001170990.1 {'Ultra-rare': 25, 'Singleton': 21, 'Common': 14, 'Rare': 3}
# 831|15129 NP_068591.2 {'Singleton': 36, 'Ultra-rare': 22, 'Rare': 3, 'Common': 2}
# 832|15129 NP_068593.2 {'Singleton': 22, 'Ultra-rare': 15, 'Rare': 1, 'Common': 1}
# 833|15129 NP_055118.1 {'Singleton': 38, 'Ultra-rare': 34, 'Common': 2, 'Rare': 1}
# 835|15129 NP_001123481.3 {'Singleton': 50, 'Ultra-rare': 33, 'Rare': 7, 'Common': 5}
# 837|15129 NP_714928.1 {'Singleton': 88, 'Ultra-rare': 62, 'Rare': 9, 'Common': 5}
# 843|15129 NP_612373.2 {'Ultra-rare': 48, 'Singleton': 46, 'Rare': 3, 'Common': 1}
# 847|15129 NP_997257.2 {'Singleton': 24, 'Ultra-rare': 12, 'Rare': 4, 'Common': 1}
# 848|15129 NP_001032902.1 {'Singleton': 47, 'Ultra-rare': 29, 'Rare': 4, 'Common': 2}
# 851|15129 NP_001138594.1 {'Singleton': 47, 'Ultra-rare': 46, 'Common': 7, 'Rare': 4}
# 852|15129 NP_112584.3 {'Singleton': 62, 'Ultra-rare': 39, 'Rare': 6, 'Common': 1}
# 854|15129 NP_003669.4 {'Singleton': 36, 'Ultra-rare': 25, 'Common': 2, 'Rare': 2}
# 856|15129 NP_149094.3 {'Singleton': 62, 'Ultra-rare': 37, 'Rare': 8, 'Common': 5}
# 857|15129 NP_085118.2 {'Singleton': 36, 'Ultra-rare': 34, 'Rare': 5, 'Common': 2}
# 859|15129 NP_001005239.2 {'Singleton': 28, 'Ultra-rare': 16, 'Rare': 9, 'Common': 6}
# 860|15129 NP_005556.1 {'Singleton': 36, 'Ultra-rare': 19, 'Rare': 4, 'Common': 2}
# 861|15129 NP_006489.1 {'Singleton': 14, 'Ultra-rare': 12, 'Rare': 2, 'Common': 1}
# 863|15129 NP_689786.2 {'Singleton': 53, 'Ultra-rare': 27, 'Rare': 5, 'Common': 2}
# 867|15129 NP_085153.1 {'Singleton': 24, 'Ultra-rare': 16, 'Rare': 1, 'Common': 1}
# 873|15129 NP_000086.2 {'Singleton': 48, 'Ultra-rare': 20, 'Common': 3, 'Rare': 1}
# 875|15129 NP_003990.1 {'Singleton': 74, 'Ultra-rare': 52, 'Rare': 6, 'Common': 4}
# 876|15129 NP_002178.2 {'Singleton': 23, 'Ultra-rare': 16, 'Rare': 2, 'Common': 1}
# 878|15129 NP_998812.1 {'Singleton': 75, 'Ultra-rare': 62, 'Common': 3, 'Rare': 1}
# 881|15129 NP_001004744.1 {'Singleton': 26, 'Ultra-rare': 18, 'Common': 6, 'Rare': 1}
# 883|15129 NP_001328.1 {'Singleton': 23, 'Ultra-rare': 16, 'Rare': 3, 'Common': 3}
# 884|15129 NP_005996.2 {'Singleton': 102, 'Ultra-rare': 94, 'Rare': 8, 'Common': 2}
# 885|15129 NP_065904.1 {'Singleton': 39, 'Ultra-rare': 31, 'Rare': 2, 'Common': 1}
# 886|15129 NP_982248.1 {'Singleton': 13, 'Ultra-rare': 11, 'Common': 2, 'Rare': 1}
# 887|15129 NP_937895.1 {'Singleton': 64, 'Ultra-rare': 41, 'Rare': 6, 'Common': 3}
# 888|15129 NP_037480.1 {'Singleton': 40, 'Ultra-rare': 29, 'Rare': 2, 'Common': 1}
# 889|15129 NP_065825.1 {'Singleton': 56, 'Ultra-rare': 16, 'Rare': 1, 'Common': 1}
# 891|15129 NP_644814.1 {'Ultra-rare': 63, 'Singleton': 57, 'Common': 5, 'Rare': 4}
# 896|15129 NP_982261.2 {'Singleton': 57, 'Ultra-rare': 34, 'Rare': 5, 'Common': 1}
# 900|15129 NP_689810.3 {'Singleton': 55, 'Ultra-rare': 35, 'Rare': 3, 'Common': 3}
# 901|15129 NP_055503.1 {'Singleton': 61, 'Ultra-rare': 33, 'Rare': 2, 'Common': 1}
# 905|15129 NP_570124.1 {'Singleton': 26, 'Ultra-rare': 25, 'Rare': 1, 'Common': 1}
# 906|15129 NP_001103279.2 {'Singleton': 23, 'Ultra-rare': 16, 'Rare': 7, 'Common': 2}
# 911|15129 NP_000526.2 {'Singleton': 77, 'Ultra-rare': 48, 'Common': 6, 'Rare': 5}
# 917|15129 NP_000186.2 {'Singleton': 54, 'Ultra-rare': 44, 'Rare': 4, 'Common': 2}
# 918|15129 NP_848511.1 {'Singleton': 64, 'Ultra-rare': 40, 'Rare': 6, 'Common': 2}
# 921|15129 NP_001755.1 {'Singleton': 34, 'Ultra-rare': 16, 'Common': 2, 'Rare': 1}
# 923|15129 NP_001073270.1 {'Singleton': 29, 'Ultra-rare': 18, 'Common': 4, 'Rare': 1}
# 925|15129 NP_001004714.1 {'Singleton': 26, 'Ultra-rare': 17, 'Rare': 1, 'Common': 1}
# 926|15129 NP_001257552.1 {'Ultra-rare': 35, 'Singleton': 34, 'Rare': 2, 'Common': 1}
# 930|15129 NP_998770.2 {'Singleton': 39, 'Ultra-rare': 27, 'Rare': 2, 'Common': 1}
# 932|15129 NP_001177986.1 {'Singleton': 54, 'Ultra-rare': 38, 'Rare': 3, 'Common': 1}
# 933|15129 NP_113664.1 {'Singleton': 39, 'Ultra-rare': 34, 'Common': 3, 'Rare': 2}
# 935|15129 NP_689625.2 {'Singleton': 40, 'Ultra-rare': 20, 'Rare': 2, 'Common': 2}
# 936|15129 NP_001093320.2 {'Singleton': 35, 'Ultra-rare': 24, 'Common': 5, 'Rare': 4}
# 939|15129 NP_005451.2 {'Singleton': 63, 'Ultra-rare': 42, 'Rare': 1, 'Common': 1}
# 940|15129 NP_079519.1 {'Singleton': 48, 'Ultra-rare': 21, 'Rare': 3, 'Common': 1}
# 943|15129 NP_817089.1 {'Singleton': 62, 'Ultra-rare': 56, 'Rare': 3, 'Common': 3}
# 947|15129 NP_001192.4 {'Singleton': 33, 'Ultra-rare': 26, 'Common': 2, 'Rare': 1}
# 948|15129 NP_001243788.1 {'Rare': 17, 'Ultra-rare': 11, 'Singleton': 10, 'Common': 6}
# 949|15129 NP_001001956.1 {'Singleton': 25, 'Ultra-rare': 22, 'Rare': 3, 'Common': 2}
# 951|15129 NP_060405.5 {'Singleton': 51, 'Ultra-rare': 50, 'Common': 4, 'Rare': 1}
# 952|15129 NP_694962.1 {'Singleton': 39, 'Ultra-rare': 23, 'Rare': 4, 'Common': 3}
# 953|15129 NP_001164212.1 {'Singleton': 26, 'Ultra-rare': 20, 'Rare': 9, 'Common': 5}
# 1162|15129 NP_919262.2 {'Singleton': 58, 'Ultra-rare': 29, 'Rare': 4, 'Common': 1}
# 1163|15129 NP_055670.1 {'Ultra-rare': 89, 'Singleton': 88, 'Rare': 5, 'Common': 3}
# 1165|15129 NP_003492.2 {'Singleton': 54, 'Ultra-rare': 45, 'Rare': 5, 'Common': 1}
# 1168|15129 NP_005373.2 {'Singleton': 57, 'Ultra-rare': 35, 'Rare': 3, 'Common': 1}
# 1171|15129 NP_001357452.1 {'Singleton': 16, 'Ultra-rare': 14, 'Common': 7, 'Rare': 3}
# 1176|15129 NP_001381512.1 {'Singleton': 57, 'Ultra-rare': 41, 'Common': 3, 'Rare': 3}
# 1177|15129 NP_003313.3 {'Singleton': 39, 'Ultra-rare': 28, 'Common': 2, 'Rare': 1}
# 1179|15129 NP_001010912.1 {'Singleton': 26, 'Ultra-rare': 23, 'Rare': 3, 'Common': 1}
# ...
# 13621|15129 NP_064440.1 {'Common': 25, 'Ultra-rare': 22, 'Singleton': 21, 'Rare': 7}
# 13629|15129 NP_001280220.1 {'Singleton': 27, 'Ultra-rare': 24, 'Common': 5, 'Rare': 2}
# 13647|15129 NP_036501.2 {'Ultra-rare': 26, 'Singleton': 14, 'Rare': 3, 'Common': 2}
# 13649|15129 NP_848515.1 {'Singleton': 17, 'Ultra-rare': 7, 'Common': 2, 'Rare': 1}
# 13662|15129 NP_001306146.1 {'Singleton': 45, 'Ultra-rare': 34, 'Rare': 6, 'Common': 1}
# 13664|15129 NP_060950.3 {'Singleton': 14, 'Ultra-rare': 10, 'Rare': 1, 'Common': 1}
# 13670|15129 NP_853641.1 {'Ultra-rare': 8, 'Singleton': 8, 'Rare': 1, 'Common': 1}
# 13673|15129 NP_004068.2 {'Singleton': 10, 'Ultra-rare': 6, 'Common': 2, 'Rare': 1}
# 13674|15129 NP_002981.2 {'Ultra-rare': 8, 'Singleton': 7, 'Rare': 2, 'Common': 1}
# 13676|15129 NP_995318.1 {'Singleton': 12, 'Ultra-rare': 8, 'Rare': 1, 'Common': 1}
# 13677|15129 NP_002110.1 {'Singleton': 28, 'Ultra-rare': 7, 'Rare': 3, 'Common': 2}
# 13678|15129 NP_064552.3 {'Singleton': 32, 'Ultra-rare': 21, 'Rare': 3, 'Common': 3}
# 13679|15129 NP_115989.1 {'Singleton': 19, 'Ultra-rare': 12, 'Rare': 2, 'Common': 1}
# 13682|15129 NP_001316999.1 {'Singleton': 19, 'Ultra-rare': 17, 'Common': 3, 'Rare': 1}
# 13683|15129 NP_056469.2 {'Singleton': 15, 'Ultra-rare': 10, 'Rare': 3, 'Common': 1}
# 13687|15129 NP_001005187.1 {'Singleton': 31, 'Ultra-rare': 22, 'Common': 4, 'Rare': 2}
# 13688|15129 NP_115968.1 {'Ultra-rare': 11, 'Singleton': 8, 'Rare': 1, 'Common': 1}
# 13689|15129 NP_775490.2 {'Singleton': 48, 'Ultra-rare': 38, 'Rare': 6, 'Common': 1}
# 13695|15129 NP_000162.2 {'Singleton': 26, 'Ultra-rare': 16, 'Rare': 1, 'Common': 1}
# 13696|15129 NP_942094.3 {'Ultra-rare': 15, 'Singleton': 11, 'Rare': 2, 'Common': 1}
# 13701|15129 NP_004636.1 {'Singleton': 35, 'Ultra-rare': 34, 'Rare': 1, 'Common': 1}
# 13706|15129 NP_065104.1 {'Singleton': 19, 'Ultra-rare': 14, 'Rare': 2, 'Common': 1}
# 13717|15129 NP_003692.1 {'Singleton': 16, 'Ultra-rare': 12, 'Rare': 2, 'Common': 1}
# 13723|15129 NP_116037.2 {'Singleton': 16, 'Ultra-rare': 5, 'Rare': 1, 'Common': 1}
# 13726|15129 NP_000191.1 {'Singleton': 6, 'Ultra-rare': 4, 'Rare': 2, 'Common': 1}
# 13728|15129 NP_065851.1 {'Singleton': 51, 'Ultra-rare': 30, 'Rare': 1, 'Common': 1}
# 13729|15129 NP_001139124.2 {'Singleton': 25, 'Ultra-rare': 16, 'Rare': 4, 'Common': 3}
# 13732|15129 NP_000938.2 {'Ultra-rare': 16, 'Singleton': 14, 'Common': 4, 'Rare': 2}
# 13737|15129 NP_056347.1 {'Singleton': 31, 'Ultra-rare': 21, 'Rare': 4, 'Common': 1}
# 13741|15129 NP_001278870.1 {'Singleton': 7, 'Ultra-rare': 3, 'Common': 2, 'Rare': 1}
# 13742|15129 NP_001034585.1 {'Ultra-rare': 5, 'Singleton': 5, 'Common': 2, 'Rare': 1}
# 13753|15129 NP_795713.2 {'Ultra-rare': 23, 'Singleton': 18, 'Rare': 1, 'Common': 1}
# 13755|15129 NP_000733.2 {'Singleton': 47, 'Ultra-rare': 26, 'Rare': 2, 'Common': 1}
# 13758|15129 NP_444509.2 {'Singleton': 19, 'Ultra-rare': 13, 'Common': 2, 'Rare': 1}
# 13760|15129 NP_002681.1 {'Singleton': 15, 'Ultra-rare': 11, 'Rare': 1, 'Common': 1}
# 13764|15129 NP_060687.2 {'Singleton': 36, 'Ultra-rare': 34, 'Rare': 13, 'Common': 1}
# 13774|15129 NP_758961.1 {'Singleton': 39, 'Ultra-rare': 29, 'Common': 3, 'Rare': 2}
# 13781|15129 NP_001019380.2 {'Singleton': 13, 'Ultra-rare': 2, 'Rare': 2, 'Common': 1}
# 13786|15129 NP_002977.1 {'Ultra-rare': 9, 'Singleton': 5, 'Rare': 1, 'Common': 1}
# 13793|15129 NP_000487.1 {'Singleton': 20, 'Ultra-rare': 14, 'Rare': 1, 'Common': 1}
# 13797|15129 NP_001342150.1 {'Singleton': 15, 'Ultra-rare': 11, 'Common': 4, 'Rare': 1}
# 13800|15129 NP_000572.2 {'Singleton': 17, 'Ultra-rare': 8, 'Rare': 1, 'Common': 1}
# 13803|15129 NP_001096062.1 {'Singleton': 26, 'Ultra-rare': 22, 'Rare': 2, 'Common': 1}
# 13811|15129 NP_937770.1 {'Singleton': 35, 'Ultra-rare': 29, 'Common': 3, 'Rare': 2}
# 13814|15129 NP_079081.2 {'Singleton': 24, 'Ultra-rare': 17, 'Rare': 3, 'Common': 2}
# 13818|15129 NP_001254652.1 {'Singleton': 33, 'Ultra-rare': 29, 'Rare': 2, 'Common': 1}
# 13822|15129 NP_064554.3 {'Ultra-rare': 14, 'Singleton': 11, 'Rare': 5, 'Common': 1}
# 13823|15129 NP_775184.1 {'Singleton': 10, 'Ultra-rare': 9, 'Common': 2, 'Rare': 1}
# 13824|15129 NP_001005241.2 {'Ultra-rare': 31, 'Singleton': 31, 'Rare': 6, 'Common': 6}
# 13825|15129 NP_001093890.1 {'Singleton': 22, 'Ultra-rare': 14, 'Rare': 1, 'Common': 1}
# 13832|15129 NP_002113.2 {'Common': 32, 'Singleton': 15, 'Ultra-rare': 7, 'Rare': 5}
# 13834|15129 NP_001001433.1 {'Singleton': 25, 'Ultra-rare': 19, 'Rare': 2, 'Common': 1}
# 13838|15129 NP_005544.4 {'Singleton': 10, 'Ultra-rare': 10, 'Rare': 7, 'Common': 2}
# 13847|15129 NP_001011655.1 {'Singleton': 35, 'Ultra-rare': 34, 'Common': 2, 'Rare': 1}
# 13856|15129 NP_006205.1 {'Singleton': 23, 'Ultra-rare': 14, 'Rare': 2, 'Common': 1}
# 13860|15129 NP_872415.1 {'Singleton': 35, 'Ultra-rare': 31, 'Rare': 3, 'Common': 1}
# 13861|15129 NP_001005853.1 {'Ultra-rare': 35, 'Singleton': 21, 'Rare': 5, 'Common': 3}
# 13863|15129 NP_908973.1 {'Singleton': 38, 'Ultra-rare': 21, 'Rare': 1, 'Common': 1}
# 13869|15129 NP_001001412.3 {'Singleton': 37, 'Ultra-rare': 36, 'Rare': 2, 'Common': 1}
# 13871|15129 NP_001923.2 {'Singleton': 42, 'Ultra-rare': 28, 'Rare': 2, 'Common': 1}
# 13874|15129 NP_036536.2 {'Singleton': 13, 'Ultra-rare': 10, 'Rare': 1, 'Common': 1}
# 13876|15129 NP_001003892.1 {'Ultra-rare': 23, 'Singleton': 20, 'Rare': 1, 'Common': 1}
# 13880|15129 NP_114167.2 {'Singleton': 16, 'Ultra-rare': 9, 'Rare': 5, 'Common': 2}
# 13888|15129 NP_055487.2 {'Singleton': 37, 'Ultra-rare': 23, 'Rare': 2, 'Common': 1}
# 13889|15129 NP_001227.1 {'Singleton': 20, 'Ultra-rare': 18, 'Rare': 2, 'Common': 1}
# 13890|15129 NP_056299.1 {'Singleton': 21, 'Ultra-rare': 8, 'Common': 1, 'Rare': 1}
# 13893|15129 NP_001092138.1 {'Singleton': 14, 'Ultra-rare': 12, 'Rare': 3, 'Common': 2}
# 13898|15129 NP_689717.2 {'Singleton': 11, 'Ultra-rare': 9, 'Rare': 2, 'Common': 1}
# 13904|15129 NP_001273130.1 {'Singleton': 19, 'Ultra-rare': 17, 'Rare': 1, 'Common': 1}
# 13910|15129 NP_004275.4 {'Ultra-rare': 61, 'Singleton': 53, 'Rare': 4, 'Common': 1}
# 13911|15129 NP_543021.1 {'Singleton': 14, 'Ultra-rare': 9, 'Rare': 3, 'Common': 1}
# 13913|15129 NP_001005198.2 {'Singleton': 30, 'Ultra-rare': 17, 'Rare': 5, 'Common': 1}
# 13915|15129 NP_065109.1 {'Singleton': 42, 'Ultra-rare': 22, 'Rare': 6, 'Common': 1}
# 13919|15129 NP_064530.1 {'Singleton': 28, 'Ultra-rare': 16, 'Rare': 2, 'Common': 1}
# 13929|15129 NP_001180461.1 {'Singleton': 8, 'Ultra-rare': 3, 'Rare': 2, 'Common': 1}
# 13936|15129 NP_937790.2 {'Singleton': 23, 'Ultra-rare': 17, 'Rare': 1, 'Common': 1}
# 13937|15129 NP_055762.3 {'Singleton': 35, 'Ultra-rare': 19, 'Common': 2, 'Rare': 1}
# 13948|15129 NP_060505.2 {'Ultra-rare': 21, 'Singleton': 19, 'Common': 3, 'Rare': 2}
# 13951|15129 NP_000441.2 {'Singleton': 37, 'Ultra-rare': 27, 'Rare': 3, 'Common': 2}
# 13955|15129 NP_004208.2 {'Singleton': 20, 'Ultra-rare': 20, 'Rare': 1, 'Common': 1}
# 13964|15129 NP_001001913.1 {'Singleton': 31, 'Ultra-rare': 25, 'Common': 5, 'Rare': 1}
# 13966|15129 NP_000840.2 {'Singleton': 11, 'Ultra-rare': 10, 'Rare': 1, 'Common': 1}
# 13969|15129 NP_109587.1 {'Singleton': 36, 'Ultra-rare': 21, 'Common': 1, 'Rare': 1}
# 13972|15129 NP_116172.2 {'Singleton': 19, 'Ultra-rare': 9, 'Rare': 2, 'Common': 1}
# 13975|15129 NP_001306587.1 {'Singleton': 13, 'Ultra-rare': 9, 'Rare': 2, 'Common': 1}
# 13978|15129 NP_742150.1 {'Singleton': 21, 'Ultra-rare': 18, 'Rare': 4, 'Common': 2}
# 13985|15129 NP_001862.2 {'Singleton': 27, 'Ultra-rare': 20, 'Common': 2, 'Rare': 1}
# 13994|15129 NP_112145.1 {'Ultra-rare': 24, 'Singleton': 15, 'Rare': 6, 'Common': 1}
# 14002|15129 NP_001099043.1 {'Singleton': 8, 'Ultra-rare': 2, 'Common': 1, 'Rare': 1}
# 14004|15129 NP_001269421.1 {'Singleton': 9, 'Ultra-rare': 9, 'Rare': 2, 'Common': 1}
# 14007|15129 NP_001005516.1 {'Singleton': 32, 'Ultra-rare': 12, 'Rare': 3, 'Common': 2}
# 14008|15129 NP_001038941.1 {'Singleton': 18, 'Ultra-rare': 12, 'Rare': 5, 'Common': 1}
# 14009|15129 NP_002112.3 {'Singleton': 8, 'Ultra-rare': 4, 'Rare': 3, 'Common': 2}
# 14017|15129 NP_001001961.2 {'Singleton': 26, 'Ultra-rare': 22, 'Rare': 3, 'Common': 2}
# 14023|15129 NP_001130033.3 {'Common': 27, 'Singleton': 18, 'Ultra-rare': 16, 'Rare': 3}
# 14033|15129 NP_005743.5 {'Singleton': 21, 'Ultra-rare': 15, 'Rare': 1, 'Common': 1}
# 14035|15129 NP_057299.1 {'Ultra-rare': 33, 'Singleton': 30, 'Rare': 1, 'Common': 1}
# 14038|15129 NP_057222.2 {'Singleton': 22, 'Ultra-rare': 15, 'Rare': 2, 'Common': 1}
# 14039|15129 NP_872338.1 {'Singleton': 17, 'Ultra-rare': 15, 'Rare': 1, 'Common': 1}
# 14048|15129 NP_004842.1 {'Singleton': 35, 'Ultra-rare': 25, 'Rare': 3, 'Common': 2}
# 14052|15129 NP_001004474.2 {'Singleton': 25, 'Ultra-rare': 17, 'Common': 3, 'Rare': 2}
# 14055|15129 NP_001010904.1 {'Singleton': 27, 'Ultra-rare': 13, 'Common': 3, 'Rare': 2}
# 14056|15129 NP_001004697.1 {'Common': 10, 'Singleton': 9, 'Ultra-rare': 5, 'Rare': 3}
# 14057|15129 NP_001005192.2 {'Singleton': 31, 'Ultra-rare': 13, 'Common': 4, 'Rare': 2}
# 14058|15129 NP_659399.2 {'Singleton': 21, 'Ultra-rare': 16, 'Rare': 2, 'Common': 2}
# 14060|15129 NP_001034881.1 {'Singleton': 13, 'Ultra-rare': 12, 'Rare': 1, 'Common': 1}
# 14061|15129 NP_060846.2 {'Singleton': 21, 'Ultra-rare': 14, 'Common': 3, 'Rare': 1}
# 14070|15129 NP_006836.2 {'Singleton': 53, 'Ultra-rare': 29, 'Rare': 1, 'Common': 1}
# 14079|15129 NP_958815.1 {'Singleton': 26, 'Ultra-rare': 19, 'Rare': 1, 'Common': 1}
# 14087|15129 NP_001073972.2 {'Ultra-rare': 11, 'Singleton': 9, 'Rare': 1, 'Common': 1}
# 14089|15129 NP_001371640.1 {'Singleton': 21, 'Ultra-rare': 15, 'Rare': 2, 'Common': 2}
# 14093|15129 NP_620409.1 {'Singleton': 42, 'Ultra-rare': 41, 'Rare': 3, 'Common': 1}
# 14094|15129 NP_001159.2 {'Singleton': 9, 'Ultra-rare': 2, 'Rare': 1, 'Common': 1}
# 14095|15129 NP_000684.2 {'Singleton': 27, 'Ultra-rare': 15, 'Common': 1, 'Rare': 1}
# 14096|15129 NP_001900.1 {'Singleton': 34, 'Ultra-rare': 18, 'Rare': 1, 'Common': 1}
# 14100|15129 NP_077300.3 {'Ultra-rare': 22, 'Singleton': 19, 'Common': 3, 'Rare': 1}
# 14109|15129 NP_079353.3 {'Ultra-rare': 16, 'Singleton': 11, 'Rare': 1, 'Common': 1}
# 14111|15129 NP_001140158.1 {'Singleton': 28, 'Ultra-rare': 21, 'Common': 2, 'Rare': 1}
# 14114|15129 NP_001012772.1 {'Singleton': 13, 'Ultra-rare': 8, 'Rare': 1, 'Common': 1}
# 14116|15129 NP_001005281.1 {'Singleton': 25, 'Ultra-rare': 18, 'Common': 2, 'Rare': 1}
# 14126|15129 NP_002954.2 {'Ultra-rare': 10, 'Singleton': 9, 'Rare': 1, 'Common': 1}
# 14129|15129 NP_004379.1 {'Singleton': 26, 'Ultra-rare': 23, 'Rare': 4, 'Common': 2}
# 14130|15129 NP_004474.2 {'Singleton': 11, 'Ultra-rare': 2, 'Rare': 2, 'Common': 1}
# 14135|15129 NP_000301.1 {'Singleton': 22, 'Ultra-rare': 15, 'Rare': 2, 'Common': 1}
# 14137|15129 NP_066269.1 {'Ultra-rare': 16, 'Singleton': 14, 'Rare': 1, 'Common': 1}
# 14151|15129 NP_000362.1 {'Singleton': 11, 'Ultra-rare': 11, 'Rare': 1, 'Common': 1}
# 14153|15129 NP_061026.2 {'Singleton': 30, 'Ultra-rare': 24, 'Rare': 3, 'Common': 2}
# 14158|15129 NP_001179.1 {'Singleton': 14, 'Ultra-rare': 12, 'Common': 1, 'Rare': 1}
# 14167|15129 NP_940947.3 {'Singleton': 26, 'Ultra-rare': 21, 'Rare': 6, 'Common': 1}
# 14169|15129 NP_062828.3 {'Singleton': 16, 'Ultra-rare': 7, 'Common': 2, 'Rare': 1}
# 14181|15129 NP_006805.2 {'Ultra-rare': 26, 'Singleton': 18, 'Rare': 2, 'Common': 2}
# 14188|15129 NP_653277.2 {'Singleton': 26, 'Ultra-rare': 12, 'Rare': 1, 'Common': 1}
# 14189|15129 NP_002629.1 {'Singleton': 13, 'Ultra-rare': 6, 'Common': 3, 'Rare': 2}
# 14190|15129 NP_002539.2 {'Singleton': 23, 'Ultra-rare': 19, 'Rare': 2, 'Common': 1}
# 14193|15129 NP_002804.2 {'Singleton': 17, 'Ultra-rare': 11, 'Rare': 2, 'Common': 2}
# 14201|15129 NP_110381.2 {'Ultra-rare': 9, 'Singleton': 6, 'Rare': 2, 'Common': 2}
# 14204|15129 NP_000885.1 {'Singleton': 20, 'Ultra-rare': 14, 'Rare': 3, 'Common': 2}
# 14212|15129 NP_714542.1 {'Singleton': 14, 'Ultra-rare': 12, 'Rare': 1, 'Common': 1}
# 14227|15129 NP_001138427.1 {'Singleton': 21, 'Ultra-rare': 10, 'Rare': 4, 'Common': 1}
# 14250|15129 NP_659547.2 {'Singleton': 22, 'Ultra-rare': 9, 'Rare': 1, 'Common': 1}
# 14253|15129 NP_079374.2 {'Singleton': 30, 'Ultra-rare': 25, 'Rare': 5, 'Common': 1}
# 14254|15129 NP_057416.1 {'Ultra-rare': 12, 'Singleton': 10, 'Rare': 2, 'Common': 1}
# 14256|15129 NP_060908.1 {'Ultra-rare': 21, 'Singleton': 18, 'Rare': 2, 'Common': 1}
# 14259|15129 NP_004660.2 {'Singleton': 13, 'Ultra-rare': 11, 'Common': 1, 'Rare': 1}
# 14260|15129 NP_060220.3 {'Ultra-rare': 48, 'Singleton': 34, 'Rare': 5, 'Common': 5}
# 14270|15129 NP_057000.2 {'Singleton': 37, 'Ultra-rare': 21, 'Rare': 1, 'Common': 1}
# 14273|15129 NP_001265558.1 {'Singleton': 38, 'Ultra-rare': 20, 'Common': 4, 'Rare': 2}
# 14275|15129 NP_001004694.2 {'Common': 16, 'Singleton': 8, 'Rare': 8, 'Ultra-rare': 4}
# 14276|15129 NP_057446.1 {'Singleton': 8, 'Ultra-rare': 7, 'Common': 2, 'Rare': 1}
# 14287|15129 NP_758955.2 {'Singleton': 22, 'Ultra-rare': 13, 'Common': 4, 'Rare': 1}
# 14300|15129 NP_848521.1 {'Ultra-rare': 5, 'Singleton': 3, 'Rare': 2, 'Common': 1}
# 14304|15129 NP_055397.1 {'Singleton': 17, 'Ultra-rare': 15, 'Common': 9, 'Rare': 1}
# 14305|15129 NP_006101.1 {'Singleton': 32, 'Ultra-rare': 20, 'Common': 2, 'Rare': 1}
# 14314|15129 NP_003559.2 {'Singleton': 25, 'Ultra-rare': 21, 'Rare': 3, 'Common': 1}
# 14338|15129 NP_078902.2 {'Singleton': 23, 'Ultra-rare': 12, 'Rare': 2, 'Common': 1}
# 14339|15129 NP_075069.3 {'Singleton': 33, 'Ultra-rare': 19, 'Common': 2, 'Rare': 1}
# 14341|15129 NP_689610.2 {'Singleton': 24, 'Ultra-rare': 15, 'Common': 2, 'Rare': 1}
# 14360|15129 NP_001158160.1 {'Singleton': 16, 'Ultra-rare': 13, 'Common': 2, 'Rare': 1}
# 14366|15129 NP_116186.1 {'Ultra-rare': 31, 'Singleton': 25, 'Rare': 2, 'Common': 2}
# 14371|15129 NP_031384.1 {'Singleton': 28, 'Ultra-rare': 16, 'Rare': 2, 'Common': 1}
# 14375|15129 NP_061907.2 {'Singleton': 11, 'Ultra-rare': 10, 'Common': 1, 'Rare': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 5
#       3 n_unique_prots = result_df['prot_acc_version'].unique().shape[0]
#       4 for i, prot_acc_version in enumerate(result_df['prot_acc_version'].unique()):
# ----> 5     x = result_df[result_df['prot_acc_version']==prot_acc_version]
#       6     class_dict = x["class"].value_counts().to_dict()
#       7     if len(class_dict)==4:
#
# File /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/pandas/core/arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /projects/ashehu/akabir4/venvs/hopper_variant_effect_analysis_mine/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# KeyboardInterrupt:
