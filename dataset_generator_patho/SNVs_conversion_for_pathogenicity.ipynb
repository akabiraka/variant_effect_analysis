# %%
import os
import sys
home_dir = "../"
module_path = os.path.abspath(os.path.join(home_dir))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import fileinput
from utils.ncbi_proteins import download_protein_list_mpi, download_protein_list, create_combined_fasta
from Bio import SeqIO

from Bio.PDB.Polypeptide import protein_letters_3to1 # 20 amino acids

# %%
def three_to_one(aa):
    if str.upper(aa) in protein_letters_3to1:
        return protein_letters_3to1[str.upper(aa)]
    return "unknown"

def get_variants_df(inp_filepath:str, pathogenicity_type=None) -> pd.DataFrame:   
    df = pd.read_csv(inp_filepath, sep="\t")
    # print(df.shape)
    # print(df.columns)
    # print(df.head())

    # pathogenicity_type: pathogenic, likely_pathogenic   
    # columns = ["Symbol", "GeneID", "GRCh38Chromosome", "GRCh38Location", "Canonical SPDI", "protein_accession.version", "Protein change"]

    variations = []
    for row_i in range(df.shape[0]):
        # print(df.loc[row_i])
        
        try:
            clinical_sig = df.loc[row_i, "Clinical significance (Last reviewed)"]
            if "Likely pathogenic" in clinical_sig:
                pathogenicity_type = "Likely-pathogenic"
            else: pathogenicity_type = "Pathogenic"
            
            # Case: bad->NM_032756.4(HPDL):c.[832G>A;91T>C], no protein variants, good->NM_000478.6(ALPL):c.1276G>A (p.Gly426Ser)
            x = df.loc[row_i, "Name"].split() # 
            if len(x)!=2: continue 
            
            prot_variant = x[1]
            try:
                prot_pos = int(prot_variant[6:-4]) # case: NM_003001.5(SDHC):c.452_455delinsATGA (p.Ser151_Gly152delinsTyrGlu)
            except:
                continue
            
            wt, mut = prot_variant[3:6], prot_variant[-4:-1]
            wt, mut = three_to_one(wt), three_to_one(mut)
            if wt=="unknown" or mut=="unknown": continue # not considering unknown protein variants

            x = df.loc[row_i, "Canonical SPDI"] 
            x = x.split("|")[0] # Case: NC_000023.11:154532268:C:A|NC_000023.11:154532045:A:C. Take the 1st.
            chrom_acc_version, _, ref_allele, alt_allele = x.split(":") # ie: NC_000023.11:154532268:C:A # chr-pos in Canonical SPDI is 0-indexed
            if len(ref_allele)>1 or len(alt_allele)>1: continue # only considering single neucleodite variants
            
            chrom_pos = int(df.loc[row_i, "GRCh38Location"]) #1-indexed
            
            
            
            new_v = {"clinvar_id": df.loc[row_i, "VariationID"], 
                    "gene_symbol": df.loc[row_i, "Symbol"],
                    "gene_id": df.loc[row_i, "GeneID"], 
                    "snp_id": df.loc[row_i, "dbSNP ID"],
                    
                    "chrom_acc_version": chrom_acc_version,
                    "chrom_pos": chrom_pos, # 1-indexed
                    "ref_allele": ref_allele,
                    "alt_allele": alt_allele,
                    
                    "prot_acc_version": df.loc[row_i, "protein_accession.version"],
                    "prot_pos": prot_pos, # NCBI prot variants are 1-indexed
                    "wt": wt, # 1-letter amino acid
                    "mut": mut,
                    "class": pathogenicity_type
                }
        
            variations.append(new_v) 
        except:
            print("Error occured: ")
            print(row_i, df.loc[row_i])
            raise
        
        # if row_i==10: break
    variations_df = pd.DataFrame(variations)
    return variations_df

# %%
# getting pathogenic data
inp_filepath = home_dir+"data/clinvar/filtered/clinvar_HumanPathogenicMissenseVariants01012022To14022023.txt"
patho_variations_df = get_variants_df(inp_filepath, pathogenicity_type="pathogenic")
print(patho_variations_df.shape)
# Out:
# (3802, 13)

# %%
# getting likely-pathogenic data
inp_filepath = home_dir+"data/clinvar/filtered/clinvar_HumanLikelyPathogenicMissenseVariants01012022To14022023.txt"
likelypatho_variations_df = get_variants_df(inp_filepath, pathogenicity_type="likely_pathogenic")
print(likelypatho_variations_df.shape)
# Out:
# (6703, 13)

# %%
# merging and clearning patho-&-likelypatho data
variations_df = pd.concat([patho_variations_df, likelypatho_variations_df], ignore_index=True)
variations_df.drop_duplicates(keep="first", inplace=True, ignore_index=True)
variations_df["class"].value_counts()
# Out:
# Likely-pathogenic    6668
# Pathogenic           3614
# Name: class, dtype: int64

# %%
# downloaing proteins
protein_acc_list = list(variations_df["prot_acc_version"].unique())
download_protein_list(protein_acc_list, start_i=0, home_dir=home_dir) # sequential downloading
# download_protein_list_mpi(protein_acc_list, len(protein_acc_list))
print("#-unique NCBI protein sequences downloaded: ", len(protein_acc_list))
# Out:
# 0 NP_001381642.1 Already existis
# 1 NP_542172.2 Already existis
# 2 NP_001164006.1 Already existis
# 3 NP_002065.1 Already existis
# 4 NP_000806.2 Already existis
# 5 NP_003027.1 Already existis
# 6 NP_002608.1 Already existis
# 7 NP_056030.1 Already existis
# 8 NP_009193.2 Already existis
# 9 NP_001036146.1 Already existis
# 10 NP_004276.2 Already existis
# 11 NP_005017.3 Already existis
# 12 NP_004949.1 Already existis
# 13 NP_005948.3 Already existis
# 14 NP_055689.1 Already existis
# 15 NP_009203.2 Already existis
# 16 NP_055816.2 Already existis
# 17 NP_000076.2 Already existis
# 18 NP_002991.2 Already existis
# 19 NP_000469.3 Already existis
# 20 NP_001782.1 Already existis
# 21 NP_005817.1 Already existis
# 22 NP_000138.2 Already existis
# 23 NP_065184.2 Already existis
# 24 NP_006006.3 Already existis
# 25 NP_060116.2 Already existis
# 26 NP_116182.2 Already existis
# 27 NP_000301.1 Already existis
# 28 NP_683763.2 Already existis
# 29 NP_006507.2 Already existis
# 30 NP_001352928.1 Already existis
# 31 NP_060620.2 Already existis
# 32 NP_000365.3 Already existis
# 33 NP_116145.1 Already existis
# 34 NP_060209.4 Already existis
# 35 NP_001041631.1 Already existis
# 36 NP_000089.1 Already existis
# 37 NP_000783.2 Already existis
# 38 NP_777596.2 Already existis
# 39 NP_002624.2 Already existis
# 40 NP_002218.2 Already existis
# 41 NP_000320.1 Already existis
# 42 NP_000007.1 Already existis
# 43 NP_891993.1 Already existis
# 44 NP_958357.1 Already existis
# 45 NP_001017975.5 Already existis
# 46 NP_000960.2 Already existis
# 47 NP_000341.2 Already existis
# 48 NP_036375.1 Already existis
# 49 NP_001909.4 Already existis
# 50 NP_057042.2 Already existis
# 51 NP_001845.3 Already existis
# 52 NP_006504.2 Already existis
# 53 NP_001010898.1 Already existis
# 54 NP_004965.1 Already existis
# 55 NP_073747.1 Already existis
# 56 NP_000692.2 Already existis
# 57 NP_000189.1 Already existis
# 58 NP_006614.2 Already existis
# 59 NP_077719.2 Already existis
# 60 NP_003837.1 Already existis
# 61 NP_005258.2 Already existis
# 62 NP_001382355.1 Already existis
# 63 NP_079426.2 Already existis
# 64 NP_061905.2 Already existis
# 65 NP_000387.1 Already existis
# 66 NP_067045.1 Already existis
# 67 NP_076946.1 Already existis
# 68 NP_055915.2 Already existis
# 69 NP_000739.1 Already existis
# 70 NP_000148.2 Already existis
# 71 NP_000289.1 Already existis
# 72 NP_008843.1 Already existis
# 73 NP_733821.1 Already existis
# 74 NP_658985.2 Already existis
# 75 NP_002520.2 Already existis
# 76 NP_000693.1 Already existis
# 77 NP_002848.1 Already existis
# 78 NP_001116236.1 Already existis
# 79 NP_000521.2 Already existis
# 80 NP_002992.1 Already existis
# 81 NP_002576.1 Already existis
# 82 NP_796372.1 Already existis
# 83 NP_061899.3 Already existis
# 84 NP_000252.1 Already existis
# 85 NP_060592.2 Already existis
# 86 NP_000479.1 Already existis
# 87 NP_003276.3 Already existis
# 88 NP_055440.1 Already existis
# 89 NP_001192222.1 Already existis
# 90 NP_000424.2 Already existis
# 91 NP_000177.2 Already existis
# 92 NP_001985.2 Already existis
# 93 NP_957705.1 Already existis
# 94 NP_000060.2 Already existis
# 95 NP_001263274.1 Already existis
# 96 NP_006609.3 Already existis
# 97 NP_057083.2 Already existis
# 98 NP_002247.3 Already existis
# 99 NP_000219.2 Already existis
# 100 NP_006138.1 Already existis
# 101 NP_758872.1 Already existis
# 102 NP_054772.1 Already existis
# 103 NP_996816.3 Already existis
# 104 NP_055991.1 Already existis
# 105 NP_002287.2 Already existis
# 106 NP_055513.2 Already existis
# 107 NP_002098.1 Already existis
# 108 NP_002212.3 Already existis
# 109 NP_001649.1 Already existis
# 110 NP_065168.2 Already existis
# 111 NP_001091.1 Already existis
# 112 NP_001026.2 Already existis
# 113 NP_000134.2 Already existis
# 114 NP_005456.1 Already existis
# 115 NP_932342.1 Already existis
# 116 NP_114032.2 Already existis
# 117 NP_001230062.1 Already existis
# 118 NP_001071178.2 Already existis
# 119 NP_003099.1 Already existis
# 120 NP_057291.1 Already existis
# 121 NP_056993.2 Already existis
# 122 NP_000375.3 Already existis
# 123 NP_072046.2 Already existis
# 124 NP_000174.1 Already existis
# 125 NP_006479.1 Already existis
# 126 NP_004332.2 Already existis
# 127 NP_000339.2 Already existis
# 128 NP_055761.2 Already existis
# 129 NP_001129123.1 Already existis
# 130 NP_000095.2 Already existis
# 131 NP_005624.2 Already existis
# 132 NP_008818.3 Already existis
# 133 NP_000332.2 Already existis
# 134 NP_001421.2 Already existis
# 135 NP_065191.2 Already existis
# 136 NP_001734.1 Already existis
# 137 NP_000242.1 Already existis
# 138 NP_000170.1 Already existis
# 139 NP_000224.2 Already existis
# 140 NP_149100.2 Already existis
# 141 NP_075044.2 Already existis
# 142 NP_003029.2 Already existis
# 143 NP_001124459.1 Already existis
# 144 NP_001606.1 Already existis
# 145 NP_550438.1 Already existis
# 146 NP_004073.2 Already existis
# 147 NP_003840.2 Already existis
# 148 NP_000812.2 Already existis
# 149 NP_000533.4 Already existis
# 150 NP_001358208.1 Already existis
# 151 NP_060319.1 Already existis
# 152 NP_054733.2 Already existis
# 153 NP_110432.1 Already existis
# 154 NP_064569.3 Already existis
# 155 NP_001289.1 Already existis
# 156 NP_006227.1 Already existis
# 157 NP_071731.1 Already existis
# 158 NP_004327.1 Already existis
# 159 NP_000303.1 Already existis
# 160 NP_525125.2 Already existis
# 161 NP_061027.2 Already existis
# 162 NP_003928.1 Already existis
# 163 NP_004513.1 Already existis
# 164 NP_006177.1 Already existis
# 165 NP_006584.1 Already existis
# 166 NP_071451.2 Already existis
# 167 NP_008853.3 Already existis
# 168 NP_001035232.1 Already existis
# 169 NP_004473.2 Already existis
# 170 NP_001159435.1 Already existis
# 171 NP_003733.2 Already existis
# 172 NP_689597.1 Already existis
# 173 NP_003696.2 Already existis
# 174 NP_003681.1 Already existis
# 175 NP_001036167.1 Already existis
# 176 NP_963842.1 Already existis
# 177 NP_000081.2 Already existis
# 178 NP_000384.2 Already existis
# 179 NP_009330.1 Already existis
# 180 NP_001165980.1 Already existis
# 181 NP_001161693.1 Already existis
# 182 NP_065970.2 Already existis
# 183 NP_001866.2 Already existis
# 184 NP_775099.2 Already existis
# 185 NP_997647.2 Already existis
# 186 NP_054859.2 Already existis
# 187 NP_005435.1 Already existis
# 188 NP_001073335.1 Already existis
# 189 NP_000775.1 Already existis
# 190 NP_079492.2 Already existis
# 191 NP_002172.2 Already existis
# 192 NP_001918.3 Already existis
# 193 NP_037467.2 Already existis
# 194 NP_852123.1 Already existis
# 195 NP_005678.3 Already existis
# 196 NP_000083.3 Already existis
# 197 NP_000082.2 Already existis
# 198 NP_849143.1 Already existis
# 199 NP_004817.2 Already existis
# 200 NP_000742.1 Already existis
# 201 NP_000454.1 Already existis
# 202 NP_004360.2 Already existis
# 203 NP_001365343.1 Already existis
# 204 NP_001230937.1 Already existis
# 205 NP_000021.1 Already existis
# 206 NP_036277.2 Already existis
# 207 NP_689996.4 Already existis
# 208 NP_001365381.1 Already existis
# 209 NP_001073986.1 Already existis
# 210 NP_001003694.1 Already existis
# 211 NP_000542.1 Already existis
# 212 NP_001001331.1 Already existis
# 213 NP_003033.3 Already existis
# 214 NP_001336161.1 Already existis
# 215 NP_001271330.1 Already existis
# 216 NP_619725.3 Already existis
# 217 NP_001357587.1 Already existis
# 218 NP_002962.1 Already existis
# 219 NP_001341641.1 Already existis
# 220 NP_000956.2 Already existis
# 221 NP_060767.2 Already existis
# 222 NP_003233.4 Already existis
# 223 NP_000395.3 Already existis
# 224 NP_006362.1 Already existis
# 225 NP_000240.1 Already existis
# 226 NP_000326.2 Already existis
# 227 NP_660149.2 Already existis
# 228 NP_116195.2 Already existis
# 229 NP_060545.3 Already existis
# 230 NP_003269.2 Already existis
# 231 NP_056155.1 Already existis
# 232 NP_054878.5 Already existis
# 233 NP_619520.1 Already existis
# 234 NP_000085.1 Already existis
# 235 NP_005042.1 Already existis
# 236 NP_000472.2 Already existis
# 237 NP_006832.1 Already existis
# 238 NP_056980.2 Already existis
# 239 NP_006021.2 Already existis
# 240 NP_056241.3 Already existis
# 241 NP_004647.1 Already existis
# 242 NP_003271.1 Already existis
# 243 NP_001448.2 Already existis
# 244 NP_001336267.1 Already existis
# 245 NP_060600.2 Already existis
# 246 NP_002932.1 Already existis
# 247 NP_000149.4 Already existis
# 248 NP_000304.2 Already existis
# 249 NP_001167621.1 Already existis
# 250 NP_001265222.1 Already existis
# 251 NP_006061.2 Already existis
# 252 NP_055230.2 Already existis
# 253 NP_001681.2 Already existis
# 254 NP_001335729.1 Already existis
# 255 NP_000178.2 Already existis
# 256 NP_000379.3 Already existis
# 257 NP_899200.1 Already existis
# 258 NP_115618.3 Already existis
# 259 NP_037468.1 Already existis
# 260 NP_054768.2 Already existis
# 261 NP_000165.1 Already existis
# 262 NP_000530.1 Already existis
# 263 NP_001365616.1 Already existis
# 264 NP_079094.1 Already existis
# 265 NP_000523.2 Already existis
# 266 NP_005853.2 Already existis
# 267 NP_004757.1 Already existis
# 268 NP_000676.1 Already existis
# 269 NP_777367.1 Already existis
# 270 NP_001258767.1 Already existis
# 271 NP_001032.2 Already existis
# 272 NP_001116224.1 Already existis
# 273 NP_004982.2 Already existis
# 274 NP_000331.1 Already existis
# 275 NP_078941.2 Already existis
# 276 NP_006209.2 Already existis
# 277 NP_003097.1 Already existis
# 278 NP_064551.3 Already existis
# 279 NP_003898.2 Already existis
# 280 NP_000451.1 Already existis
# 281 NP_004445.1 Already existis
# 282 NP_001613.2 Already existis
# 283 NP_003713.3 Already existis
# 284 NP_570850.2 Already existis
# 285 NP_001369202.1 Already existis
# 286 NP_940967.1 Already existis
# 287 NP_002568.2 Already existis
# 288 NP_001120650.1 Already existis
# 289 NP_000194.2 Already existis
# 290 NP_071325.2 Already existis
# 291 NP_000133.1 Already existis
# 292 NP_036450.1 Already existis
# 293 NP_775931.3 Already existis
# 294 NP_005996.2 Already existis
# 295 NP_001365544.1 Already existis
# 296 NP_000311.2 Already existis
# 297 NP_079408.3 Already existis
# 298 NP_003915.2 Already existis
# 299 NP_000798.2 Already existis
# 300 NP_000223.1 Already existis
# 301 NP_001072992.1 Already existis
# 302 NP_005603.3 Already existis
# 303 NP_001544.1 Already existis
# 304 NP_000397.1 Already existis
# 305 NP_055806.2 Already existis
# 306 NP_055023.2 Already existis
# 307 NP_004398.1 Already existis
# 308 NP_001194.1 Already existis
# 309 NP_000935.1 Already existis
# 310 NP_001128618.1 Already existis
# 311 NP_003989.2 Already existis
# 312 NP_000195.3 Already existis
# 313 NP_000316.2 Already existis
# 314 NP_001139.3 Already existis
# 315 NP_001308500.1 Already existis
# 316 NP_005024.2 Already existis
# 317 NP_001124170.1 Already existis
# 318 NP_660208.2 Already existis
# 319 NP_001278232.1 Already existis
# 320 NP_003592.3 Already existis
# 321 NP_758454.1 Already existis
# 322 NP_001336727.1 Already existis
# 323 NP_000815.1 Already existis
# 324 NP_001077088.2 Already existis
# 325 NP_004444.2 Already existis
# 326 NP_006736.1 Already existis
# 327 NP_005236.2 Already existis
# 328 NP_004468.1 Already existis
# 329 NP_004159.2 Already existis
# 330 NP_001003841.1 Already existis
# 331 NP_937983.2 Already existis
# 332 NP_004544.1 Already existis
# 333 NP_060225.4 Already existis
# 334 NP_001323.1 Already existis
# 335 NP_001360.1 Already existis
# 336 NP_009049.2 Already existis
# 337 NP_612357.4 Already existis
# 338 NP_006718.2 Already existis
# 339 NP_057264.4 Already existis
# 340 NP_002176.2 Already existis
# 341 NP_001007528.1 Already existis
# 342 NP_597677.2 Already existis
# 343 NP_001371661.1 Already existis
# 344 NP_001121143.1 Already existis
# 345 NP_066550.2 Already existis
# 346 NP_789776.1 Already existis
# 347 NP_002175.2 Already existis
# 348 NP_001098101.1 Already existis
# 349 NP_000335.1 Already existis
# 350 NP_071415.1 Already existis
# 351 NP_005900.2 Already existis
# 352 NP_000512.2 Already existis
# 353 NP_000037.2 Already existis
# 354 NP_002430.3 Already existis
# 355 NP_002388.2 Already existis
# 356 NP_005645.1 Already existis
# 357 NP_937793.1 Already existis
# 358 NP_000430.3 Already existis
# 359 NP_000029.2 Already existis
# 360 NP_067627.3 Already existis
# 361 NP_000405.1 Already existis
# 362 NP_001173.2 Already existis
# 363 NP_001990.2 Already existis
# 364 NP_001017372.1 Already existis
# 365 NP_005331.1 Already existis
# 366 NP_588613.3 Already existis
# 367 NP_003051.1 Already existis
# 368 NP_078991.3 Already existis
# 369 NP_000349.1 Already existis
# 370 NP_938023.1 Already existis
# 371 NP_005850.1 Already existis
# 372 NP_061751.1 Already existis
# 373 NP_000103.2 Already existis
# 374 NP_001275634.1 Already existis
# 375 NP_002600.1 Already existis
# 376 NP_057065.2 Already existis
# 377 NP_001534.1 Already existis
# 378 NP_000162.2 Already existis
# 379 NP_001358656.1 Already existis
# 380 NP_001121116.1 Already existis
# 381 NP_944494.1 Already existis
# 382 NP_002878.2 Already existis
# 383 NP_004378.1 Already existis
# 384 NP_071900.2 Already existis
# 385 NP_057306.2 Already existis
# 386 NP_000834.2 Already existis
# 387 NP_001244222.1 Already existis
# 388 NP_003891.1 Already existis
# 389 NP_001444.2 Already existis
# 390 NP_001060.1 Already existis
# 391 NP_821080.1 Already existis
# 392 NP_112210.1 Already existis
# 393 NP_005115.2 Already existis
# 394 NP_003098.1 Already existis
# 395 NP_001071.1 Already existis
# 396 NP_000401.1 Already existis
# 397 NP_003533.1 Already existis
# 398 NP_068803.1 Already existis
# 399 NP_001311.3 Already existis
# 400 NP_751898.1 Already existis
# 401 NP_000425.1 Already existis
# 402 NP_000491.4 Already existis
# 403 NP_002115.2 Already existis
# 404 NP_542411.2 Already existis
# 405 NP_008910.2 Already existis
# 406 NP_006763.2 Already existis
# 407 NP_002215.2 Already existis
# 408 NP_003313.3 Already existis
# 409 NP_443193.1 Already existis
# 410 NP_001361552.1 Already existis
# 411 NP_001012426.1 Already existis
# 412 NP_001371839.1 Already existis
# 413 NP_000313.2 Already existis
# 414 NP_000278.3 Already existis
# 415 NP_006236.1 Already existis
# 416 NP_689945.2 Already existis
# 417 NP_065796.2 Already existis
# 418 NP_001019801.3 Already existis
# 419 NP_000246.2 Already existis
# 420 NP_619639.3 Already existis
# 421 NP_001361665.1 Already existis
# 422 NP_001136272.1 Already existis
# 423 NP_062816.2 Already existis
# 424 NP_036566.1 Already existis
# 425 NP_001116241.1 Already existis
# 426 NP_898871.1 Already existis
# 427 NP_006407.1 Already existis
# 428 NP_064716.2 Already existis
# 429 NP_067067.1 Already existis
# 430 NP_663304.1 Already existis
# 431 NP_065822.2 Already existis
# 432 NP_001186492.1 Already existis
# 433 NP_116119.2 Already existis
# 434 NP_937882.2 Already existis
# 435 NP_000484.2 Already existis
# 436 NP_001035940.1 Already existis
# 437 NP_000156.1 Already existis
# 438 NP_006064.2 Already existis
# 439 NP_000417.3 Already existis
# 440 NP_000036.2 Already existis
# 441 NP_004821.2 Already existis
# 442 NP_006199.2 Already existis
# 443 NP_004091.3 Already existis
# 444 NP_001128303.1 Already existis
# 445 NP_055554.1 Already existis
# 446 NP_005661.1 Already existis
# 447 NP_004681.1 Already existis
# 448 NP_001361757.1 Already existis
# 449 NP_116250.3 Already existis
# 450 NP_001258791.1 Already existis
# 451 NP_000867.3 Already existis
# 452 NP_002784.1 Already existis
# 453 NP_064608.2 Already existis
# 454 NP_115791.3 Already existis
# 455 NP_001092.1 Already existis
# 456 NP_996994.1 Already existis
# 457 NP_000526.2 Already existis
# 458 NP_000465.1 Already existis
# 459 NP_001264044.1 Already existis
# 460 NP_001026880.2 Already existis
# 461 NP_002038.2 Already existis
# 462 NP_940820.1 Already existis
# 463 NP_005393.2 Already existis
# 464 NP_003709.3 Already existis
# 465 NP_000153.1 Already existis
# 466 NP_002532.2 Already existis
# 467 NP_000587.1 Already existis
# 468 NP_001076440.2 Already existis
# 469 NP_005219.2 Already existis
# 470 NP_000172.2 Already existis
# 471 NP_000039.2 Already existis
# 472 NP_694578.1 Already existis
# 473 NP_056385.1 Already existis
# 474 NP_036611.2 Already existis
# 475 NP_002060.4 Already existis
# 476 NP_000713.2 Already existis
# 477 NP_000434.1 Already existis
# 478 NP_919436.1 Already existis
# 479 NP_000080.2 Already existis
# 480 NP_003910.1 Already existis
# 481 NP_055066.1 Already existis
# 482 NP_001664.3 Already existis
# 483 NP_057272.1 Already existis
# 484 NP_004435.3 Already existis
# 485 NP_005951.1 Already existis
# 486 NP_000432.1 Already existis
# 487 NP_000102.1 Already existis
# 488 NP_000099.2 Already existis
# 489 NP_001032209.1 Already existis
# 490 NP_001159817.1 Already existis
# 491 NP_000483.3 Already existis
# 492 NP_036413.1 Already existis
# 493 NP_000874.2 Already existis
# 494 NP_001449.3 Already existis
# 495 NP_065683.2 Already existis
# 496 NP_004324.2 Already existis
# 497 NP_002760.1 Already existis
# 498 NP_000074.3 Already existis
# 499 NP_071890.2 Already existis
# 500 NP_004447.2 Already existis
# 501 NP_060854.2 Already existis
# 502 NP_000229.1 Already existis
# 503 NP_005605.1 Already existis
# 504 NP_057287.2 Already existis
# 505 NP_733751.2 Already existis
# 506 NP_570629.2 Already existis
# 507 NP_005506.3 Already existis
# 508 NP_490647.1 Already existis
# 509 NP_001295022.1 Already existis
# 510 NP_000228.1 Already existis
# 511 NP_001684.2 Already existis
# 512 NP_005135.2 Already existis
# 513 NP_001381061.1 Already existis
# 514 NP_644807.1 Already existis
# 515 NP_001304707.1 Already existis
# 516 NP_006120.1 Already existis
# 517 NP_001121903.1 Already existis
# 518 NP_001076580.1 Already existis
# 519 NP_000628.2 Already existis
# 520 NP_001095871.1 Already existis
# 521 NP_075598.2 Already existis
# 522 NP_000028.3 Already existis
# 523 NP_060575.1 Already existis
# 524 NP_112216.3 Already existis
# 525 NP_689632.2 Already existis
# 526 NP_002341.1 Already existis
# 527 NP_060250.2 Already existis
# 528 NP_015628.2 Already existis
# 529 NP_061845.2 Already existis
# 530 NP_061971.3 Already existis
# 531 NP_714915.3 Already existis
# 532 NP_002559.2 Already existis
# 533 NP_848660.3 Already existis
# 534 NP_054831.2 Already existis
# 535 NP_000118.2 Already existis
# 536 NP_003175.2 Already existis
# 537 NP_004510.1 Already existis
# 538 NP_000488.3 Already existis
# 539 NP_000489.3 Already existis
# 540 NP_835466.2 Already existis
# 541 NP_958786.1 Already existis
# 542 NP_003792.1 Already existis
# 543 NP_036211.2 Already existis
# 544 NP_003061.3 Already existis
# 545 NP_598004.1 Already existis
# 546 NP_000161.2 Already existis
# 547 NP_001362496.1 Already existis
# 548 NP_000068.1 Already existis
# 549 NP_478102.2 Already existis
# 550 NP_000450.3 Already existis
# 551 NP_001161.1 Already existis
# 552 NP_000146.2 Already existis
# 553 NP_009057.1 Already existis
# 554 NP_003986.2 Already existis
# 555 NP_005467.1 Already existis
# 556 NP_036335.1 Already existis
# 557 NP_619636.2 Already existis
# 558 NP_060132.3 Already existis
# 559 NP_002063.2 Already existis
# 560 NP_112553.1 Already existis
# 561 NP_001003800.1 Already existis
# 562 NP_000498.2 Already existis
# 563 NP_000255.2 Already existis
# 564 NP_004603.1 Already existis
# 565 NP_149078.1 Already existis
# 566 NP_000026.2 Already existis
# 567 NP_001365140.1 Already existis
# 568 NP_937895.1 Already existis
# 569 NP_004950.2 Already existis
# 570 NP_001167618.1 Already existis
# 571 NP_001027392.1 Already existis
# 572 NP_001108225.1 Already existis
# 573 NP_057119.3 Already existis
# 574 NP_001123910.1 Already existis
# 575 NP_000104.1 Already existis
# 576 NP_446464.1 Already existis
# 577 NP_067632.2 Already existis
# 578 NP_001070833.1 Already existis
# 579 NP_055861.3 Already existis
# 580 NP_001364233.1 Already existis
# 581 NP_003163.1 Already existis
# 582 NP_620596.2 Already existis
# 583 NP_000084.3 Already existis
# 584 NP_065873.2 Already existis
# 585 NP_063945.2 Already existis
# 586 NP_060087.3 Already existis
# 587 NP_006403.2 Already existis
# 588 NP_015566.1 Already existis
# 589 NP_001170787.2 Already existis
# 590 NP_079033.4 Already existis
# 591 NP_001357029.1 Already existis
# 592 NP_001002295.1 Already existis
# 593 NP_001313271.1 Already existis
# 594 NP_001029027.1 Already existis
# 595 NP_068506.2 Already existis
# 596 NP_004512.1 Already existis
# 597 NP_066124.1 Already existis
# 598 NP_065574.4 Already existis
# 599 NP_060715.2 Already existis
# 600 NP_000390.2 Already existis
# 601 NP_000179.2 Already existis
# 602 NP_001076585.1 Already existis
# 603 NP_071407.4 Already existis
# 604 NP_002769.1 Already existis
# 605 NP_148982.1 Already existis
# 606 NP_000420.1 Already existis
# 607 NP_149091.1 Already existis
# 608 NP_001015880.1 Already existis
# 609 NP_000305.3 Already existis
# 610 NP_000034.1 Already existis
# 611 NP_000226.2 Already existis
# 612 NP_004514.2 Already existis
# 613 NP_006195.3 Already existis
# 614 NP_002851.2 Already existis
# 615 NP_056446.4 Already existis
# 616 NP_612422.2 Already existis
# 617 NP_000186.2 Already existis
# 618 NP_068602.2 Already existis
# 619 NP_001182192.1 Already existis
# 620 NP_000093.1 Already existis
# 621 NP_001338098.1 Already existis
# 622 NP_005436.1 Already existis
# 623 NP_862823.1 Already existis
# 624 NP_006784.1 Already existis
# 625 NP_000132.3 Already existis
# 626 NP_002766.1 Already existis
# 627 NP_001359052.1 Already existis
# 628 NP_000265.1 Already existis
# 629 NP_073713.2 Already existis
# 630 NP_000366.1 Already existis
# 631 NP_001362309.1 Already existis
# 632 NP_796374.2 Already existis
# 633 NP_004083.3 Already existis
# 634 NP_066288.2 Already existis
# 635 NP_665893.2 Already existis
# 636 NP_002448.4 Already existis
# 637 NP_000603.1 Already existis
# 638 NP_000198.1 Already existis
# 639 NP_000351.2 Already existis
# 640 NP_000209.2 Already existis
# 641 NP_000534.3 Already existis
# 642 NP_653267.2 Already existis
# 643 NP_000382.3 Already existis
# 644 NP_036382.2 Already existis
# 645 NP_001137533.1 Already existis
# 646 NP_000516.3 Already existis
# 647 NP_000343.2 Already existis
# 648 NP_001106212.1 Already existis
# 649 NP_004202.4 Already existis
# 650 NP_998764.1 Already existis
# 651 NP_073562.1 Already existis
# 652 NP_113606.2 Already existis
# 653 NP_001355823.1 Already existis
# 654 NP_077744.4 Already existis
# 655 NP_000439.2 Already existis
# 656 NP_000527.2 Already existis
# 657 NP_068745.2 Already existis
# 658 NP_003673.3 Already existis
# 659 NP_002795.2 Already existis
# 660 NP_005046.2 Already existis
# 661 NP_000053.2 Already existis
# 662 NP_945185.1 Already existis
# 663 NP_004174.1 Already existis
# 664 NP_036332.2 Already existis
# 665 NP_938148.1 Already existis
# 666 NP_000923.1 Already existis
# 667 NP_201567.1 Already existis
# 668 NP_001092141.1 Already existis
# 669 NP_005600.1 Already existis
# 670 NP_001357188.2 Already existis
# 671 NP_058634.4 Already existis
# 672 NP_006833.2 Already existis
# 673 NP_060496.2 Already existis
# 674 NP_078925.3 Already existis
# 675 NP_009034.2 Already existis
# 676 NP_002326.2 Already existis
# 677 NP_001867.2 Already existis
# 678 NP_002171.2 Already existis
# 679 NP_001351.2 Already existis
# 680 NP_006176.2 Already existis
# 681 NP_057941.1 Already existis
# 682 NP_001245321.1 Already existis
# 683 NP_001273506.1 Already existis
# 684 NP_000251.3 Already existis
# 685 NP_076984.2 Already existis
# 686 NP_001092286.2 Already existis
# 687 NP_003788.2 Already existis
# 688 NP_036325.2 Already existis
# 689 NP_001805.4 Already existis
# 690 NP_000363.1 Already existis
# 691 NP_004612.2 Already existis
# 692 NP_001123617.1 Already existis
# 693 NP_001368.2 Already existis
# 694 NP_000820.4 Already existis
# 695 NP_000010.1 Already existis
# 696 NP_000042.3 Already existis
# 697 NP_079016.2 Already existis
# 698 NP_001276737.1 Already existis
# 699 NP_002993.1 Already existis
# 700 NP_000308.1 Already existis
# 701 NP_000030.1 Already existis
# 702 NP_001549.2 Already existis
# 703 NP_001184033.1 Already existis
# 704 NP_000181.2 Already existis
# 705 NP_001373.2 Already existis
# 706 NP_001265360.1 Already existis
# 707 NP_079045.1 Already existis
# 708 NP_689926.1 Already existis
# 709 NP_722450.1 Already existis
# 710 NP_068813.1 Already existis
# 711 NP_055199.1 Already existis
# 712 NP_000710.5 Already existis
# 713 NP_003315.2 Already existis
# 714 NP_000208.2 Already existis
# 715 NP_000543.3 Already existis
# 716 NP_001264.2 Already existis
# 717 NP_002327.2 Already existis
# 718 NP_000825.2 Already existis
# 719 NP_064693.2 Already existis
# 720 NP_008871.3 Already existis
# 721 NP_004976.2 Already existis
# 722 NP_036192.2 Already existis
# 723 NP_001005242.2 Already existis
# 724 NP_001166935.1 Already existis
# 725 NP_689854.2 Already existis
# 726 NP_000367.1 Already existis
# 727 NP_001835.3 Already existis
# 728 NP_001650.1 Already existis
# 729 NP_005421.1 Already existis
# 730 NP_003473.3 Already existis
# 731 NP_066382.1 Already existis
# 732 NP_006000.2 Already existis
# 733 NP_001306928.1 Already existis
# 734 NP_001317189.1 Already existis
# 735 NP_000011.2 Already existis
# 736 NP_000415.2 Already existis
# 737 NP_006112.3 Already existis
# 738 NP_056480.1 Already existis
# 739 NP_065434.1 Already existis
# 740 NP_001020.2 Already existis
# 741 NP_005410.1 Already existis
# 742 NP_001677.2 Already existis
# 743 NP_000776.1 Already existis
# 744 NP_776173.3 Already existis
# 745 NP_055069.1 Already existis
# 746 NP_037386.1 Already existis
# 747 NP_631875.1 Already existis
# 748 NP_078961.3 Already existis
# 749 NP_005630.1 Already existis
# 750 NP_079390.3 Already existis
# 751 NP_000890.1 Already existis
# 752 NP_001353450.1 Already existis
# 753 NP_077288.2 Already existis
# 754 NP_000268.1 Already existis
# 755 NP_056090.1 Already existis
# 756 NP_060552.4 Already existis
# 757 NP_569733.2 Already existis
# 758 NP_067638.3 Already existis
# 759 NP_733765.1 Already existis
# 760 NP_005466.1 Already existis
# 761 NP_058132.2 Already existis
# 762 NP_852259.1 Already existis
# 763 NP_056150.1 Already existis
# 764 NP_000536.6 Already existis
# 765 NP_006222.2 Already existis
# 766 NP_068773.2 Already existis
# 767 NP_003995.2 Already existis
# 768 NP_001103689.1 Already existis
# 769 NP_002001.1 Already existis
# 770 NP_000222.2 Already existis
# 771 NP_055178.3 Already existis
# 772 NP_000050.3 Already existis
# 773 NP_055902.1 Already existis
# 774 NP_037470.1 Already existis
# 775 NP_003841.1 Already existis
# 776 NP_000312.2 Already existis
# 777 NP_001155970.1 Already existis
# 778 NP_002258.2 Already existis
# 779 NP_000044.2 Already existis
# 780 NP_005699.1 Already existis
# 781 NP_000273.2 Already existis
# 782 NP_443099.1 Already existis
# 783 NP_001836.3 Already existis
# 784 NP_001837.2 Already existis
# 785 NP_001229811.1 Already existis
# 786 NP_056020.2 Already existis
# 787 NP_000495.1 Already existis
# 788 NP_009123.1 Already existis
# 789 NP_001164100.1 Already existis
# 790 NP_003973.3 Already existis
# 791 NP_001341569.1 Already existis
# 792 NP_000248.2 Already existis
# 793 NP_001341697.1 Already existis
# 794 NP_000350.1 Already existis
# 795 NP_005240.3 Already existis
# 796 NP_004077.1 Already existis
# 797 NP_001025226.1 Already existis
# 798 NP_060387.2 Already existis
# 799 NP_055487.2 Already existis
# 800 NP_001073136.1 Already existis
# 801 NP_001359005.1 Already existis
# 802 NP_006355.2 Already existis
# 803 NP_008870.2 Already existis
# 804 NP_079160.1 Already existis
# 805 NP_056999.2 Already existis
# 806 NP_000152.1 Already existis
# 807 NP_065861.3 Already existis
# 808 NP_001342365.1 Already existis
# 809 NP_065857.1 Already existis
# 810 NP_689656.2 Already existis
# 811 NP_001123476.1 Already existis
# 812 NP_000012.1 Already existis
# 813 NP_878314.1 Already existis
# 814 NP_005041.1 Already existis
# 815 NP_006423.1 Already existis
# 816 NP_001096034.1 Already existis
# 817 NP_000144.2 Already existis
# 818 NP_060888.2 Already existis
# 819 NP_002793.2 Already existis
# 820 NP_008819.1 Already existis
# 821 NP_006320.2 Already existis
# 822 NP_004230.2 Already existis
# 823 NP_803187.1 Already existis
# 824 NP_057501.2 Already existis
# 825 NP_003394.1 Already existis
# 826 NP_001367.2 Already existis
# 827 NP_056471.1 Already existis
# 828 NP_071934.3 Already existis
# 829 NP_000805.1 Already existis
# 830 NP_000801.1 Already existis
# 831 NP_000266.2 Already existis
# 832 NP_001027.3 Already existis
# 833 NP_001352017.1 Already existis
# 834 NP_002216.3 Already existis
# 835 NP_061947.1 Already existis
# 836 NP_000061.1 Already existis
# 837 NP_612486.2 Already existis
# 838 NP_116281.2 Already existis
# 839 NP_079413.3 Already existis
# 840 NP_001350640.1 Already existis
# 841 NP_995322.1 Already existis
# 842 NP_000329.2 Already existis
# 843 NP_001020419.1 Already existis
# 844 NP_000129.3 Already existis
# 845 NP_861454.2 Already existis
# 846 NP_057278.2 Already existis
# 847 NP_899058.1 Already existis
# 848 NP_073752.6 Already existis
# 849 NP_996920.1 Already existis
# 850 NP_003879.2 Already existis
# 851 NP_001094832.1 Already existis
# 852 NP_002746.1 Already existis
# 853 NP_005576.3 Already existis
# 854 NP_001354734.1 Already existis
# 855 NP_079093.2 Already existis
# 856 NP_055064.1 Already existis
# 857 NP_000511.2 Already existis
# 858 NP_005468.1 Already existis
# 859 NP_003603.1 Already existis
# 860 NP_006706.2 Already existis
# 861 NP_116197.4 Already existis
# 862 NP_000128.1 Already existis
# 863 NP_078856.4 Already existis
# 864 NP_001012.1 Already existis
# 865 NP_000317.1 Already existis
# 866 NP_002684.1 Already existis
# 867 NP_001262.3 Already existis
# 868 NP_001365718.1 Already existis
# 869 NP_000508.1 Already existis
# 870 NP_000549.1 Already existis
# 871 NP_001278.1 Already existis
# 872 NP_057195.2 Already existis
# 873 NP_000539.2 Already existis
# 874 NP_001009944.3 Already existis
# 875 NP_115647.2 Already existis
# 876 NP_001080.2 Already existis
# 877 NP_001685.1 Already existis
# 878 NP_004371.2 Already existis
# 879 NP_061982.3 Already existis
# 880 NP_000294.1 Already existis
# 881 NP_001127879.1 Already existis
# 882 NP_001295071.1 Already existis
# 883 NP_001162.5 Already existis
# 884 NP_003352.2 Already existis
# 885 NP_060206.2 Already existis
# 886 NP_000327.2 Already existis
# 887 NP_705831.1 Already existis
# 888 NP_004311.1 Already existis
# 889 NP_057235.2 Already existis
# 890 NP_115564.2 Already existis
# 891 NP_004951.1 Already existis
# 892 NP_001098717.1 Already existis
# 893 NP_891552.1 Already existis
# 894 NP_001357395.1 Already existis
# 895 NP_005844.4 Already existis
# 896 NP_004521.1 Already existis
# 897 NP_066268.1 Already existis
# 898 NP_001119580.2 Already existis
# 899 NP_588609.1 Already existis
# 900 NP_001288.3 Already existis
# 901 NP_057368.3 Already existis
# 902 NP_001788.2 Already existis
# 903 NP_004605.4 Already existis
# 904 NP_003896.1 Already existis
# 905 NP_003780.1 Already existis
# 906 NP_001361604.1 Already existis
# 907 NP_004585.1 Already existis
# 908 NP_000220.1 Already existis
# 909 NP_004351.1 Already existis
# 910 NP_001596.2 Already existis
# 911 NP_008816.3 Already existis
# 912 NP_077282.3 Already existis
# 913 NP_001070886.1 Already existis
# 914 NP_005539.1 Already existis
# 915 NP_057457.1 Already existis
# 916 NP_005351.2 Already existis
# 917 NP_003782.1 Already existis
# 918 NP_001442.2 Already existis
# 919 NP_079011.3 Already existis
# 920 NP_000503.1 Already existis
# 921 NP_001230208.1 Already existis
# 922 NP_037407.4 Already existis
# 923 NP_003110.1 Already existis
# 924 NP_000126.2 Already existis
# 925 NP_006077.2 Already existis
# 926 NP_057616.2 Already existis
# 927 NP_006436.3 Already existis
# 928 NP_002936.1 Already existis
# 929 NP_000421.1 Already existis
# 930 NP_000040.1 Already existis
# 931 NP_659505.1 Already existis
# 932 NP_004928.2 Already existis
# 933 NP_000071.1 Already existis
# 934 NP_000164.5 Already existis
# 935 NP_127497.1 Already existis
# 936 NP_055151.3 Already existis
# 937 NP_808218.1 Already existis
# 938 NP_001308004.1 Already existis
# 939 NP_000009.1 Already existis
# 940 NP_000928.1 Already existis
# 941 NP_000537.3 Already existis
# 942 NP_001005273.1 Already existis
# 943 NP_000171.1 Already existis
# 944 NP_079375.3 Already existis
# 945 NP_000295.1 Already existis
# 946 NP_057323.3 Already existis
# 947 NP_000373.1 Already existis
# 948 NP_659731.1 Already existis
# 949 NP_001035957.1 Already existis
# 950 NP_001333683.1 Already existis
# 951 NP_000449.1 Already existis
# 952 NP_955366.1 Already existis
# 953 NP_000412.4 Already existis
# 954 NP_644805.1 Already existis
# 955 NP_001123493.1 Already existis
# 956 NP_000254.2 Already existis
# 957 NP_001061.2 Already existis
# 958 NP_003623.1 Already existis
# 959 NP_115763.2 Already existis
# 960 NP_000142.2 Already existis
# 961 NP_000333.1 Already existis
# 962 NP_002078.1 Already existis
# 963 NP_000410.2 Already existis
# 964 NP_004238.3 Already existis
# 965 NP_002046.1 Already existis
# 966 NP_001247.3 Already existis
# 967 NP_000203.2 Already existis
# 968 NP_005211.1 Already existis
# 969 NP_002195.1 Already existis
# 970 NP_000014.1 Already existis
# 971 NP_000079.2 Already existis
# 972 NP_004850.1 Already existis
# 973 NP_001308049.1 Already existis
# 974 NP_005112.2 Already existis
# 975 NP_002392.2 Already existis
# 976 NP_000325.4 Already existis
# 977 NP_002725.1 Already existis
# 978 NP_000337.1 Already existis
# 979 NP_694941.2 Already existis
# 980 NP_077728.3 Already existis
# 981 NP_001119593.1 Already existis
# 982 NP_000204.3 Already existis
# 983 NP_005315.1 Already existis
# 984 NP_775899.3 Already existis
# 985 NP_000143.2 Already existis
# 986 NP_000190.1 Already existis
# 987 NP_001243000.2 Already existis
# 988 NP_002513.2 Already existis
# 989 NP_001079990.1 Already existis
# 990 NP_001605.1 Already existis
# 991 NP_056110.2 Already existis
# 992 NP_001362737.1 Already existis
# 993 NP_036439.2 Already existis
# 994 NP_001365112.1 Already existis
# 995 NP_892023.1 Already existis
# 996 NP_006787.2 Already existis
# 997 NP_000262.2 Already existis
# 998 NP_000362.1 Already existis
# 999 NP_060725.1 Already existis
# 1000 NP_056374.2 Already existis
# 1001 NP_001371403.1 Already existis
# 1002 NP_005892.1 Already existis
# 1003 NP_001073936.1 Already existis
# 1004 NP_001077431.1 Already existis
# 1005 NP_000131.2 Already existis
# 1006 NP_038463.2 Already existis
# 1007 NP_005026.3 Already existis
# 1008 NP_001963.1 Already existis
# 1009 NP_004359.1 Already existis
# 1010 NP_000446.1 Already existis
# 1011 NP_000147.1 Already existis
# 1012 NP_005874.1 Already existis
# 1013 NP_000470.3 Already existis
# 1014 NP_001137458.1 Already existis
# 1015 NP_002058.2 Already existis
# 1016 NP_001138637.1 Already existis
# 1017 NP_057347.2 Already existis
# 1018 NP_149053.1 Already existis
# 1019 NP_056982.1 Already existis
# 1020 NP_006078.2 Already existis
# 1021 NP_001159586.1 Already existis
# 1022 NP_001164626.1 Already existis
# 1023 NP_008880.2 Already existis
# 1024 NP_078966.2 Already existis
# 1025 NP_003322.3 Already existis
# 1026 NP_987096.1 Already existis
# 1027 NP_003063.2 Already existis
# 1028 NP_000518.1 Already existis
# 1029 NP_001602.1 Already existis
# 1030 NP_006388.2 Already existis
# 1031 NP_055790.1 Already existis
# 1032 NP_001366.1 Already existis
# 1033 NP_000150.1 Already existis
# 1034 NP_004452.1 Already existis
# 1035 NP_001352831.1 Already existis
# 1036 NP_001120694.1 Already existis
# 1037 NP_055736.2 Already existis
# 1038 NP_612510.1 Already existis
# 1039 NP_000426.2 Already existis
# 1040 NP_116009.2 Already existis
# 1041 NP_000206.2 Already existis
# 1042 NP_005526.1 Already existis
# 1043 NP_001380433.1 Already existis
# 1044 NP_005018.2 Already existis
# 1045 NP_000086.2 Already existis
# 1046 NP_067090.1 Already existis
# 1047 NP_055085.1 Already existis
# 1048 NP_004355.2 Already existis
# 1049 NP_000166.2 Already existis
# 1050 NP_116024.1 Already existis
# 1051 NP_055542.1 Already existis
# 1052 NP_004637.1 Already existis
# 1053 NP_001077430.1 Already existis
# 1054 NP_066925.1 Already existis
# 1055 NP_000531.2 Already existis
# 1056 NP_001001563.2 Already existis
# 1057 NP_000651.3 Already existis
# 1058 NP_000700.1 Already existis
# 1059 NP_001013.1 Already existis
# 1060 NP_689509.1 Already existis
# 1061 NP_597701.1 Already existis
# 1062 NP_001373227.1 Already existis
# 1063 NP_055112.2 Already existis
# 1064 NP_061981.2 Already existis
# 1065 NP_000032.1 Already existis
# 1066 NP_001369351.1 Already existis
# 1067 NP_000391.1 Already existis
# 1068 NP_005175.2 Already existis
# 1069 NP_077277.1 Already existis
# 1070 NP_000225.1 Already existis
# 1071 NP_000827.2 Already existis
# 1072 NP_060106.2 Already existis
# 1073 NP_004908.4 Already existis
# 1074 NP_001976.1 Already existis
# 1075 NP_002730.1 Already existis
# 1076 NP_056444.3 Already existis
# 1077 NP_077274.3 Already existis
# 1078 NP_000354.4 Already existis
# 1079 NP_808227.1 Already existis
# 1080 NP_212134.3 Already existis
# 1081 NP_000481.2 Already existis
# 1082 NP_001167560.1 Already existis
# 1083 NP_001373322.1 Already existis
# 1084 NP_001191.1 Already existis
# 1085 NP_570824.1 Already existis
# 1086 NP_000205.1 Already existis
# 1087 NP_057184.1 Already existis
# 1088 NP_056153.2 Already existis
# 1089 NP_008823.1 Already existis
# 1090 NP_110517.2 Already existis
# 1091 NP_005452.2 Already existis
# 1092 NP_787110.2 Already existis
# 1093 NP_000299.3 Already existis
# 1094 NP_110404.1 Already existis
# 1095 NP_004966.1 Already existis
# 1096 NP_001269460.1 Already existis
# 1097 NP_000773.2 Already existis
# 1098 NP_001710.1 Already existis
# 1099 NP_000507.1 Already existis
# 1100 NP_110400.1 Already existis
# 1101 NP_742105.1 Already existis
# 1102 NP_001949.1 Already existis
# 1103 NP_001269938.1 Already existis
# 1104 NP_079495.1 Already existis
# 1105 NP_001340623.1 Already existis
# 1106 NP_000445.1 Already existis
# 1107 NP_060083.1 Already existis
# 1108 NP_001745.2 Already existis
# 1109 NP_001339443.1 Already existis
# 1110 NP_001334650.1 Already existis
# 1111 NP_001243246.1 Already existis
# 1112 NP_543136.1 Already existis
# 1113 NP_000374.1 Already existis
# 1114 NP_659428.2 Already existis
# 1115 NP_000202.3 Already existis
# 1116 NP_001839.2 Already existis
# 1117 NP_001840.3 Already existis
# 1118 NP_002331.3 Already existis
# 1119 NP_001269154.1 Already existis
# 1120 NP_061816.1 Already existis
# 1121 NP_005975.1 Already existis
# 1122 NP_000398.1 Already existis
# 1123 NP_477352.3 Already existis
# 1124 NP_006758.2 Already existis
# 1125 NP_056145.5 Already existis
# 1126 NP_057411.1 Already existis
# 1127 NP_004067.1 Already existis
# 1128 NP_000487.1 Already existis
# 1129 NP_001118.3 Already existis
# 1130 NP_000259.1 Already existis
# 1131 NP_001290185.1 Already existis
# 1132 NP_000334.1 Already existis
# 1133 NP_000353.1 Already existis
# 1134 NP_002464.1 Already existis
# 1135 NP_006069.1 Already existis
# 1136 NP_008872.1 Already existis
# 1137 NP_003551.2 Already existis
# 1138 NP_066919.2 Already existis
# 1139 NP_000017.1 Already existis
# 1140 NP_001420.2 Already existis
# 1141 NP_001089.1 Already existis
# 1142 NP_055981.1 Already existis
# 1143 NP_005129.2 Already existis
# 1144 NP_001944.1 Already existis
# 1145 NP_000478.3 Already existis
# 1146 NP_000442.1 Already existis
# 1147 NP_000038.2 Already existis
# 1148 NP_000207.2 Already existis
# 1149 NP_000264.2 Already existis
# 1150 NP_005324.3 Already existis
# 1151 NP_001133.1 Already existis
# 1152 NP_057646.1 Already existis
# 1153 NP_619542.1 Already existis
# 1154 NP_002054.1 Already existis
# 1155 NP_002632.1 Already existis
# 1156 NP_001310218.1 Already existis
# 1157 NP_000321.1 Already existis
# 1158 NP_000275.1 Already existis
# 1159 NP_004577.1 Already existis
# 1160 NP_055147.1 Already existis
# 1161 NP_000435.3 Already existis
# 1162 NP_620689.1 Already existis
# 1163 NP_000388.2 Already existis
# 1164 NP_001030025.1 Already existis
# 1165 NP_000522.3 Already existis
# 1166 NP_001347.3 Already existis
# 1167 NP_001354650.1 Already existis
# 1168 NP_000257.1 Already existis
# 1169 NP_008846.2 Already existis
# 1170 NP_006570.1 Already existis
# 1171 NP_000368.1 Already existis
# 1172 NP_002040.1 Already existis
# 1173 NP_005651.1 Already existis
# 1174 NP_006512.2 Already existis
# 1175 NP_001025067.1 Already existis
# 1176 NP_054728.2 Already existis
# 1177 NP_005439.2 Already existis
# 1178 NP_004178.2 Already existis
# 1179 NP_006297.2 Already existis
# 1180 NP_065973.2 Already existis
# 1181 NP_004454.2 Already existis
# 1182 NP_000023.2 Already existis
# 1183 NP_038472.2 Already existis
# 1184 NP_001340850.1 Already existis
# 1185 NP_061154.1 Already existis
# 1186 NP_000035.2 Already existis
# 1187 NP_004420.1 Already existis
# 1188 NP_001390.1 Already existis
# 1189 NP_005111.2 Already existis
# 1190 NP_851820.1 Already existis
# 1191 NP_000157.1 Already existis
# 1192 NP_004597.3 Already existis
# 1193 NP_060956.1 Already existis
# 1194 NP_006508.2 Already existis
# 1195 NP_000480.3 Already existis
# 1196 NP_000043.4 Already existis
# 1197 NP_000282.1 Already existis
# 1198 NP_694984.5 Already existis
# 1199 NP_001171809.1 Already existis
# 1200 NP_000052.1 Already existis
# 1201 NP_000160.1 Already existis
# 1202 NP_000524.3 Already existis
# 1203 NP_203699.1 Already existis
# 1204 NP_001182482.1 Already existis
# 1205 NP_001093392.1 Already existis
# 1206 NP_065922.3 Already existis
# 1207 NP_005023.2 Already existis
# 1208 NP_001143.2 Already existis
# 1209 NP_003327.2 Already existis
# 1210 NP_078804.2 Already existis
# 1211 NP_002285.1 Already existis
# 1212 NP_015564.5 Already existis
# 1213 NP_001158.2 Already existis
# 1214 NP_002342.1 Already existis
# 1215 NP_000267.2 Already existis
# 1216 NP_001412.1 Already existis
# 1217 NP_919253.1 Already existis
# 1218 NP_001015877.1 Already existis
# 1219 NP_000185.1 Already existis
# 1220 NP_001153171.1 Already existis
# 1221 NP_000065.1 Already existis
# 1222 NP_000124.1 Already existis
# 1223 NP_000193.1 Already existis
# 1224 NP_000243.1 Already existis
# 1225 NP_000799.1 Already existis
# 1226 NP_005620.1 Already existis
# 1227 NP_000024.2 Already existis
# 1228 NP_001265045.1 Already existis
# 1229 NP_000045.1 Already existis
# 1230 NP_001104262.1 Already existis
# 1231 NP_001104026.1 Already existis
# 1232 NP_000107.1 Already existis
# 1233 NP_001346945.1 Already existis
# 1234 NP_001354.1 Already existis
# 1235 NP_000123.1 Already existis
# 1236 NP_940978.2 Already existis
# 1237 NP_114127.3 Already existis
# 1238 NP_073624.2 Already existis
# 1239 NP_031401.1 Already existis
# 1240 NP_000293.2 Already existis
# 1241 NP_056193.2 Already existis
# 1242 NP_004422.2 Already existis
# 1243 NP_071372.1 Already existis
# 1244 NP_997304.3 Already existis
# 1245 NP_055862.1 Already existis
# 1246 NP_115785.1 Already existis
# 1247 NP_001009999.1 Already existis
# 1248 NP_001358857.1 Already existis
# 1249 NP_003671.1 Already existis
# 1250 NP_001380991.1 Already existis
# 1251 NP_004691.2 Already existis
# 1252 NP_005364.1 Already existis
# 1253 NP_065098.1 Already existis
# 1254 NP_001041639.1 Already existis
# 1255 NP_056321.2 Already existis
# 1256 NP_036318.1 Already existis
# 1257 NP_001128145.1 Already existis
# 1258 NP_002294.2 Already existis
# 1259 NP_057062.1 Already existis
# 1260 NP_000633.2 Already existis
# 1261 NP_003663.2 Already existis
# 1262 NP_006487.1 Already existis
# 1263 NP_001365898.1 Already existis
# 1264 NP_001240781.1 Already existis
# 1265 NP_002515.1 Already existis
# 1266 NP_056651.1 Already existis
# 1267 NP_998818.1 Already existis
# 1268 NP_689476.2 Already existis
# 1269 NP_006547.1 Already existis
# 1270 NP_060959.2 Already existis
# 1271 NP_060586.2 Already existis
# 1272 NP_003117.2 Already existis
# 1273 NP_002232.2 Already existis
# 1274 NP_004362.2 Already existis
# 1275 NP_006173.2 Already existis
# 1276 NP_008927.1 Already existis
# 1277 NP_000121.2 Already existis
# 1278 NP_940905.2 Already existis
# 1279 NP_002104.2 Already existis
# 1280 NP_060606.3 Already existis
# 1281 NP_001239031.1 Already existis
# 1282 NP_796376.2 Already existis
# 1283 NP_000528.1 Already existis
# 1284 NP_001006659.1 Already existis
# 1285 NP_758861.1 Already existis
# 1286 NP_001366332.1 Already existis
# 1287 NP_064632.2 Already existis
# 1288 NP_073623.1 Already existis
# 1289 NP_000072.2 Already existis
# 1290 NP_665860.2 Already existis
# 1291 NP_991331.1 Already existis
# 1292 NP_001193673.1 Already existis
# 1293 NP_001289981.1 Already existis
# 1294 NP_001034451.1 Already existis
# 1295 NP_005369.2 Already existis
# 1296 NP_065830.2 Already existis
# 1297 NP_002372.1 Already existis
# 1298 NP_000173.2 Already existis
# 1299 NP_919224.1 Already existis
# 1300 NP_066918.2 Already existis
# 1301 NP_002428.1 Already existis
# 1302 NP_001029288.1 Already existis
# 1303 NP_056477.1 Already existis
# 1304 NP_002700.1 Already existis
# 1305 NP_001025054.1 Already existis
# 1306 NP_004295.2 Already existis
# 1307 NP_001186067.1 Already existis
# 1308 NP_071881.1 Already existis
# 1309 NP_071882.1 Already existis
# 1310 NP_001165084.1 Already existis
# 1311 NP_001177203.1 Already existis
# 1312 NP_003119.2 Already existis
# 1313 NP_060532.2 Already existis
# 1314 NP_001231639.1 Already existis
# 1315 NP_001683.2 Already existis
# 1316 NP_003115.1 Already existis
# 1317 NP_001365383.1 Already existis
# 1318 NP_001274420.1 Already existis
# 1319 NP_653164.2 Already existis
# 1320 NP_001373064.1 Already existis
# 1321 NP_068587.1 Already existis
# 1322 NP_006334.2 Already existis
# 1323 NP_003457.1 Already existis
# 1324 NP_001361282.1 Already existis
# 1325 NP_055610.1 Already existis
# 1326 NP_001365049.1 Already existis
# 1327 NP_001157980.2 Already existis
# 1328 NP_079029.3 Already existis
# 1329 NP_001352465.1 Already existis
# 1330 NP_004516.2 Already existis
# 1331 NP_006054.2 Already existis
# 1332 NP_000808.2 Already existis
# 1333 NP_114148.3 Already existis
# 1334 NP_001138722.1 Already existis
# 1335 NP_000070.1 Already existis
# 1336 NP_001813.1 Already existis
# 1337 NP_006155.2 Already existis
# 1338 NP_001254479.2 Already existis
# 1339 NP_055400.1 Already existis
# 1340 NP_055177.2 Already existis
# 1341 NP_001335697.1 Already existis
# 1342 NP_001037850.1 Already existis
# 1343 NP_001195.2 Already existis
# 1344 NP_005205.2 Already existis
# 1345 NP_004997.4 Already existis
# 1346 NP_008822.2 Already existis
# 1347 NP_001548.1 Already existis
# 1348 NP_079519.1 Already existis
# 1349 NP_001335252.1 Already existis
# 1350 NP_877437.2 Already existis
# 1351 NP_000835.1 Already existis
# 1352 NP_079541.1 Already existis
# 1353 NP_002871.1 Already existis
# 1354 NP_004619.3 Already existis
# 1355 NP_005668.2 Already existis
# 1356 NP_001895.1 Already existis
# 1357 NP_064627.1 Already existis
# 1358 NP_000307.1 Already existis
# 1359 NP_055990.1 Already existis
# 1360 NP_001026873.2 Already existis
# 1361 NP_001780.2 Already existis
# 1362 NP_001398.2 Already existis
# 1363 NP_000378.1 Already existis
# 1364 NP_000875.2 Already existis
# 1365 NP_942581.1 Already existis
# 1366 NP_002283.3 Already existis
# 1367 NP_068806.2 Already existis
# 1368 NP_002061.1 Already existis
# 1369 NP_006536.3 Already existis
# 1370 NP_001364334.1 Already existis
# 1371 NP_001341533.1 Already existis
# 1372 NP_000297.1 Already existis
# 1373 NP_057673.2 Already existis
# 1374 NP_001186728.1 Already existis
# 1375 NP_068799.2 Already existis
# 1376 NP_004517.2 Already existis
# 1377 NP_116027.2 Already existis
# 1378 NP_001263199.1 Already existis
# 1379 NP_443715.1 Already existis
# 1380 NP_001054.2 Already existis
# 1381 NP_005621.2 Already existis
# 1382 NP_848649.3 Already existis
# 1383 NP_003403.2 Already existis
# 1384 NP_004121.2 Already existis
# 1385 NP_009220.2 Already existis
# 1386 NP_079272.4 Already existis
# 1387 NP_000046.1 Already existis
# 1388 NP_009148.2 Already existis
# 1389 NP_002653.1 Already existis
# 1390 NP_001958.2 Already existis
# 1391 NP_006571.2 Already existis
# 1392 NP_001354478.1 Already existis
# 1393 NP_000987.2 Already existis
# 1394 NP_000274.3 Already existis
# 1395 NP_001035889.1 Already existis
# 1396 NP_001116153.1 Already existis
# 1397 NP_714928.1 Already existis
# 1398 NP_006008.1 Already existis
# 1399 NP_056958.3 Already existis
# 1400 NP_000213.1 Already existis
# 1401 NP_115593.3 Already existis
# 1402 NP_079350.5 Already existis
# 1403 NP_001345850.1 Already existis
# 1404 NP_000288.1 Already existis
# 1405 NP_000336.1 Already existis
# 1406 NP_898898.1 Already existis
# 1407 NP_005318.6 Already existis
# 1408 NP_001358525.1 Already existis
# 1409 NP_476516.1 Already existis
# 1410 NP_000892.2 Already existis
# 1411 NP_068657.1 Already existis
# 1412 NP_068656.2 Already existis
# 1413 NP_612395.2 Already existis
# 1414 NP_001186326.1 Already existis
# 1415 NP_001820.2 Already existis
# 1416 NP_000018.2 Already existis
# 1417 NP_997235.3 Already existis
# 1418 NP_000883.2 Already existis
# 1419 NP_000119.1 Already existis
# 1420 NP_001035.1 Already existis
# 1421 NP_036205.1 Already existis
# 1422 NP_004456.1 Already existis
# 1423 NP_000073.1 Already existis
# 1424 NP_001091981.1 Already existis
# 1425 NP_001158136.1 Already existis
# 1426 NP_852664.1 Already existis
# 1427 NP_115495.3 Already existis
# 1428 NP_055454.1 Already existis
# 1429 NP_001261.2 Already existis
# 1430 NP_055238.1 Already existis
# 1431 NP_002706.1 Already existis
# 1432 NP_057688.3 Already existis
# 1433 NP_057664.1 Already existis
# 1434 NP_064502.9 Already existis
# 1435 NP_078853.2 Already existis
# 1436 NP_009217.3 Already existis
# 1437 NP_000818.2 Already existis
# 1438 NP_001032410.1 Already existis
# 1439 NP_003043.3 Already existis
# 1440 NP_891555.2 Already existis
# 1441 NP_006558.1 Already existis
# 1442 NP_000120.2 Already existis
# 1443 NP_004406.2 Already existis
# 1444 NP_001358995.1 Already existis
# 1445 NP_001229886.1 Already existis
# 1446 NP_004743.1 Already existis
# 1447 NP_004964.2 Already existis
# 1448 NP_001121636.1 Already existis
# 1449 NP_940988.2 Already existis
# 1450 NP_003536.1 Already existis
# 1451 NP_001461.1 Already existis
# 1452 NP_001103279.2 Already existis
# 1453 NP_003578.2 Already existis
# 1454 NP_821133.1 Already existis
# 1455 NP_008860.4 Already existis
# 1456 NP_001352205.1 Already existis
# 1457 NP_000584.3 Already existis
# 1458 NP_057143.1 Already existis
# 1459 NP_055595.2 Already existis
# 1460 NP_003212.2 Already existis
# 1461 NP_004361.3 Already existis
# 1462 NP_004990.3 Already existis
# 1463 NP_060404.4 Already existis
# 1464 NP_001073977.1 Already existis
# 1465 NP_055836.1 Already existis
# 1466 NP_001265645.1 Already existis
# 1467 NP_009145.1 Already existis
# 1468 NP_612468.1 Already existis
# 1469 NP_000279.1 Already existis
# 1470 NP_001278963.1 Already existis
# 1471 NP_892006.3 Already existis
# 1472 NP_997001.1 Already existis
# 1473 NP_004553.2 Already existis
# 1474 NP_001372008.1 Already existis
# 1475 NP_057182.1 Already existis
# 1476 NP_005609.3 Already existis
# 1477 NP_689956.2 Already existis
# 1478 NP_008839.2 Already existis
# 1479 NP_036426.4 Already existis
# 1480 NP_061932.1 Already existis
# 1481 NP_061820.1 Already existis
# 1482 NP_002128.1 Already existis
# 1483 NP_005514.1 Already existis
# 1484 NP_000513.2 Already existis
# 1485 NP_000814.2 Already existis
# 1486 NP_000159.3 Already existis
# 1487 NP_001211.3 Already existis
# 1488 NP_057122.2 Already existis
# 1489 NP_004594.1 Already existis
# 1490 NP_001382342.1 Already existis
# 1491 NP_005909.2 Already existis
# 1492 NP_036563.1 Already existis
# 1493 NP_000457.1 Already existis
# 1494 NP_060124.2 Already existis
# 1495 NP_001362453.1 Already existis
# 1496 NP_005711.1 Already existis
# 1497 NP_004713.2 Already existis
# 1498 NP_001075.1 Already existis
# 1499 NP_853530.2 Already existis
# 1500 NP_945350.1 Already existis
# 1501 NP_891847.1 Already existis
# 1502 NP_056265.2 Already existis
# 1503 NP_001859.1 Already existis
# 1504 NP_001052.3 Already existis
# 1505 NP_003031.3 Already existis
# 1506 NP_005422.1 Already existis
# 1507 NP_000184.1 Already existis
# 1508 NP_061764.2 Already existis
# 1509 NP_078872.3 Already existis
# 1510 NP_699163.2 Already existis
# 1511 NP_808592.2 Already existis
# 1512 NP_006149.2 Already existis
# 1513 NP_001017420.1 Already existis
# 1514 NP_000544.2 Already existis
# 1515 NP_009106.1 Already existis
# 1516 NP_009129.1 Already existis
# 1517 NP_000340.2 Already existis
# 1518 NP_055277.1 Already existis
# 1519 NP_006757.2 Already existis
# 1520 NP_001244109.1 Already existis
# 1521 NP_004811.1 Already existis
# 1522 NP_000494.2 Already existis
# 1523 NP_000058.1 Already existis
# 1524 NP_057107.4 Already existis
# 1525 NP_001139332.1 Already existis
# 1526 NP_001185462.1 Already existis
# 1527 NP_006256.1 Already existis
# 1528 NP_055661.3 Already existis
# 1529 NP_003226.4 Already existis
# 1530 NP_001153844.1 Already existis
# 1531 NP_036286.2 Already existis
# 1532 NP_510965.1 Already existis
# 1533 NP_001350047.1 Already existis
# 1534 NP_003374.3 Already existis
# 1535 NP_004963.1 Already existis
# 1536 NP_065880.2 Already existis
# 1537 NP_000541.1 Already existis
# 1538 NP_001177666.1 Already existis
# 1539 NP_057609.2 Already existis
# 1540 NP_036276.1 Already existis
# 1541 NP_005857.1 Already existis
# 1542 NP_116023.2 Already existis
# 1543 NP_003280.2 Already existis
# 1544 NP_065995.1 Already existis
# 1545 NP_057126.2 Already existis
# 1546 NP_001353074.1 Already existis
# 1547 NP_008845.2 Already existis
# 1548 NP_150648.2 Already existis
# 1549 NP_001689.1 Already existis
# 1550 NP_004551.2 Already existis
# 1551 NP_006406.1 Already existis
# 1552 NP_000188.1 Already existis
# 1553 NP_061819.2 Already existis
# 1554 NP_005449.5 Already existis
# 1555 NP_005493.2 Already existis
# 1556 NP_067047.4 Already existis
# 1557 NP_005583.1 Already existis
# 1558 NP_001850.1 Already existis
# 1559 NP_116277.2 Already existis
# 1560 NP_775960.4 Already existis
# 1561 NP_003156.1 Already existis
# 1562 NP_004399.2 Already existis
# 1563 NP_005085.2 Already existis
# 1564 NP_003002.2 Already existis
# 1565 NP_055723.1 Already existis
# 1566 NP_005148.2 Already existis
# 1567 NP_115925.2 Already existis
# 1568 NP_000359.1 Already existis
# 1569 NP_835258.1 Already existis
# 1570 NP_006079.1 Already existis
# 1571 NP_055970.1 Already existis
# 1572 NP_001008213.1 Already existis
# 1573 NP_057288.1 Already existis
# 1574 NP_000115.1 Already existis
# 1575 NP_001371069.1 Already existis
# 1576 NP_001345192.1 Already existis
# 1577 NP_060814.4 Already existis
# 1578 NP_004264.2 Already existis
# 1579 NP_001354463.1 Already existis
# 1580 NP_036462.2 Already existis
# 1581 NP_001154824.1 Already existis
# 1582 NP_001092138.1 Already existis
# 1583 NP_004320.2 Already existis
# 1584 NP_005262.1 Already existis
# 1585 NP_001604.1 Already existis
# 1586 NP_057425.3 Already existis
# 1587 NP_510870.1 Already existis
# 1588 NP_000269.3 Already existis
# 1589 NP_001364066.1 Already existis
# 1590 NP_060119.3 Already existis
# 1591 NP_001127835.2 Already existis
# 1592 NP_031399.2 Already existis
# 1593 NP_001600.1 Already existis
# 1594 NP_065109.1 Already existis
# 1595 NP_003273.1 Already existis
# 1596 NP_001014437.1 Already existis
# 1597 NP_055304.1 Already existis
# 1598 NP_001369496.1 Already existis
# 1599 NP_001243615.1 Already existis
# 1600 NP_001018067.1 Already existis
# 1601 NP_001354802.1 Already existis
# 1602 NP_005557.1 Already existis
# 1603 NP_000602.1 Already existis
# 1604 NP_004162.2 Already existis
# 1605 NP_997005.1 Already existis
# 1606 NP_004804.2 Already existis
# 1607 NP_000497.1 Already existis
# 1608 NP_004542.1 Already existis
# 1609 NP_001914.3 Already existis
# 1610 NP_653186.2 Already existis
# 1611 NP_006259.1 Already existis
# 1612 NP_001123616.1 Already existis
# 1613 NP_008877.2 Already existis
# 1614 NP_001035806.1 Already existis
# 1615 NP_660201.1 Already existis
# 1616 NP_002487.1 Already existis
# 1617 NP_006010.2 Already existis
# 1618 NP_060105.3 Already existis
# 1619 NP_060631.2 Already existis
# 1620 NP_001122394.1 Already existis
# 1621 NP_002567.3 Already existis
# 1622 NP_004259.3 Already existis
# 1623 NP_002418.1 Already existis
# 1624 NP_005788.1 Already existis
# 1625 NP_004388.2 Already existis
# 1626 NP_001157749.1 Already existis
# 1627 NP_005179.2 Already existis
# 1628 NP_005413.2 Already existis
# 1629 NP_001245173.1 Already existis
# 1630 NP_002008.2 Already existis
# 1631 NP_000881.3 Already existis
# 1632 NP_001161095.1 Already existis
# 1633 NP_001750.1 Already existis
# 1634 NP_065689.1 Already existis
# 1635 NP_001056.1 Already existis
# 1636 NP_065712.1 Already existis
# 1637 NP_001978.1 Already existis
# 1638 NP_004973.1 Already existis
# 1639 NP_945316.1 Already existis
# 1640 NP_085911.2 Already existis
# 1641 NP_001035526.1 Already existis
# 1642 NP_000280.1 Already existis
# 1643 NP_004809.2 Already existis
# 1644 NP_060583.2 Already existis
# 1645 NP_000477.1 Already existis
# 1646 NP_003067.3 Already existis
# 1647 NP_055006.1 Already existis
# 1648 NP_000414.2 Already existis
# 1649 NP_002896.2 Already existis
# 1650 NP_001027558.1 Already existis
# 1651 NP_001973.2 Already existis
# 1652 NP_004975.2 Already existis
# 1653 NP_005717.3 Already existis
# 1654 NP_002067.1 Already existis
# 1655 NP_055134.2 Already existis
# 1656 NP_001026849.1 Already existis
# 1657 NP_065134.1 Already existis
# 1658 NP_647480.1 Already existis
# 1659 NP_001193908.1 Already existis
# 1660 NP_002456.2 Already existis
# 1661 NP_443077.1 Already existis
# 1662 NP_000422.1 Already existis
# 1663 NP_001076007.1 Already existis
# 1664 NP_001359503.1 Already existis
# 1665 NP_002825.3 Already existis
# 1666 NP_005987.3 Already existis
# 1667 NP_000008.1 Already existis
# 1668 NP_001340274.1 Already existis
# 1669 NP_079085.2 Already existis
# 1670 NP_036595.2 Already existis
# 1671 NP_079491.2 Already existis
# 1672 NP_005923.3 Already existis
# 1673 NP_001251.1 Already existis
# 1674 NP_000200.1 Already existis
# 1675 NP_919299.3 Already existis
# 1676 NP_997244.4 Already existis
# 1677 NP_055120.1 Already existis
# 1678 NP_009060.2 Already existis
# 1679 NP_996820.1 Already existis
# 1680 NP_062562.1 Already existis
# 1681 NP_060277.1 Already existis
# 1682 NP_001092744.1 Already existis
# 1683 NP_002733.2 Already existis
# 1684 NP_002854.3 Already existis
# 1685 NP_001193.2 Already existis
# 1686 NP_060269.3 Already existis
# 1687 NP_068374.1 Already existis
# 1688 NP_005973.1 Already existis
# 1689 NP_001521.1 Already existis
# 1690 NP_647479.2 Already existis
# 1691 NP_056161.2 Already existis
# 1692 NP_060261.2 Already existis
# 1693 NP_078772.1 Already existis
# 1694 NP_037514.2 Already existis
# 1695 NP_004854.1 Already existis
# 1696 NP_000286.3 Already existis
# 1697 NP_003375.1 Already existis
# 1698 NP_612808.1 Already existis
# 1699 NP_001357524.1 Already existis
# 1700 NP_001369359.1 Already existis
# 1701 NP_002217.3 Already existis
# 1702 NP_001510.2 Already existis
# 1703 NP_570854.1 Already existis
# 1704 NP_055782.3 Already existis
# 1705 NP_001238953.1 Already existis
# 1706 NP_005150.1 Already existis
# 1707 NP_733775.1 Already existis
# 1708 NP_689661.1 Already existis
# 1709 NP_997464.2 Already existis
# 1710 NP_001473.1 Already existis
# 1711 NP_076968.2 Already existis
# 1712 NP_000227.2 Already existis
# 1713 NP_004989.2 Already existis
# 1714 NP_001018005.1 Already existis
# 1715 NP_000933.1 Already existis
# 1716 NP_005893.1 Already existis
# 1717 NP_060352.1 Already existis
# 1718 NP_000772.2 Already existis
# 1719 NP_001138830.1 Already existis
# 1720 NP_000741.1 Already existis
# 1721 NP_001356197.1 Already existis
# 1722 NP_001106849.1 Already existis
# 1723 NP_000048.1 Already existis
# 1724 NP_620688.2 Already existis
# 1725 NP_066921.2 Already existis
# 1726 NP_076425.1 Already existis
# 1727 NP_001752.2 Already existis
# 1728 NP_001186036.1 Already existis
# 1729 NP_003461.2 Already existis
# 1730 NP_001129944.1 Already existis
# 1731 NP_005227.1 Already existis
# 1732 NP_002573.1 Already existis
# 1733 NP_001077083.1 Already existis
# 1734 NP_078951.2 Already existis
# 1735 NP_001035897.1 Already existis
# 1736 NP_015556.1 Already existis
# 1737 NP_660282.2 Already existis
# 1738 NP_009005.1 Already existis
# 1739 NP_006653.2 Already existis
# 1740 NP_000285.1 Already existis
# 1741 NP_055527.1 Already existis
# 1742 NP_443106.1 Already existis
# 1743 NP_597700.1 Already existis
# 1744 NP_003022.3 Already existis
# 1745 NP_002959.2 Already existis
# 1746 NP_114091.4 Already existis
# 1747 NP_055484.3 Already existis
# 1748 NP_958933.1 Already existis
# 1749 NP_037374.1 Already existis
# 1750 NP_000187.3 Already existis
# 1751 NP_006556.1 Already existis
# 1752 NP_061896.1 Already existis
# 1753 NP_001119.3 Already existis
# 1754 NP_002652.2 Already existis
# 1755 NP_000092.2 Already existis
# 1756 NP_001136336.2 Already existis
# 1757 NP_000968.2 Already existis
# 1758 NP_542435.2 Already existis
# 1759 NP_000738.2 Already existis
# 1760 NP_001335645.1 Already existis
# 1761 NP_001242941.1 Already existis
# 1762 NP_002461.2 Already existis
# 1763 NP_001363.2 Already existis
# 1764 NP_001036162.1 Already existis
# 1765 NP_004269.1 Already existis
# 1766 NP_659434.2 Already existis
# 1767 NP_109590.3 Already existis
# 1768 NP_002009.1 Already existis
# 1769 NP_056496.1 Already existis
# 1770 NP_001230368.1 Already existis
# 1771 NP_065842.1 Already existis
# 1772 NP_056170.2 Already existis
# 1773 NP_001253981.1 Already existis
# 1774 NP_942131.1 Already existis
# 1775 NP_219487.3 Already existis
# 1776 NP_003070.3 Already existis
# 1777 NP_000217.2 Already existis
# 1778 NP_000517.3 Already existis
# 1779 NP_068758.3 Already existis
# 1780 NP_009225.1 Already existis
# 1781 NP_001073143.1 Already existis
# 1782 NP_612396.1 Already existis
# 1783 NP_056258.1 Already existis
# 1784 NP_003387.1 Already existis
# 1785 NP_001007229.1 Already existis
# 1786 NP_061496.2 Already existis
# 1787 NP_003638.1 Already existis
# 1788 NP_114432.2 Already existis
# 1789 NP_006843.2 Already existis
# 1790 NP_000506.2 Already existis
# 1791 NP_872579.2 Already existis
# 1792 NP_060035.2 Already existis
# 1793 NP_000882.1 Already existis
# 1794 NP_954712.1 Already existis
# 1795 NP_001153245.1 Already existis
# 1796 NP_000909.2 Already existis
# 1797 NP_008838.2 Already existis
# 1798 NP_005550.2 Already existis
# 1799 NP_066552.2 Already existis
# 1800 NP_001136438.1 Already existis
# 1801 NP_002885.1 Already existis
# 1802 NP_085135.1 Already existis
# 1803 NP_055083.1 Already existis
# 1804 NP_005350.1 Already existis
# 1805 NP_004530.1 Already existis
# 1806 NP_001361314.1 Already existis
# 1807 NP_005903.2 Already existis
# 1808 NP_003830.1 Already existis
# 1809 NP_775901.3 Already existis
# 1810 NP_077718.3 Already existis
# 1811 NP_001051.1 Already existis
# 1812 NP_001952.1 Already existis
# 1813 NP_109587.1 Already existis
# 1814 NP_115484.2 Already existis
# 1815 NP_783313.1 Already existis
# 1816 NP_006003.1 Already existis
# 1817 NP_000055.2 Already existis
# 1818 NP_000199.2 Already existis
# 1819 NP_001124295.1 Already existis
# 1820 NP_001005361.1 Already existis
# 1821 NP_001276033.1 Already existis
# 1822 NP_000519.2 Already existis
# 1823 NP_001369170.1 Already existis
# 1824 NP_443108.1 Already existis
# 1825 NP_775754.2 Already existis
# 1826 NP_001073890.2 Already existis
# 1827 NP_004741.1 Already existis
# 1828 NP_001483.3 Already existis
# 1829 NP_001371457.1 Already existis
# 1830 NP_113636.2 Already existis
# 1831 NP_644813.1 Already existis
# 1832 NP_004482.4 Already existis
# 1833 NP_008990.2 Already existis
# 1834 NP_004968.2 Already existis
# 1835 NP_055040.2 Already existis
# 1836 NP_055331.1 Already existis
# 1837 NP_001243644.1 Already existis
# 1838 NP_009210.1 Already existis
# 1839 NP_945345.2 Already existis
# 1840 NP_000302.1 Already existis
# 1841 NP_001364071.1 Already existis
# 1842 NP_740754.1 Already existis
# 1843 NP_006354.2 Already existis
# 1844 NP_003089.1 Already existis
# 1845 NP_001269862.1 Already existis
# 1846 NP_000169.1 Already existis
# 1847 NP_542119.1 Already existis
# 1848 NP_000013.2 Already existis
# 1849 NP_065759.1 Already existis
# 1850 NP_059142.3 Already existis
# 1851 NP_000475.1 Already existis
# 1852 NP_005060.1 Already existis
# 1853 NP_000062.1 Already existis
# 1854 NP_056074.1 Already existis
# 1855 NP_001121121.1 Already existis
# 1856 NP_004773.1 Already existis
# 1857 NP_002736.3 Already existis
# 1858 NP_003064.2 Already existis
# 1859 NP_001878.1 Already existis
# 1860 NP_001877.1 Already existis
# 1861 NP_002421.3 Already existis
# 1862 NP_002863.1 Already existis
# 1863 NP_001365347.1 Already existis
# 1864 NP_060476.2 Already existis
# 1865 NP_061868.1 Already existis
# 1866 NP_758448.1 Already existis
# 1867 NP_001307681.2 Already existis
# 1868 NP_001821.2 Already existis
# 1869 NP_000283.1 Already existis
# 1870 NP_004586.2 Already existis
# 1871 NP_001406.1 Already existis
# 1872 NP_000466.2 Already existis
# 1873 NP_003997.2 Already existis
# 1874 NP_005756.2 Already existis
# 1875 NP_001034680.2 Already existis
# 1876 NP_001278344.1 Already existis
# 1877 NP_001129470.1 Already existis
# 1878 NP_005667.2 Already existis
# 1879 NP_008881.2 Already existis
# 1880 NP_982301.1 Already existis
# 1881 NP_001027554.1 Already existis
# 1882 NP_001129629.1 Already existis
# 1883 NP_003170.1 Already existis
# 1884 NP_001121370.1 Already existis
# 1885 NP_001104595.1 Already existis
# 1886 NP_113584.3 Already existis
# 1887 NP_002538.1 Already existis
# 1888 NP_000197.1 Already existis
# 1889 NP_000298.3 Already existis
# 1890 NP_001004051.1 Already existis
# 1891 NP_004771.2 Already existis
# 1892 NP_002755.1 Already existis
# 1893 NP_001137453.1 Already existis
# 1894 NP_001011551.1 Already existis
# 1895 NP_001075019.1 Already existis
# 1896 NP_001036215.1 Already existis
# 1897 NP_004199.1 Already existis
# 1898 NP_004475.1 Already existis
# 1899 NP_001366039.1 Already existis
# 1900 NP_003404.1 Already existis
# 1901 NP_004105.1 Already existis
# 1902 NP_115928.1 Already existis
# 1903 NP_002015.1 Already existis
# 1904 NP_002016.2 Already existis
# 1905 NP_001702.1 Already existis
# 1906 NP_003482.1 Already existis
# 1907 NP_004690.1 Already existis
# 1908 NP_000393.4 Already existis
# 1909 NP_001093327.1 Already existis
# 1910 NP_003131.1 Already existis
# #-unique NCBI protein sequences downloaded:  1911

# %%
# filtering on seq-len <= 1022
data = []
n_prots = len(protein_acc_list)
for i, prot in enumerate(protein_acc_list):
    filepath = home_dir+f"data/proteins/fastas/{prot}.fasta" 
    seq_record = SeqIO.parse(filepath, format="fasta").__next__()
    seq = str(seq_record.seq)
    seq_len = len(seq)
    if seq_len<=1022:
        print(f"{i}/{n_prots}")
        x = variations_df[variations_df['prot_acc_version']==prot].copy()
        x["seq_len"] = int(seq_len)
        x["seq"] = seq
        data.append(x)
variations_df = pd.concat(data)
variations_df["class"].value_counts()
# Out:
# Likely-pathogenic    4168
# Pathogenic           2308
# Name: class, dtype: int64

# %%
# saving variants and combined fasta file
filename = "patho_and_likelypatho"
out_filepath = home_dir+f"models/aa_common/datasets_pathogenicity/{filename}"

print("\nLog: saving variants ...")
variations_df.to_csv(out_filepath+".tsv", index=False, sep="\t", header=True)


print("\nLog: Creating merged fasta document ...")
protein_acc_list = list(variations_df["prot_acc_version"].unique())
create_combined_fasta(protein_acc_list, out_filepath+".fasta", home_dir)
# Out:
# Log: saving variants ...
#
# Log: Creating merged fasta document ...
# 0 NP_001381642.1 Already existis
# 1 NP_542172.2 Already existis
# 2 NP_001164006.1 Already existis
# 3 NP_002065.1 Already existis
# 4 NP_000806.2 Already existis
# 5 NP_003027.1 Already existis
# 6 NP_002608.1 Already existis
# 7 NP_009193.2 Already existis
# 8 NP_004276.2 Already existis
# 9 NP_005948.3 Already existis
# 10 NP_055689.1 Already existis
# 11 NP_009203.2 Already existis
# 12 NP_000076.2 Already existis
# 13 NP_002991.2 Already existis
# 14 NP_000469.3 Already existis
# 15 NP_001782.1 Already existis
# 16 NP_005817.1 Already existis
# 17 NP_000138.2 Already existis
# 18 NP_065184.2 Already existis
# 19 NP_060116.2 Already existis
# 20 NP_116182.2 Already existis
# 21 NP_000301.1 Already existis
# 22 NP_683763.2 Already existis
# 23 NP_006507.2 Already existis
# 24 NP_060620.2 Already existis
# 25 NP_000365.3 Already existis
# 26 NP_116145.1 Already existis
# 27 NP_060209.4 Already existis
# 28 NP_000089.1 Already existis
# 29 NP_000783.2 Already existis
# 30 NP_777596.2 Already existis
# 31 NP_002624.2 Already existis
# 32 NP_000320.1 Already existis
# 33 NP_000007.1 Already existis
# 34 NP_891993.1 Already existis
# 35 NP_000960.2 Already existis
# 36 NP_036375.1 Already existis
# 37 NP_001909.4 Already existis
# 38 NP_057042.2 Already existis
# 39 NP_006504.2 Already existis
# 40 NP_001010898.1 Already existis
# 41 NP_004965.1 Already existis
# 42 NP_073747.1 Already existis
# 43 NP_000189.1 Already existis
# 44 NP_006614.2 Already existis
# 45 NP_003837.1 Already existis
# 46 NP_005258.2 Already existis
# 47 NP_079426.2 Already existis
# 48 NP_000387.1 Already existis
# 49 NP_067045.1 Already existis
# 50 NP_076946.1 Already existis
# 51 NP_000739.1 Already existis
# 52 NP_000148.2 Already existis
# 53 NP_000289.1 Already existis
# 54 NP_008843.1 Already existis
# 55 NP_733821.1 Already existis
# 56 NP_658985.2 Already existis
# 57 NP_002520.2 Already existis
# 58 NP_000693.1 Already existis
# 59 NP_002848.1 Already existis
# 60 NP_001116236.1 Already existis
# 61 NP_000521.2 Already existis
# 62 NP_002992.1 Already existis
# 63 NP_002576.1 Already existis
# 64 NP_796372.1 Already existis
# 65 NP_061899.3 Already existis
# 66 NP_000252.1 Already existis
# 67 NP_060592.2 Already existis
# 68 NP_000479.1 Already existis
# 69 NP_055440.1 Already existis
# 70 NP_000424.2 Already existis
# 71 NP_001985.2 Already existis
# 72 NP_001263274.1 Already existis
# 73 NP_057083.2 Already existis
# 74 NP_002247.3 Already existis
# 75 NP_006138.1 Already existis
# 76 NP_758872.1 Already existis
# 77 NP_054772.1 Already existis
# 78 NP_055991.1 Already existis
# 79 NP_002287.2 Already existis
# 80 NP_055513.2 Already existis
# 81 NP_002098.1 Already existis
# 82 NP_002212.3 Already existis
# 83 NP_001649.1 Already existis
# 84 NP_065168.2 Already existis
# 85 NP_001091.1 Already existis
# 86 NP_000134.2 Already existis
# 87 NP_005456.1 Already existis
# 88 NP_932342.1 Already existis
# 89 NP_114032.2 Already existis
# 90 NP_001071178.2 Already existis
# 91 NP_003099.1 Already existis
# 92 NP_057291.1 Already existis
# 93 NP_072046.2 Already existis
# 94 NP_000174.1 Already existis
# 95 NP_006479.1 Already existis
# 96 NP_000339.2 Already existis
# 97 NP_055761.2 Already existis
# 98 NP_001129123.1 Already existis
# 99 NP_000095.2 Already existis
# 100 NP_008818.3 Already existis
# 101 NP_000332.2 Already existis
# 102 NP_001421.2 Already existis
# 103 NP_065191.2 Already existis
# 104 NP_001734.1 Already existis
# 105 NP_000242.1 Already existis
# 106 NP_000224.2 Already existis
# 107 NP_149100.2 Already existis
# 108 NP_075044.2 Already existis
# 109 NP_003029.2 Already existis
# 110 NP_001606.1 Already existis
# 111 NP_550438.1 Already existis
# 112 NP_003840.2 Already existis
# 113 NP_000812.2 Already existis
# 114 NP_000533.4 Already existis
# 115 NP_001358208.1 Already existis
# 116 NP_060319.1 Already existis
# 117 NP_110432.1 Already existis
# 118 NP_064569.3 Already existis
# 119 NP_001289.1 Already existis
# 120 NP_006227.1 Already existis
# 121 NP_071731.1 Already existis
# 122 NP_000303.1 Already existis
# 123 NP_525125.2 Already existis
# 124 NP_003928.1 Already existis
# 125 NP_004513.1 Already existis
# 126 NP_006177.1 Already existis
# 127 NP_006584.1 Already existis
# 128 NP_004473.2 Already existis
# 129 NP_689597.1 Already existis
# 130 NP_003696.2 Already existis
# 131 NP_003681.1 Already existis
# 132 NP_001036167.1 Already existis
# 133 NP_963842.1 Already existis
# 134 NP_009330.1 Already existis
# 135 NP_001165980.1 Already existis
# 136 NP_054859.2 Already existis
# 137 NP_005435.1 Already existis
# 138 NP_001073335.1 Already existis
# 139 NP_000775.1 Already existis
# 140 NP_079492.2 Already existis
# 141 NP_002172.2 Already existis
# 142 NP_001918.3 Already existis
# 143 NP_037467.2 Already existis
# 144 NP_852123.1 Already existis
# 145 NP_005678.3 Already existis
# 146 NP_849143.1 Already existis
# 147 NP_004817.2 Already existis
# 148 NP_000742.1 Already existis
# 149 NP_000454.1 Already existis
# 150 NP_000021.1 Already existis
# 151 NP_036277.2 Already existis
# 152 NP_689996.4 Already existis
# 153 NP_000542.1 Already existis
# 154 NP_003033.3 Already existis
# 155 NP_001336161.1 Already existis
# 156 NP_001271330.1 Already existis
# 157 NP_619725.3 Already existis
# 158 NP_001357587.1 Already existis
# 159 NP_002962.1 Already existis
# 160 NP_001341641.1 Already existis
# 161 NP_000956.2 Already existis
# 162 NP_060767.2 Already existis
# 163 NP_003233.4 Already existis
# 164 NP_000395.3 Already existis
# 165 NP_006362.1 Already existis
# 166 NP_000240.1 Already existis
# 167 NP_660149.2 Already existis
# 168 NP_116195.2 Already existis
# 169 NP_060545.3 Already existis
# 170 NP_003269.2 Already existis
# 171 NP_056155.1 Already existis
# 172 NP_005042.1 Already existis
# 173 NP_000472.2 Already existis
# 174 NP_006832.1 Already existis
# 175 NP_056980.2 Already existis
# 176 NP_056241.3 Already existis
# 177 NP_004647.1 Already existis
# 178 NP_003271.1 Already existis
# 179 NP_001336267.1 Already existis
# 180 NP_060600.2 Already existis
# 181 NP_000149.4 Already existis
# 182 NP_000304.2 Already existis
# 183 NP_001167621.1 Already existis
# 184 NP_001265222.1 Already existis
# 185 NP_006061.2 Already existis
# 186 NP_001681.2 Already existis
# 187 NP_001335729.1 Already existis
# 188 NP_000178.2 Already existis
# 189 NP_037468.1 Already existis
# 190 NP_054768.2 Already existis
# 191 NP_000165.1 Already existis
# 192 NP_000530.1 Already existis
# 193 NP_001365616.1 Already existis
# 194 NP_079094.1 Already existis
# 195 NP_000523.2 Already existis
# 196 NP_004757.1 Already existis
# 197 NP_000676.1 Already existis
# 198 NP_777367.1 Already existis
# 199 NP_001258767.1 Already existis
# 200 NP_001116224.1 Already existis
# 201 NP_000331.1 Already existis
# 202 NP_078941.2 Already existis
# 203 NP_003097.1 Already existis
# 204 NP_064551.3 Already existis
# 205 NP_003898.2 Already existis
# 206 NP_000451.1 Already existis
# 207 NP_004445.1 Already existis
# 208 NP_001613.2 Already existis
# 209 NP_003713.3 Already existis
# 210 NP_570850.2 Already existis
# 211 NP_940967.1 Already existis
# 212 NP_002568.2 Already existis
# 213 NP_001120650.1 Already existis
# 214 NP_000194.2 Already existis
# 215 NP_071325.2 Already existis
# 216 NP_000133.1 Already existis
# 217 NP_036450.1 Already existis
# 218 NP_775931.3 Already existis
# 219 NP_005996.2 Already existis
# 220 NP_000311.2 Already existis
# 221 NP_003915.2 Already existis
# 222 NP_000798.2 Already existis
# 223 NP_000223.1 Already existis
# 224 NP_001072992.1 Already existis
# 225 NP_001544.1 Already existis
# 226 NP_000397.1 Already existis
# 227 NP_004398.1 Already existis
# 228 NP_001194.1 Already existis
# 229 NP_000935.1 Already existis
# 230 NP_001128618.1 Already existis
# 231 NP_003989.2 Already existis
# 232 NP_000195.3 Already existis
# 233 NP_000316.2 Already existis
# 234 NP_001308500.1 Already existis
# 235 NP_005024.2 Already existis
# 236 NP_001124170.1 Already existis
# 237 NP_660208.2 Already existis
# 238 NP_758454.1 Already existis
# 239 NP_001336727.1 Already existis
# 240 NP_000815.1 Already existis
# 241 NP_001077088.2 Already existis
# 242 NP_004444.2 Already existis
# 243 NP_006736.1 Already existis
# 244 NP_004468.1 Already existis
# 245 NP_004159.2 Already existis
# 246 NP_001003841.1 Already existis
# 247 NP_004544.1 Already existis
# 248 NP_060225.4 Already existis
# 249 NP_612357.4 Already existis
# 250 NP_006718.2 Already existis
# 251 NP_057264.4 Already existis
# 252 NP_002176.2 Already existis
# 253 NP_001007528.1 Already existis
# 254 NP_066550.2 Already existis
# 255 NP_789776.1 Already existis
# 256 NP_002175.2 Already existis
# 257 NP_001098101.1 Already existis
# 258 NP_000335.1 Already existis
# 259 NP_071415.1 Already existis
# 260 NP_000512.2 Already existis
# 261 NP_000037.2 Already existis
# 262 NP_002388.2 Already existis
# 263 NP_005645.1 Already existis
# 264 NP_937793.1 Already existis
# 265 NP_000430.3 Already existis
# 266 NP_067627.3 Already existis
# 267 NP_000405.1 Already existis
# 268 NP_001173.2 Already existis
# 269 NP_001017372.1 Already existis
# 270 NP_005331.1 Already existis
# 271 NP_003051.1 Already existis
# 272 NP_078991.3 Already existis
# 273 NP_000349.1 Already existis
# 274 NP_938023.1 Already existis
# 275 NP_005850.1 Already existis
# 276 NP_061751.1 Already existis
# 277 NP_000103.2 Already existis
# 278 NP_001275634.1 Already existis
# 279 NP_057065.2 Already existis
# 280 NP_001534.1 Already existis
# 281 NP_000162.2 Already existis
# 282 NP_001358656.1 Already existis
# 283 NP_001121116.1 Already existis
# 284 NP_944494.1 Already existis
# 285 NP_002878.2 Already existis
# 286 NP_004378.1 Already existis
# 287 NP_057306.2 Already existis
# 288 NP_000834.2 Already existis
# 289 NP_001244222.1 Already existis
# 290 NP_003891.1 Already existis
# 291 NP_001444.2 Already existis
# 292 NP_001060.1 Already existis
# 293 NP_821080.1 Already existis
# 294 NP_112210.1 Already existis
# 295 NP_003098.1 Already existis
# 296 NP_001071.1 Already existis
# 297 NP_000401.1 Already existis
# 298 NP_003533.1 Already existis
# 299 NP_068803.1 Already existis
# 300 NP_001311.3 Already existis
# 301 NP_751898.1 Already existis
# 302 NP_000425.1 Already existis
# 303 NP_000491.4 Already existis
# 304 NP_002115.2 Already existis
# 305 NP_008910.2 Already existis
# 306 NP_003313.3 Already existis
# 307 NP_443193.1 Already existis
# 308 NP_001361552.1 Already existis
# 309 NP_001012426.1 Already existis
# 310 NP_001371839.1 Already existis
# 311 NP_000313.2 Already existis
# 312 NP_000278.3 Already existis
# 313 NP_006236.1 Already existis
# 314 NP_689945.2 Already existis
# 315 NP_065796.2 Already existis
# 316 NP_001019801.3 Already existis
# 317 NP_000246.2 Already existis
# 318 NP_062816.2 Already existis
# 319 NP_036566.1 Already existis
# 320 NP_001116241.1 Already existis
# 321 NP_898871.1 Already existis
# 322 NP_006407.1 Already existis
# 323 NP_064716.2 Already existis
# 324 NP_067067.1 Already existis
# 325 NP_663304.1 Already existis
# 326 NP_065822.2 Already existis
# 327 NP_001186492.1 Already existis
# 328 NP_116119.2 Already existis
# 329 NP_937882.2 Already existis
# 330 NP_000484.2 Already existis
# 331 NP_001035940.1 Already existis
# 332 NP_000156.1 Already existis
# 333 NP_006064.2 Already existis
# 334 NP_000036.2 Already existis
# 335 NP_006199.2 Already existis
# 336 NP_004091.3 Already existis
# 337 NP_055554.1 Already existis
# 338 NP_005661.1 Already existis
# 339 NP_116250.3 Already existis
# 340 NP_001258791.1 Already existis
# 341 NP_002784.1 Already existis
# 342 NP_064608.2 Already existis
# 343 NP_001092.1 Already existis
# 344 NP_996994.1 Already existis
# 345 NP_000526.2 Already existis
# 346 NP_000465.1 Already existis
# 347 NP_001026880.2 Already existis
# 348 NP_002038.2 Already existis
# 349 NP_940820.1 Already existis
# 350 NP_005393.2 Already existis
# 351 NP_000153.1 Already existis
# 352 NP_000587.1 Already existis
# 353 NP_001076440.2 Already existis
# 354 NP_000172.2 Already existis
# 355 NP_000039.2 Already existis
# 356 NP_694578.1 Already existis
# 357 NP_036611.2 Already existis
# 358 NP_002060.4 Already existis
# 359 NP_919436.1 Already existis
# 360 NP_003910.1 Already existis
# 361 NP_055066.1 Already existis
# 362 NP_001664.3 Already existis
# 363 NP_057272.1 Already existis
# 364 NP_004435.3 Already existis
# 365 NP_000432.1 Already existis
# 366 NP_000102.1 Already existis
# 367 NP_000099.2 Already existis
# 368 NP_001159817.1 Already existis
# 369 NP_036413.1 Already existis
# 370 NP_000874.2 Already existis
# 371 NP_065683.2 Already existis
# 372 NP_004324.2 Already existis
# 373 NP_002760.1 Already existis
# 374 NP_000074.3 Already existis
# 375 NP_071890.2 Already existis
# 376 NP_004447.2 Already existis
# 377 NP_060854.2 Already existis
# 378 NP_005605.1 Already existis
# 379 NP_057287.2 Already existis
# 380 NP_570629.2 Already existis
# 381 NP_005506.3 Already existis
# 382 NP_490647.1 Already existis
# 383 NP_001295022.1 Already existis
# 384 NP_000228.1 Already existis
# 385 NP_001684.2 Already existis
# 386 NP_001381061.1 Already existis
# 387 NP_644807.1 Already existis
# 388 NP_001304707.1 Already existis
# 389 NP_006120.1 Already existis
# 390 NP_001121903.1 Already existis
# 391 NP_001076580.1 Already existis
# 392 NP_000628.2 Already existis
# 393 NP_001095871.1 Already existis
# 394 NP_075598.2 Already existis
# 395 NP_060575.1 Already existis
# 396 NP_112216.3 Already existis
# 397 NP_689632.2 Already existis
# 398 NP_002341.1 Already existis
# 399 NP_061845.2 Already existis
# 400 NP_061971.3 Already existis
# 401 NP_714915.3 Already existis
# 402 NP_002559.2 Already existis
# 403 NP_848660.3 Already existis
# 404 NP_000118.2 Already existis
# 405 NP_004510.1 Already existis
# 406 NP_000488.3 Already existis
# 407 NP_000489.3 Already existis
# 408 NP_835466.2 Already existis
# 409 NP_003792.1 Already existis
# 410 NP_036211.2 Already existis
# 411 NP_598004.1 Already existis
# 412 NP_000161.2 Already existis
# 413 NP_000068.1 Already existis
# 414 NP_478102.2 Already existis
# 415 NP_001161.1 Already existis
# 416 NP_000146.2 Already existis
# 417 NP_009057.1 Already existis
# 418 NP_005467.1 Already existis
# 419 NP_036335.1 Already existis
# 420 NP_619636.2 Already existis
# 421 NP_002063.2 Already existis
# 422 NP_112553.1 Already existis
# 423 NP_001003800.1 Already existis
# 424 NP_000498.2 Already existis
# 425 NP_004603.1 Already existis
# 426 NP_149078.1 Already existis
# 427 NP_000026.2 Already existis
# 428 NP_937895.1 Already existis
# 429 NP_004950.2 Already existis
# 430 NP_001167618.1 Already existis
# 431 NP_001027392.1 Already existis
# 432 NP_001108225.1 Already existis
# 433 NP_057119.3 Already existis
# 434 NP_000104.1 Already existis
# 435 NP_446464.1 Already existis
# 436 NP_067632.2 Already existis
# 437 NP_001070833.1 Already existis
# 438 NP_001364233.1 Already existis
# 439 NP_003163.1 Already existis
# 440 NP_063945.2 Already existis
# 441 NP_006403.2 Already existis
# 442 NP_015566.1 Already existis
# 443 NP_001170787.2 Already existis
# 444 NP_001357029.1 Already existis
# 445 NP_001002295.1 Already existis
# 446 NP_001313271.1 Already existis
# 447 NP_001029027.1 Already existis
# 448 NP_004512.1 Already existis
# 449 NP_065574.4 Already existis
# 450 NP_060715.2 Already existis
# 451 NP_000390.2 Already existis
# 452 NP_000179.2 Already existis
# 453 NP_001076585.1 Already existis
# 454 NP_002769.1 Already existis
# 455 NP_148982.1 Already existis
# 456 NP_000420.1 Already existis
# 457 NP_149091.1 Already existis
# 458 NP_001015880.1 Already existis
# 459 NP_000305.3 Already existis
# 460 NP_000034.1 Already existis
# 461 NP_000226.2 Already existis
# 462 NP_006195.3 Already existis
# 463 NP_002851.2 Already existis
# 464 NP_056446.4 Already existis
# 465 NP_612422.2 Already existis
# 466 NP_000186.2 Already existis
# 467 NP_068602.2 Already existis
# 468 NP_000093.1 Already existis
# 469 NP_001338098.1 Already existis
# 470 NP_862823.1 Already existis
# 471 NP_006784.1 Already existis
# 472 NP_000132.3 Already existis
# 473 NP_002766.1 Already existis
# 474 NP_001359052.1 Already existis
# 475 NP_000265.1 Already existis
# 476 NP_073713.2 Already existis
# 477 NP_000366.1 Already existis
# 478 NP_001362309.1 Already existis
# 479 NP_796374.2 Already existis
# 480 NP_004083.3 Already existis
# 481 NP_066288.2 Already existis
# 482 NP_665893.2 Already existis
# 483 NP_000603.1 Already existis
# 484 NP_000198.1 Already existis
# 485 NP_000351.2 Already existis
# 486 NP_000209.2 Already existis
# 487 NP_000534.3 Already existis
# 488 NP_000382.3 Already existis
# 489 NP_036382.2 Already existis
# 490 NP_001137533.1 Already existis
# 491 NP_000516.3 Already existis
# 492 NP_001106212.1 Already existis
# 493 NP_004202.4 Already existis
# 494 NP_998764.1 Already existis
# 495 NP_073562.1 Already existis
# 496 NP_113606.2 Already existis
# 497 NP_001355823.1 Already existis
# 498 NP_077744.4 Already existis
# 499 NP_000527.2 Already existis
# 500 NP_068745.2 Already existis
# 501 NP_002795.2 Already existis
# 502 NP_005046.2 Already existis
# 503 NP_000053.2 Already existis
# 504 NP_945185.1 Already existis
# 505 NP_004174.1 Already existis
# 506 NP_036332.2 Already existis
# 507 NP_938148.1 Already existis
# 508 NP_201567.1 Already existis
# 509 NP_001092141.1 Already existis
# 510 NP_005600.1 Already existis
# 511 NP_001357188.2 Already existis
# 512 NP_058634.4 Already existis
# 513 NP_006833.2 Already existis
# 514 NP_060496.2 Already existis
# 515 NP_078925.3 Already existis
# 516 NP_009034.2 Already existis
# 517 NP_001867.2 Already existis
# 518 NP_002171.2 Already existis
# 519 NP_001351.2 Already existis
# 520 NP_057941.1 Already existis
# 521 NP_001245321.1 Already existis
# 522 NP_076984.2 Already existis
# 523 NP_003788.2 Already existis
# 524 NP_036325.2 Already existis
# 525 NP_001805.4 Already existis
# 526 NP_000363.1 Already existis
# 527 NP_004612.2 Already existis
# 528 NP_001123617.1 Already existis
# 529 NP_000820.4 Already existis
# 530 NP_000010.1 Already existis
# 531 NP_079016.2 Already existis
# 532 NP_001276737.1 Already existis
# 533 NP_002993.1 Already existis
# 534 NP_000308.1 Already existis
# 535 NP_000030.1 Already existis
# 536 NP_001549.2 Already existis
# 537 NP_000181.2 Already existis
# 538 NP_001373.2 Already existis
# 539 NP_001265360.1 Already existis
# 540 NP_079045.1 Already existis
# 541 NP_689926.1 Already existis
# 542 NP_722450.1 Already existis
# 543 NP_068813.1 Already existis
# 544 NP_055199.1 Already existis
# 545 NP_003315.2 Already existis
# 546 NP_000208.2 Already existis
# 547 NP_008871.3 Already existis
# 548 NP_004976.2 Already existis
# 549 NP_036192.2 Already existis
# 550 NP_001005242.2 Already existis
# 551 NP_000367.1 Already existis
# 552 NP_001650.1 Already existis
# 553 NP_005421.1 Already existis
# 554 NP_066382.1 Already existis
# 555 NP_006000.2 Already existis
# 556 NP_001306928.1 Already existis
# 557 NP_000011.2 Already existis
# 558 NP_000415.2 Already existis
# 559 NP_006112.3 Already existis
# 560 NP_056480.1 Already existis
# 561 NP_065434.1 Already existis
# 562 NP_001020.2 Already existis
# 563 NP_005410.1 Already existis
# 564 NP_001677.2 Already existis
# 565 NP_000776.1 Already existis
# 566 NP_776173.3 Already existis
# 567 NP_055069.1 Already existis
# 568 NP_037386.1 Already existis
# 569 NP_631875.1 Already existis
# 570 NP_078961.3 Already existis
# 571 NP_005630.1 Already existis
# 572 NP_000890.1 Already existis
# 573 NP_000268.1 Already existis
# 574 NP_067638.3 Already existis
# 575 NP_005466.1 Already existis
# 576 NP_058132.2 Already existis
# 577 NP_852259.1 Already existis
# 578 NP_000536.6 Already existis
# 579 NP_068773.2 Already existis
# 580 NP_003995.2 Already existis
# 581 NP_001103689.1 Already existis
# 582 NP_002001.1 Already existis
# 583 NP_000222.2 Already existis
# 584 NP_055902.1 Already existis
# 585 NP_037470.1 Already existis
# 586 NP_003841.1 Already existis
# 587 NP_000312.2 Already existis
# 588 NP_001155970.1 Already existis
# 589 NP_002258.2 Already existis
# 590 NP_005699.1 Already existis
# 591 NP_000273.2 Already existis
# 592 NP_001229811.1 Already existis
# 593 NP_000495.1 Already existis
# 594 NP_003973.3 Already existis
# 595 NP_001341569.1 Already existis
# 596 NP_001341697.1 Already existis
# 597 NP_000350.1 Already existis
# 598 NP_005240.3 Already existis
# 599 NP_004077.1 Already existis
# 600 NP_060387.2 Already existis
# 601 NP_055487.2 Already existis
# 602 NP_001073136.1 Already existis
# 603 NP_001359005.1 Already existis
# 604 NP_006355.2 Already existis
# 605 NP_079160.1 Already existis
# 606 NP_056999.2 Already existis
# 607 NP_000152.1 Already existis
# 608 NP_065861.3 Already existis
# 609 NP_065857.1 Already existis
# 610 NP_689656.2 Already existis
# 611 NP_001123476.1 Already existis
# 612 NP_000012.1 Already existis
# 613 NP_878314.1 Already existis
# 614 NP_005041.1 Already existis
# 615 NP_006423.1 Already existis
# 616 NP_001096034.1 Already existis
# 617 NP_000144.2 Already existis
# 618 NP_060888.2 Already existis
# 619 NP_002793.2 Already existis
# 620 NP_008819.1 Already existis
# 621 NP_006320.2 Already existis
# 622 NP_057501.2 Already existis
# 623 NP_003394.1 Already existis
# 624 NP_000805.1 Already existis
# 625 NP_000801.1 Already existis
# 626 NP_000266.2 Already existis
# 627 NP_002216.3 Already existis
# 628 NP_061947.1 Already existis
# 629 NP_000061.1 Already existis
# 630 NP_116281.2 Already existis
# 631 NP_995322.1 Already existis
# 632 NP_001020419.1 Already existis
# 633 NP_861454.2 Already existis
# 634 NP_057278.2 Already existis
# 635 NP_899058.1 Already existis
# 636 NP_996920.1 Already existis
# 637 NP_003879.2 Already existis
# 638 NP_001094832.1 Already existis
# 639 NP_002746.1 Already existis
# 640 NP_005576.3 Already existis
# 641 NP_001354734.1 Already existis
# 642 NP_079093.2 Already existis
# 643 NP_055064.1 Already existis
# 644 NP_000511.2 Already existis
# 645 NP_003603.1 Already existis
# 646 NP_116197.4 Already existis
# 647 NP_000128.1 Already existis
# 648 NP_001012.1 Already existis
# 649 NP_000317.1 Already existis
# 650 NP_001365718.1 Already existis
# 651 NP_000508.1 Already existis
# 652 NP_000549.1 Already existis
# 653 NP_001278.1 Already existis
# 654 NP_057195.2 Already existis
# 655 NP_115647.2 Already existis
# 656 NP_001685.1 Already existis
# 657 NP_061982.3 Already existis
# 658 NP_000294.1 Already existis
# 659 NP_003352.2 Already existis
# 660 NP_060206.2 Already existis
# 661 NP_000327.2 Already existis
# 662 NP_705831.1 Already existis
# 663 NP_004311.1 Already existis
# 664 NP_115564.2 Already existis
# 665 NP_004951.1 Already existis
# 666 NP_001098717.1 Already existis
# 667 NP_891552.1 Already existis
# 668 NP_001357395.1 Already existis
# 669 NP_005844.4 Already existis
# 670 NP_004521.1 Already existis
# 671 NP_066268.1 Already existis
# 672 NP_001119580.2 Already existis
# 673 NP_588609.1 Already existis
# 674 NP_001788.2 Already existis
# 675 NP_004605.4 Already existis
# 676 NP_003896.1 Already existis
# 677 NP_003780.1 Already existis
# 678 NP_001361604.1 Already existis
# 679 NP_004585.1 Already existis
# 680 NP_000220.1 Already existis
# 681 NP_004351.1 Already existis
# 682 NP_001596.2 Already existis
# 683 NP_077282.3 Already existis
# 684 NP_001070886.1 Already existis
# 685 NP_005539.1 Already existis
# 686 NP_057457.1 Already existis
# 687 NP_005351.2 Already existis
# 688 NP_001442.2 Already existis
# 689 NP_079011.3 Already existis
# 690 NP_000503.1 Already existis
# 691 NP_001230208.1 Already existis
# 692 NP_003110.1 Already existis
# 693 NP_006077.2 Already existis
# 694 NP_057616.2 Already existis
# 695 NP_002936.1 Already existis
# 696 NP_000421.1 Already existis
# 697 NP_000040.1 Already existis
# 698 NP_659505.1 Already existis
# 699 NP_004928.2 Already existis
# 700 NP_000071.1 Already existis
# 701 NP_000164.5 Already existis
# 702 NP_055151.3 Already existis
# 703 NP_808218.1 Already existis
# 704 NP_001308004.1 Already existis
# 705 NP_000009.1 Already existis
# 706 NP_000537.3 Already existis
# 707 NP_000295.1 Already existis
# 708 NP_000373.1 Already existis
# 709 NP_659731.1 Already existis
# 710 NP_001333683.1 Already existis
# 711 NP_000449.1 Already existis
# 712 NP_955366.1 Already existis
# 713 NP_000412.4 Already existis
# 714 NP_644805.1 Already existis
# 715 NP_001123493.1 Already existis
# 716 NP_000254.2 Already existis
# 717 NP_001061.2 Already existis
# 718 NP_000142.2 Already existis
# 719 NP_000333.1 Already existis
# 720 NP_002078.1 Already existis
# 721 NP_004238.3 Already existis
# 722 NP_002046.1 Already existis
# 723 NP_001247.3 Already existis
# 724 NP_000203.2 Already existis
# 725 NP_005211.1 Already existis
# 726 NP_000014.1 Already existis
# 727 NP_001308049.1 Already existis
# 728 NP_002392.2 Already existis
# 729 NP_002725.1 Already existis
# 730 NP_000337.1 Already existis
# 731 NP_694941.2 Already existis
# 732 NP_077728.3 Already existis
# 733 NP_001119593.1 Already existis
# 734 NP_005315.1 Already existis
# 735 NP_000143.2 Already existis
# 736 NP_000190.1 Already existis
# 737 NP_002513.2 Already existis
# 738 NP_001079990.1 Already existis
# 739 NP_001605.1 Already existis
# 740 NP_001362737.1 Already existis
# 741 NP_892023.1 Already existis
# 742 NP_006787.2 Already existis
# 743 NP_000362.1 Already existis
# 744 NP_060725.1 Already existis
# 745 NP_005892.1 Already existis
# 746 NP_001077431.1 Already existis
# 747 NP_000131.2 Already existis
# 748 NP_038463.2 Already existis
# 749 NP_001963.1 Already existis
# 750 NP_004359.1 Already existis
# 751 NP_000446.1 Already existis
# 752 NP_000147.1 Already existis
# 753 NP_000470.3 Already existis
# 754 NP_001137458.1 Already existis
# 755 NP_002058.2 Already existis
# 756 NP_001138637.1 Already existis
# 757 NP_057347.2 Already existis
# 758 NP_149053.1 Already existis
# 759 NP_056982.1 Already existis
# 760 NP_006078.2 Already existis
# 761 NP_001164626.1 Already existis
# 762 NP_008880.2 Already existis
# 763 NP_987096.1 Already existis
# 764 NP_000518.1 Already existis
# 765 NP_001602.1 Already existis
# 766 NP_006388.2 Already existis
# 767 NP_001366.1 Already existis
# 768 NP_000150.1 Already existis
# 769 NP_004452.1 Already existis
# 770 NP_001352831.1 Already existis
# 771 NP_612510.1 Already existis
# 772 NP_116009.2 Already existis
# 773 NP_005526.1 Already existis
# 774 NP_005018.2 Already existis
# 775 NP_000086.2 Already existis
# 776 NP_067090.1 Already existis
# 777 NP_055085.1 Already existis
# 778 NP_004355.2 Already existis
# 779 NP_000166.2 Already existis
# 780 NP_116024.1 Already existis
# 781 NP_066925.1 Already existis
# 782 NP_001001563.2 Already existis
# 783 NP_000651.3 Already existis
# 784 NP_000700.1 Already existis
# 785 NP_001013.1 Already existis
# 786 NP_689509.1 Already existis
# 787 NP_597701.1 Already existis
# 788 NP_055112.2 Already existis
# 789 NP_061981.2 Already existis
# 790 NP_000032.1 Already existis
# 791 NP_001369351.1 Already existis
# 792 NP_000391.1 Already existis
# 793 NP_005175.2 Already existis
# 794 NP_077277.1 Already existis
# 795 NP_000225.1 Already existis
# 796 NP_004908.4 Already existis
# 797 NP_001976.1 Already existis
# 798 NP_002730.1 Already existis
# 799 NP_056444.3 Already existis
# 800 NP_077274.3 Already existis
# 801 NP_000354.4 Already existis
# 802 NP_808227.1 Already existis
# 803 NP_212134.3 Already existis
# 804 NP_000481.2 Already existis
# 805 NP_001167560.1 Already existis
# 806 NP_001373322.1 Already existis
# 807 NP_001191.1 Already existis
# 808 NP_570824.1 Already existis
# 809 NP_057184.1 Already existis
# 810 NP_008823.1 Already existis
# 811 NP_110517.2 Already existis
# 812 NP_005452.2 Already existis
# 813 NP_787110.2 Already existis
# 814 NP_000299.3 Already existis
# 815 NP_110404.1 Already existis
# 816 NP_004966.1 Already existis
# 817 NP_000773.2 Already existis
# 818 NP_001710.1 Already existis
# 819 NP_000507.1 Already existis
# 820 NP_110400.1 Already existis
# 821 NP_742105.1 Already existis
# 822 NP_001949.1 Already existis
# 823 NP_079495.1 Already existis
# 824 NP_000445.1 Already existis
# 825 NP_060083.1 Already existis
# 826 NP_001745.2 Already existis
# 827 NP_001339443.1 Already existis
# 828 NP_001334650.1 Already existis
# 829 NP_001243246.1 Already existis
# 830 NP_543136.1 Already existis
# 831 NP_000374.1 Already existis
# 832 NP_659428.2 Already existis
# 833 NP_000202.3 Already existis
# 834 NP_001840.3 Already existis
# 835 NP_002331.3 Already existis
# 836 NP_001269154.1 Already existis
# 837 NP_061816.1 Already existis
# 838 NP_005975.1 Already existis
# 839 NP_000398.1 Already existis
# 840 NP_006758.2 Already existis
# 841 NP_057411.1 Already existis
# 842 NP_004067.1 Already existis
# 843 NP_000487.1 Already existis
# 844 NP_001118.3 Already existis
# 845 NP_000259.1 Already existis
# 846 NP_000334.1 Already existis
# 847 NP_000353.1 Already existis
# 848 NP_006069.1 Already existis
# 849 NP_008872.1 Already existis
# 850 NP_003551.2 Already existis
# 851 NP_000017.1 Already existis
# 852 NP_001089.1 Already existis
# 853 NP_055981.1 Already existis
# 854 NP_005129.2 Already existis
# 855 NP_001944.1 Already existis
# 856 NP_000478.3 Already existis
# 857 NP_000442.1 Already existis
# 858 NP_000038.2 Already existis
# 859 NP_000207.2 Already existis
# 860 NP_000264.2 Already existis
# 861 NP_005324.3 Already existis
# 862 NP_001133.1 Already existis
# 863 NP_002054.1 Already existis
# 864 NP_002632.1 Already existis
# 865 NP_001310218.1 Already existis
# 866 NP_000321.1 Already existis
# 867 NP_000275.1 Already existis
# 868 NP_004577.1 Already existis
# 869 NP_055147.1 Already existis
# 870 NP_000435.3 Already existis
# 871 NP_620689.1 Already existis
# 872 NP_000388.2 Already existis
# 873 NP_000522.3 Already existis
# 874 NP_001347.3 Already existis
# 875 NP_001354650.1 Already existis
# 876 NP_000257.1 Already existis
# 877 NP_008846.2 Already existis
# 878 NP_006570.1 Already existis
# 879 NP_000368.1 Already existis
# 880 NP_002040.1 Already existis
# 881 NP_005651.1 Already existis
# 882 NP_006512.2 Already existis
# 883 NP_001025067.1 Already existis
# 884 NP_054728.2 Already existis
# 885 NP_005439.2 Already existis
# 886 NP_004454.2 Already existis
# 887 NP_000023.2 Already existis
# 888 NP_038472.2 Already existis
# 889 NP_001340850.1 Already existis
# 890 NP_061154.1 Already existis
# 891 NP_000035.2 Already existis
# 892 NP_004420.1 Already existis
# 893 NP_001390.1 Already existis
# 894 NP_851820.1 Already existis
# 895 NP_000157.1 Already existis
# 896 NP_060956.1 Already existis
# 897 NP_006508.2 Already existis
# 898 NP_000282.1 Already existis
# 899 NP_000052.1 Already existis
# 900 NP_000160.1 Already existis
# 901 NP_000524.3 Already existis
# 902 NP_001182482.1 Already existis
# 903 NP_065922.3 Already existis
# 904 NP_005023.2 Already existis
# 905 NP_001143.2 Already existis
# 906 NP_003327.2 Already existis
# 907 NP_078804.2 Already existis
# 908 NP_002285.1 Already existis
# 909 NP_015564.5 Already existis
# 910 NP_001158.2 Already existis
# 911 NP_002342.1 Already existis
# 912 NP_000267.2 Already existis
# 913 NP_001412.1 Already existis
# 914 NP_919253.1 Already existis
# 915 NP_001015877.1 Already existis
# 916 NP_000185.1 Already existis
# 917 NP_001153171.1 Already existis
# 918 NP_000065.1 Already existis
# 919 NP_000124.1 Already existis
# 920 NP_000193.1 Already existis
# 921 NP_000243.1 Already existis
# 922 NP_000799.1 Already existis
# 923 NP_005620.1 Already existis
# 924 NP_000024.2 Already existis
# 925 NP_000045.1 Already existis
# 926 NP_001104262.1 Already existis
# 927 NP_000107.1 Already existis
# 928 NP_001346945.1 Already existis
# 929 NP_001354.1 Already existis
# 930 NP_114127.3 Already existis
# 931 NP_073624.2 Already existis
# 932 NP_031401.1 Already existis
# 933 NP_000293.2 Already existis
# 934 NP_004422.2 Already existis
# 935 NP_997304.3 Already existis
# 936 NP_055862.1 Already existis
# 937 NP_115785.1 Already existis
# 938 NP_001009999.1 Already existis
# 939 NP_003671.1 Already existis
# 940 NP_004691.2 Already existis
# 941 NP_005364.1 Already existis
# 942 NP_065098.1 Already existis
# 943 NP_001041639.1 Already existis
# 944 NP_056321.2 Already existis
# 945 NP_036318.1 Already existis
# 946 NP_001128145.1 Already existis
# 947 NP_057062.1 Already existis
# 948 NP_003663.2 Already existis
# 949 NP_006487.1 Already existis
# 950 NP_001365898.1 Already existis
# 951 NP_001240781.1 Already existis
# 952 NP_002515.1 Already existis
# 953 NP_056651.1 Already existis
# 954 NP_998818.1 Already existis
# 955 NP_689476.2 Already existis
# 956 NP_006547.1 Already existis
# 957 NP_060586.2 Already existis
# 958 NP_002232.2 Already existis
# 959 NP_006173.2 Already existis
# 960 NP_008927.1 Already existis
# 961 NP_002104.2 Already existis
# 962 NP_796376.2 Already existis
# 963 NP_000528.1 Already existis
# 964 NP_758861.1 Already existis
# 965 NP_001366332.1 Already existis
# 966 NP_064632.2 Already existis
# 967 NP_073623.1 Already existis
# 968 NP_665860.2 Already existis
# 969 NP_991331.1 Already existis
# 970 NP_001193673.1 Already existis
# 971 NP_001034451.1 Already existis
# 972 NP_005369.2 Already existis
# 973 NP_002372.1 Already existis
# 974 NP_000173.2 Already existis
# 975 NP_066918.2 Already existis
# 976 NP_002428.1 Already existis
# 977 NP_001029288.1 Already existis
# 978 NP_002700.1 Already existis
# 979 NP_071881.1 Already existis
# 980 NP_071882.1 Already existis
# 981 NP_001165084.1 Already existis
# 982 NP_001177203.1 Already existis
# 983 NP_060532.2 Already existis
# 984 NP_001231639.1 Already existis
# 985 NP_001683.2 Already existis
# 986 NP_003115.1 Already existis
# 987 NP_653164.2 Already existis
# 988 NP_068587.1 Already existis
# 989 NP_006334.2 Already existis
# 990 NP_003457.1 Already existis
# 991 NP_006054.2 Already existis
# 992 NP_000808.2 Already existis
# 993 NP_114148.3 Already existis
# 994 NP_001138722.1 Already existis
# 995 NP_000070.1 Already existis
# 996 NP_001813.1 Already existis
# 997 NP_006155.2 Already existis
# 998 NP_055400.1 Already existis
# 999 NP_055177.2 Already existis
# 1000 NP_001037850.1 Already existis
# 1001 NP_005205.2 Already existis
# 1002 NP_004997.4 Already existis
# 1003 NP_008822.2 Already existis
# 1004 NP_001548.1 Already existis
# 1005 NP_079519.1 Already existis
# 1006 NP_877437.2 Already existis
# 1007 NP_000835.1 Already existis
# 1008 NP_079541.1 Already existis
# 1009 NP_002871.1 Already existis
# 1010 NP_004619.3 Already existis
# 1011 NP_005668.2 Already existis
# 1012 NP_001895.1 Already existis
# 1013 NP_000307.1 Already existis
# 1014 NP_001026873.2 Already existis
# 1015 NP_001780.2 Already existis
# 1016 NP_000378.1 Already existis
# 1017 NP_000875.2 Already existis
# 1018 NP_942581.1 Already existis
# 1019 NP_068806.2 Already existis
# 1020 NP_002061.1 Already existis
# 1021 NP_006536.3 Already existis
# 1022 NP_001364334.1 Already existis
# 1023 NP_001341533.1 Already existis
# 1024 NP_000297.1 Already existis
# 1025 NP_057673.2 Already existis
# 1026 NP_001186728.1 Already existis
# 1027 NP_068799.2 Already existis
# 1028 NP_004517.2 Already existis
# 1029 NP_116027.2 Already existis
# 1030 NP_001263199.1 Already existis
# 1031 NP_001054.2 Already existis
# 1032 NP_005621.2 Already existis
# 1033 NP_848649.3 Already existis
# 1034 NP_003403.2 Already existis
# 1035 NP_004121.2 Already existis
# 1036 NP_009220.2 Already existis
# 1037 NP_079272.4 Already existis
# 1038 NP_000046.1 Already existis
# 1039 NP_009148.2 Already existis
# 1040 NP_001958.2 Already existis
# 1041 NP_006571.2 Already existis
# 1042 NP_000987.2 Already existis
# 1043 NP_000274.3 Already existis
# 1044 NP_001116153.1 Already existis
# 1045 NP_714928.1 Already existis
# 1046 NP_006008.1 Already existis
# 1047 NP_056958.3 Already existis
# 1048 NP_000213.1 Already existis
# 1049 NP_001345850.1 Already existis
# 1050 NP_000288.1 Already existis
# 1051 NP_000336.1 Already existis
# 1052 NP_898898.1 Already existis
# 1053 NP_005318.6 Already existis
# 1054 NP_001358525.1 Already existis
# 1055 NP_476516.1 Already existis
# 1056 NP_000892.2 Already existis
# 1057 NP_068657.1 Already existis
# 1058 NP_068656.2 Already existis
# 1059 NP_612395.2 Already existis
# 1060 NP_001820.2 Already existis
# 1061 NP_000018.2 Already existis
# 1062 NP_997235.3 Already existis
# 1063 NP_000883.2 Already existis
# 1064 NP_000119.1 Already existis
# 1065 NP_001035.1 Already existis
# 1066 NP_036205.1 Already existis
# 1067 NP_004456.1 Already existis
# 1068 NP_000073.1 Already existis
# 1069 NP_001091981.1 Already existis
# 1070 NP_852664.1 Already existis
# 1071 NP_002706.1 Already existis
# 1072 NP_009217.3 Already existis
# 1073 NP_000818.2 Already existis
# 1074 NP_003043.3 Already existis
# 1075 NP_006558.1 Already existis
# 1076 NP_000120.2 Already existis
# 1077 NP_001358995.1 Already existis
# 1078 NP_001229886.1 Already existis
# 1079 NP_004743.1 Already existis
# 1080 NP_001121636.1 Already existis
# 1081 NP_940988.2 Already existis
# 1082 NP_003536.1 Already existis
# 1083 NP_001461.1 Already existis
# 1084 NP_001103279.2 Already existis
# 1085 NP_821133.1 Already existis
# 1086 NP_000584.3 Already existis
# 1087 NP_057143.1 Already existis
# 1088 NP_003212.2 Already existis
# 1089 NP_001073977.1 Already existis
# 1090 NP_001265645.1 Already existis
# 1091 NP_009145.1 Already existis
# 1092 NP_612468.1 Already existis
# 1093 NP_000279.1 Already existis
# 1094 NP_001278963.1 Already existis
# 1095 NP_997001.1 Already existis
# 1096 NP_004553.2 Already existis
# 1097 NP_057182.1 Already existis
# 1098 NP_005609.3 Already existis
# 1099 NP_689956.2 Already existis
# 1100 NP_008839.2 Already existis
# 1101 NP_036426.4 Already existis
# 1102 NP_061932.1 Already existis
# 1103 NP_061820.1 Already existis
# 1104 NP_002128.1 Already existis
# 1105 NP_005514.1 Already existis
# 1106 NP_000513.2 Already existis
# 1107 NP_000814.2 Already existis
# 1108 NP_001211.3 Already existis
# 1109 NP_057122.2 Already existis
# 1110 NP_004594.1 Already existis
# 1111 NP_001382342.1 Already existis
# 1112 NP_005909.2 Already existis
# 1113 NP_036563.1 Already existis
# 1114 NP_005711.1 Already existis
# 1115 NP_004713.2 Already existis
# 1116 NP_001075.1 Already existis
# 1117 NP_945350.1 Already existis
# 1118 NP_056265.2 Already existis
# 1119 NP_001859.1 Already existis
# 1120 NP_001052.3 Already existis
# 1121 NP_005422.1 Already existis
# 1122 NP_000184.1 Already existis
# 1123 NP_061764.2 Already existis
# 1124 NP_078872.3 Already existis
# 1125 NP_699163.2 Already existis
# 1126 NP_808592.2 Already existis
# 1127 NP_006149.2 Already existis
# 1128 NP_001017420.1 Already existis
# 1129 NP_009106.1 Already existis
# 1130 NP_009129.1 Already existis
# 1131 NP_000340.2 Already existis
# 1132 NP_055277.1 Already existis
# 1133 NP_001244109.1 Already existis
# 1134 NP_004811.1 Already existis
# 1135 NP_000494.2 Already existis
# 1136 NP_000058.1 Already existis
# 1137 NP_057107.4 Already existis
# 1138 NP_001185462.1 Already existis
# 1139 NP_006256.1 Already existis
# 1140 NP_036286.2 Already existis
# 1141 NP_510965.1 Already existis
# 1142 NP_001350047.1 Already existis
# 1143 NP_003374.3 Already existis
# 1144 NP_000541.1 Already existis
# 1145 NP_001177666.1 Already existis
# 1146 NP_057609.2 Already existis
# 1147 NP_036276.1 Already existis
# 1148 NP_005857.1 Already existis
# 1149 NP_003280.2 Already existis
# 1150 NP_065995.1 Already existis
# 1151 NP_057126.2 Already existis
# 1152 NP_008845.2 Already existis
# 1153 NP_001689.1 Already existis
# 1154 NP_004551.2 Already existis
# 1155 NP_006406.1 Already existis
# 1156 NP_000188.1 Already existis
# 1157 NP_061819.2 Already existis
# 1158 NP_005449.5 Already existis
# 1159 NP_005583.1 Already existis
# 1160 NP_001850.1 Already existis
# 1161 NP_003156.1 Already existis
# 1162 NP_004399.2 Already existis
# 1163 NP_005085.2 Already existis
# 1164 NP_003002.2 Already existis
# 1165 NP_055723.1 Already existis
# 1166 NP_115925.2 Already existis
# 1167 NP_835258.1 Already existis
# 1168 NP_006079.1 Already existis
# 1169 NP_055970.1 Already existis
# 1170 NP_001008213.1 Already existis
# 1171 NP_057288.1 Already existis
# 1172 NP_001345192.1 Already existis
# 1173 NP_060814.4 Already existis
# 1174 NP_004264.2 Already existis
# 1175 NP_001354463.1 Already existis
# 1176 NP_001092138.1 Already existis
# 1177 NP_004320.2 Already existis
# 1178 NP_005262.1 Already existis
# 1179 NP_001604.1 Already existis
# 1180 NP_510870.1 Already existis
# 1181 NP_000269.3 Already existis
# 1182 NP_060119.3 Already existis
# 1183 NP_031399.2 Already existis
# 1184 NP_001600.1 Already existis
# 1185 NP_065109.1 Already existis
# 1186 NP_003273.1 Already existis
# 1187 NP_001014437.1 Already existis
# 1188 NP_055304.1 Already existis
# 1189 NP_001369496.1 Already existis
# 1190 NP_001243615.1 Already existis
# 1191 NP_001018067.1 Already existis
# 1192 NP_001354802.1 Already existis
# 1193 NP_005557.1 Already existis
# 1194 NP_000602.1 Already existis
# 1195 NP_004162.2 Already existis
# 1196 NP_997005.1 Already existis
# 1197 NP_004804.2 Already existis
# 1198 NP_000497.1 Already existis
# 1199 NP_004542.1 Already existis
# 1200 NP_653186.2 Already existis
# 1201 NP_006259.1 Already existis
# 1202 NP_660201.1 Already existis
# 1203 NP_002487.1 Already existis
# 1204 NP_006010.2 Already existis
# 1205 NP_060105.3 Already existis
# 1206 NP_060631.2 Already existis
# 1207 NP_001122394.1 Already existis
# 1208 NP_002567.3 Already existis
# 1209 NP_004259.3 Already existis
# 1210 NP_002418.1 Already existis
# 1211 NP_005788.1 Already existis
# 1212 NP_004388.2 Already existis
# 1213 NP_001157749.1 Already existis
# 1214 NP_005179.2 Already existis
# 1215 NP_001245173.1 Already existis
# 1216 NP_002008.2 Already existis
# 1217 NP_000881.3 Already existis
# 1218 NP_001750.1 Already existis
# 1219 NP_065689.1 Already existis
# 1220 NP_001056.1 Already existis
# 1221 NP_065712.1 Already existis
# 1222 NP_001978.1 Already existis
# 1223 NP_004973.1 Already existis
# 1224 NP_945316.1 Already existis
# 1225 NP_085911.2 Already existis
# 1226 NP_001035526.1 Already existis
# 1227 NP_000280.1 Already existis
# 1228 NP_004809.2 Already existis
# 1229 NP_060583.2 Already existis
# 1230 NP_000477.1 Already existis
# 1231 NP_003067.3 Already existis
# 1232 NP_000414.2 Already existis
# 1233 NP_002896.2 Already existis
# 1234 NP_001027558.1 Already existis
# 1235 NP_005717.3 Already existis
# 1236 NP_002067.1 Already existis
# 1237 NP_055134.2 Already existis
# 1238 NP_001026849.1 Already existis
# 1239 NP_065134.1 Already existis
# 1240 NP_647480.1 Already existis
# 1241 NP_001193908.1 Already existis
# 1242 NP_443077.1 Already existis
# 1243 NP_000422.1 Already existis
# 1244 NP_001076007.1 Already existis
# 1245 NP_002825.3 Already existis
# 1246 NP_005987.3 Already existis
# 1247 NP_000008.1 Already existis
# 1248 NP_079085.2 Already existis
# 1249 NP_036595.2 Already existis
# 1250 NP_079491.2 Already existis
# 1251 NP_005923.3 Already existis
# 1252 NP_001251.1 Already existis
# 1253 NP_000200.1 Already existis
# 1254 NP_919299.3 Already existis
# 1255 NP_055120.1 Already existis
# 1256 NP_009060.2 Already existis
# 1257 NP_996820.1 Already existis
# 1258 NP_062562.1 Already existis
# 1259 NP_060277.1 Already existis
# 1260 NP_001092744.1 Already existis
# 1261 NP_002733.2 Already existis
# 1262 NP_002854.3 Already existis
# 1263 NP_001193.2 Already existis
# 1264 NP_060269.3 Already existis
# 1265 NP_068374.1 Already existis
# 1266 NP_005973.1 Already existis
# 1267 NP_001521.1 Already existis
# 1268 NP_647479.2 Already existis
# 1269 NP_060261.2 Already existis
# 1270 NP_078772.1 Already existis
# 1271 NP_037514.2 Already existis
# 1272 NP_004854.1 Already existis
# 1273 NP_000286.3 Already existis
# 1274 NP_003375.1 Already existis
# 1275 NP_612808.1 Already existis
# 1276 NP_001357524.1 Already existis
# 1277 NP_001369359.1 Already existis
# 1278 NP_001510.2 Already existis
# 1279 NP_570854.1 Already existis
# 1280 NP_055782.3 Already existis
# 1281 NP_005150.1 Already existis
# 1282 NP_733775.1 Already existis
# 1283 NP_689661.1 Already existis
# 1284 NP_997464.2 Already existis
# 1285 NP_001473.1 Already existis
# 1286 NP_076968.2 Already existis
# 1287 NP_000227.2 Already existis
# 1288 NP_001018005.1 Already existis
# 1289 NP_000933.1 Already existis
# 1290 NP_005893.1 Already existis
# 1291 NP_060352.1 Already existis
# 1292 NP_000772.2 Already existis
# 1293 NP_000741.1 Already existis
# 1294 NP_076425.1 Already existis
# 1295 NP_001752.2 Already existis
# 1296 NP_001186036.1 Already existis
# 1297 NP_001129944.1 Already existis
# 1298 NP_005227.1 Already existis
# 1299 NP_002573.1 Already existis
# 1300 NP_001077083.1 Already existis
# 1301 NP_001035897.1 Already existis
# 1302 NP_015556.1 Already existis
# 1303 NP_660282.2 Already existis
# 1304 NP_009005.1 Already existis
# 1305 NP_000285.1 Already existis
# 1306 NP_443106.1 Already existis
# 1307 NP_597700.1 Already existis
# 1308 NP_003022.3 Already existis
# 1309 NP_114091.4 Already existis
# 1310 NP_055484.3 Already existis
# 1311 NP_958933.1 Already existis
# 1312 NP_037374.1 Already existis
# 1313 NP_000187.3 Already existis
# 1314 NP_006556.1 Already existis
# 1315 NP_061896.1 Already existis
# 1316 NP_001119.3 Already existis
# 1317 NP_000092.2 Already existis
# 1318 NP_000968.2 Already existis
# 1319 NP_542435.2 Already existis
# 1320 NP_000738.2 Already existis
# 1321 NP_001036162.1 Already existis
# 1322 NP_004269.1 Already existis
# 1323 NP_659434.2 Already existis
# 1324 NP_056496.1 Already existis
# 1325 NP_065842.1 Already existis
# 1326 NP_056170.2 Already existis
# 1327 NP_001253981.1 Already existis
# 1328 NP_219487.3 Already existis
# 1329 NP_003070.3 Already existis
# 1330 NP_000217.2 Already existis
# 1331 NP_000517.3 Already existis
# 1332 NP_068758.3 Already existis
# 1333 NP_001073143.1 Already existis
# 1334 NP_612396.1 Already existis
# 1335 NP_003387.1 Already existis
# 1336 NP_001007229.1 Already existis
# 1337 NP_003638.1 Already existis
# 1338 NP_006843.2 Already existis
# 1339 NP_000506.2 Already existis
# 1340 NP_060035.2 Already existis
# 1341 NP_000882.1 Already existis
# 1342 NP_001153245.1 Already existis
# 1343 NP_000909.2 Already existis
# 1344 NP_008838.2 Already existis
# 1345 NP_066552.2 Already existis
# 1346 NP_002885.1 Already existis
# 1347 NP_055083.1 Already existis
# 1348 NP_005350.1 Already existis
# 1349 NP_004530.1 Already existis
# 1350 NP_005903.2 Already existis
# 1351 NP_003830.1 Already existis
# 1352 NP_077718.3 Already existis
# 1353 NP_001051.1 Already existis
# 1354 NP_001952.1 Already existis
# 1355 NP_109587.1 Already existis
# 1356 NP_115484.2 Already existis
# 1357 NP_783313.1 Already existis
# 1358 NP_006003.1 Already existis
# 1359 NP_001005361.1 Already existis
# 1360 NP_001276033.1 Already existis
# 1361 NP_000519.2 Already existis
# 1362 NP_001369170.1 Already existis
# 1363 NP_443108.1 Already existis
# 1364 NP_775754.2 Already existis
# 1365 NP_004741.1 Already existis
# 1366 NP_001483.3 Already existis
# 1367 NP_001371457.1 Already existis
# 1368 NP_113636.2 Already existis
# 1369 NP_644813.1 Already existis
# 1370 NP_008990.2 Already existis
# 1371 NP_004968.2 Already existis
# 1372 NP_055040.2 Already existis
# 1373 NP_055331.1 Already existis
# 1374 NP_001243644.1 Already existis
# 1375 NP_009210.1 Already existis
# 1376 NP_945345.2 Already existis
# 1377 NP_000302.1 Already existis
# 1378 NP_740754.1 Already existis
# 1379 NP_006354.2 Already existis
# 1380 NP_003089.1 Already existis
# 1381 NP_001269862.1 Already existis
# 1382 NP_000169.1 Already existis
# 1383 NP_542119.1 Already existis
# 1384 NP_000013.2 Already existis
# 1385 NP_059142.3 Already existis
# 1386 NP_000475.1 Already existis
# 1387 NP_005060.1 Already existis
# 1388 NP_000062.1 Already existis
# 1389 NP_056074.1 Already existis
# 1390 NP_001121121.1 Already existis
# 1391 NP_004773.1 Already existis
# 1392 NP_002736.3 Already existis
# 1393 NP_003064.2 Already existis
# 1394 NP_001878.1 Already existis
# 1395 NP_001877.1 Already existis
# 1396 NP_002863.1 Already existis
# 1397 NP_060476.2 Already existis
# 1398 NP_758448.1 Already existis
# 1399 NP_001307681.2 Already existis
# 1400 NP_001821.2 Already existis
# 1401 NP_004586.2 Already existis
# 1402 NP_001406.1 Already existis
# 1403 NP_000466.2 Already existis
# 1404 NP_005756.2 Already existis
# 1405 NP_001129470.1 Already existis
# 1406 NP_005667.2 Already existis
# 1407 NP_008881.2 Already existis
# 1408 NP_982301.1 Already existis
# 1409 NP_001027554.1 Already existis
# 1410 NP_001129629.1 Already existis
# 1411 NP_003170.1 Already existis
# 1412 NP_001121370.1 Already existis
# 1413 NP_002538.1 Already existis
# 1414 NP_000197.1 Already existis
# 1415 NP_000298.3 Already existis
# 1416 NP_001004051.1 Already existis
# 1417 NP_004771.2 Already existis
# 1418 NP_002755.1 Already existis
# 1419 NP_001137453.1 Already existis
# 1420 NP_001011551.1 Already existis
# 1421 NP_004199.1 Already existis
# 1422 NP_004475.1 Already existis
# 1423 NP_001366039.1 Already existis
# 1424 NP_003404.1 Already existis
# 1425 NP_004105.1 Already existis
# 1426 NP_115928.1 Already existis
# 1427 NP_002015.1 Already existis
# 1428 NP_001702.1 Already existis
# 1429 NP_003482.1 Already existis
# 1430 NP_004690.1 Already existis
# 1431 NP_000393.4 Already existis
# 1432 NP_001093327.1 Already existis
# 1433 NP_003131.1 Already existis
# #-unique NCBI protein sequences downloaded:  1434
# Creating merged fasta document.

# %%
variations_df["class"].value_counts()
# Out:
# Likely-pathogenic    4168
# Pathogenic           2308
# Name: class, dtype: int64
